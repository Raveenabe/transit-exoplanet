# %%
import numpy as np
from astropy.io import fits
from scipy.interpolate import interp1d

# %%
# Function to find common wavelength range and flux for two spectra
def find_common_range(wavelength1, flux1, wavelength2, flux2):
    common_range = np.intersect1d(wavelength1, wavelength2)
    indices1 = np.searchsorted(wavelength1, common_range, side='left')
    indices2 = np.searchsorted(wavelength2, common_range, side='left')
    indices1 = np.clip(indices1, 0, len(flux1) - 1)
    indices2 = np.clip(indices2, 0, len(flux2) - 1)
    common_flux1 = flux1[indices1]
    common_flux2 = flux2[indices2]
    return common_range, common_flux1, common_flux2

# %%
# Function to normalize the spectrum within a specified wavelength range
def normalize_spectrum(wavelengths, spectrum, wavelength_range):
    # Ensure only wavelengths within the specified range are considered
    selected_indices = np.where((wavelengths >= wavelength_range[0]) & (wavelengths <= wavelength_range[1]))[0]
    selected_wavelengths = wavelengths[selected_indices]
    selected_spectrum = spectrum[selected_indices]
    
    # Normalize the spectrum between 0 and 1
    normalized_spectrum = (selected_spectrum - np.min(selected_spectrum)) / (np.max(selected_spectrum) - np.min(selected_spectrum))
    
    return selected_wavelengths, normalized_spectrum

# %%
# Load Transiting Spectrum
transit_file = "spec-58050-KP194045N483045V06_sp10-054.fits"
data_transit = fits.open(transit_file)

# Blue arm spectra
transit_wvb = data_transit[1].data["WAVELENGTH"]
transit_blue = data_transit[1].data["FLUX"]

# %%
# Load Non-Transit Spectrum
non_transit_file = "spec-57919-KP192314N471144V04_sp09-033.fits"
data_non_transit = fits.open(non_transit_file)

# Blue arm spectrum
non_transit_blue = data_non_transit[1].data["FLUX"]
non_transit_wvb = data_transit[1].data["WAVELENGTH"]

# %%
# Find common wavelength range for red and blue arms
common_range_blue, transit_blue_common, non_transit_blue_common = find_common_range(transit_wvb[0], transit_blue[0], non_transit_wvb[0], non_transit_blue[0])

# Calculate median flux for each arm
median_flux_blue = np.median(transit_blue_common)

# Normalize spectra between 0 and 1
normalized_blue = (transit_blue_common - np.min(transit_blue_common)) / (np.max(transit_blue_common) - np.min(transit_blue_common))
normalized_non_transit_blue = (non_transit_blue_common  - np.min(non_transit_blue_common)) / (np.max(non_transit_blue_common) - np.min(non_transit_blue_common))


'''
# Specify the wavelength range for normalization
wavelength_range = (4100, 9000)

# Normalize transit and non-transit spectra for the blue arm within the specified wavelength range
selected_wavelengths_blue_transit, normalized_transit_blue = normalize_spectrum(transit_wvb, transit_blue, wavelength_range)
selected_wavelengths_blue_non_transit, normalized_non_transit_blue = normalize_spectrum(non_transit_wvb, non_transit_blue, wavelength_range)


# Find common wavelength range for red and blue arms
common_range_blue, transit_blue_common, non_transit_blue_common = find_common_range(selected_wavelengths_blue_transit[0], normalized_transit_blue[0], selected_wavelengths_blue_non_transit[0], normalized_non_transit_blue[0])
'''
# Out:
# '\n# Specify the wavelength range for normalization\nwavelength_range = (4100, 9000)\n\n# Normalize transit and non-transit spectra for the blue arm within the specified wavelength range\nselected_wavelengths_blue_transit, normalized_transit_blue = normalize_spectrum(transit_wvb, transit_blue, wavelength_range)\nselected_wavelengths_blue_non_transit, normalized_non_transit_blue = normalize_spectrum(non_transit_wvb, non_transit_blue, wavelength_range)\n\n\n# Find common wavelength range for red and blue arms\ncommon_range_blue, transit_blue_common, non_transit_blue_common = find_common_range(selected_wavelengths_blue_transit[0], normalized_transit_blue[0], selected_wavelengths_blue_non_transit[0], normalized_non_transit_blue[0])\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema

def find_and_plot_absorption_lines(transit_spectrum_blue, non_transit_spectrum_blue, common_range_blue, wavelength_range, sensitivity):
    # Select the data within the wavelength range
    mask_blue = (common_range_blue >= wavelength_range[0]) & (common_range_blue <= wavelength_range[1])

    # Check if there is any data in the wavelength range for the blue arm
    if not np.any(mask_blue):
        print("No data in the specified wavelength range for the blue arm.")
        return

    # Find local minima in the blue arm transit spectrum
    minima_transit_blue = argrelextrema(transit_spectrum_blue[mask_blue], np.less, order=10)[0]

    # Find local minima in the blue arm non-transit spectrum
    minima_non_transit_blue = argrelextrema(non_transit_spectrum_blue[mask_blue], np.less, order=10)[0]

    # Print the wavelength values corresponding to the identified absorption lines
    print("Absorption Lines in Transit Spectrum (Blue Arm):", common_range_blue[mask_blue][minima_transit_blue])
    print("Absorption Lines in Non-Transit Spectrum (Blue Arm):", common_range_blue[mask_blue][minima_non_transit_blue])

    # Create a new figure
    plt.figure(figsize=(15, 8))

    # Plot the spectra with identified absorption lines
    plt.plot(common_range_blue[mask_blue], transit_spectrum_blue[mask_blue], label='Transit Spectrum (Blue Arm)', color='blue')
    plt.plot(common_range_blue[mask_blue][minima_transit_blue], transit_spectrum_blue[mask_blue][minima_transit_blue], 'o', color='blue', markersize=8, label='Absorption Lines (Transit, Blue Arm)')

    plt.plot(common_range_blue[mask_blue], non_transit_spectrum_blue[mask_blue], label='Non-Transit Spectrum (Blue Arm)', color='cyan')
    plt.plot(common_range_blue[mask_blue][minima_non_transit_blue], non_transit_spectrum_blue[mask_blue][minima_non_transit_blue], 'o', color='cyan', markersize=8, label='Absorption Lines (Non-Transit, Blue Arm)')

    # Set x-axis limits
    plt.xlim(wavelength_range[0], wavelength_range[1])

    # Adjust the figure layout
    plt.xlabel('Wavelength (Angstrom)', fontsize=12)
    plt.ylabel('Flux', fontsize=12)
    plt.legend(fontsize=12)
    plt.title('Transit and Non-Transit Spectra with Identified Absorption Lines (Blue Arm)', fontsize=14)

    plt.show()

# Example usage (replace with your actual values)
# Assuming you have transit_spectrum_blue, non_transit_spectrum_blue, common_range_blue, and other variables defined
find_and_plot_absorption_lines(normalized_blue, normalized_non_transit_blue, common_range_blue, [6530, 6570], sensitivity=0.01)
# Out:
# Absorption Lines in Transit Spectrum (Blue Arm): [6564.4766]
# Absorption Lines in Non-Transit Spectrum (Blue Arm): [6564.4766]

# %%
corrected_wavelength_blue_transit=[]
corrected_wavelength_blue_non_transit=[]

# %%
import numpy as np
import matplotlib.pyplot as plt

def correct_wavelength_with_calibration(transit_spectrum, common_range, true_peak_wavelengths, observed_peak_wavelengths_transit, observed_peak_wavelengths_non_transit):
    # Calculate the correction factors based on the true and observed peaks for transit and non-transit
    correction_factor_transit = np.mean(true_peak_wavelengths - observed_peak_wavelengths_transit)
    correction_factor_non_transit = np.mean(true_peak_wavelengths - observed_peak_wavelengths_non_transit)

    # Correct the wavelength scale of the transit and non-transit spectra separately
    corrected_wavelength_transit = common_range + correction_factor_transit
    corrected_wavelength_non_transit = common_range + correction_factor_non_transit

    return corrected_wavelength_transit, corrected_wavelength_non_transit
''''
# Example true values for Mg I lines from a high-resolution reference spectrum
mg_i_lines_true_values = np.array([5172.684, 5183.604])

# Example observed values for Mg I lines in transit and non-transit spectra
observed_peaks_transit_blue = np.array([5173.4463, 5184.4175])  # Adjust with actual peak values
observed_peaks_non_transit_blue = np.array([5164.0454, 5174.878])  # Adjust with actual peak values

# Use the actual common range for the blue arm obtained from find_common_range
common_range_blue, _, _ = find_common_range(transit_wvb[0], transit_blue[0], transit_wvb[0], non_transit_blue[0])
'''
# Example true values for Mg I lines from a high-resolution reference spectrum
mg_i_lines_true_values = np.array([6562.8])

# Example observed values for Mg I lines in transit and non-transit spectra
observed_peaks_transit_blue = np.array([6564.4766])  # Adjust with actual peak values
observed_peaks_non_transit_blue = np.array([6564.4766])  # Adjust with actual peak values

# Use the actual common range for the blue arm obtained from find_common_range
#common_range_blue, _, _ = find_common_range(transit_wvb[0], transit_blue[0], transit_wvb[0], non_transit_blue[0])

# Correct the wavelength scale separately for transit and non-transit
corrected_wavelength_blue_transit, corrected_wavelength_blue_non_transit = correct_wavelength_with_calibration(
    transit_blue_common, common_range_blue, mg_i_lines_true_values, observed_peaks_transit_blue, observed_peaks_non_transit_blue
)

# Plot the original and corrected spectra for visualization
plt.figure(figsize=(10, 5))
#plt.plot(common_range_blue, normalized_blue, linestyle='--', label='Original Spectrum')

plt.plot(corrected_wavelength_blue_transit, normalized_blue, linestyle='--', label='Corrected Spectrum (Transit)')
plt.plot(corrected_wavelength_blue_non_transit, normalized_non_transit_blue, linestyle='--', label='Corrected Spectrum (Non-Transit)')

# Plot true values for Mg I lines from high-resolution reference spectrum
#plt.scatter(mg_i_lines_true_values, [0]*len(mg_i_lines_true_values), marker='x', color='red', label='True Values (Mg I Lines)')

# Set x-axis limits for the specific wavelength range
wavelength_range = [3500, 9500]  # Adjust with your desired range
plt.xlim(wavelength_range[0], wavelength_range[1])

plt.xlabel('Corrected Wavelength(Angstrom)', fontweight='bold', fontsize=17)
plt.ylabel('Normalized Flux', fontweight='bold', fontsize=17)
plt.title('Transit and Non-Transit spectrum after wavelength correction', fontweight='bold', fontsize=17)
plt.legend()

# Set tick labels to bold
plt.tick_params(axis='both', which='major', labelsize=14, width=2, length=6, labelcolor='black', pad=6, direction='inout', bottom=True, top=True, left=True, right=True, grid_color='grey', grid_alpha=0.5, grid_linestyle='--', labelrotation=45, colors='black', grid_linewidth=1.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import argrelextrema

def find_and_plot_absorption_lines(corrected_wavelength_transit_blue, corrected_wavelength_non_transit_blue, transit_spectrum_blue, non_transit_spectrum_blue, wavelength_range, sensitivity):
    # Select the data within the wavelength range
    mask_blue = (corrected_wavelength_transit_blue >= wavelength_range[0]) & (corrected_wavelength_transit_blue <= wavelength_range[1])

    # Check if there is any data in the wavelength range for the blue arm
    if not np.any(mask_blue):
        print("No data in the specified wavelength range for the blue arm.")
        return

    # Find local minima in the blue arm transit spectrum
    minima_transit_blue = argrelextrema(transit_spectrum_blue[mask_blue], np.less, order=10)[0]

    # Find local minima in the blue arm non-transit spectrum
    minima_non_transit_blue = argrelextrema(non_transit_spectrum_blue[mask_blue], np.less, order=10)[0]

    # Print the wavelength values corresponding to the identified absorption lines
    print("Absorption Lines in Transit Spectrum (Blue Arm):", corrected_wavelength_transit_blue[mask_blue][minima_transit_blue])
    print("Absorption Lines in Non-Transit Spectrum (Blue Arm):", corrected_wavelength_non_transit_blue[mask_blue][minima_non_transit_blue])

    # Create a new figure
    fig, ax = plt.subplots(figsize=(20, 8))

    # Plot the spectra with identified absorption lines
    if np.any(mask_blue):
        ax.plot(corrected_wavelength_transit_blue[mask_blue], transit_spectrum_blue[mask_blue], label='Transit Spectrum (Blue Arm)', color='blue')
        ax.plot(corrected_wavelength_transit_blue[mask_blue][minima_transit_blue], transit_spectrum_blue[mask_blue][minima_transit_blue], 'o', color='blue', markersize=8, label='Absorption Lines (Transit, Blue Arm)')

        ax.plot(corrected_wavelength_non_transit_blue[mask_blue], non_transit_spectrum_blue[mask_blue], label='Non-Transit Spectrum (Blue Arm)', color='cyan')
        ax.plot(corrected_wavelength_non_transit_blue[mask_blue][minima_non_transit_blue], non_transit_spectrum_blue[mask_blue][minima_non_transit_blue], 'o', color='cyan', markersize=8, label='Absorption Lines (Non-Transit, Blue Arm)')

    # Set x-axis limits
    ax.set_xlim(wavelength_range[0], wavelength_range[1])

    # Adjust the figure layout
    ax.set_xlabel('Corrected Wavelength (Angstrom)', fontsize=12)
    ax.set_ylabel('Flux', fontsize=12)
    ax.legend(fontsize=12)
    ax.set_title('Transit and Non-Transit Spectra with Identified Absorption Lines (Blue Arm)', fontsize=14)

    plt.show()

# Example usage (replace with your actual data)
find_and_plot_absorption_lines(corrected_wavelength_blue_transit, corrected_wavelength_blue_non_transit, transit_blue_common, non_transit_blue_common, [6540, 6565], sensitivity=0.01)
# Out:
# Absorption Lines in Transit Spectrum (Blue Arm): [6562.8]
# Absorption Lines in Non-Transit Spectrum (Blue Arm): [6562.8]

# %%
print(np.min(corrected_wavelength_blue_transit),np.max(corrected_wavelength_blue_transit)) #blue arm transit
print(np.min(corrected_wavelength_blue_non_transit),np.max(corrected_wavelength_blue_non_transit)) #blue arm non transit
# Out:
# 3698.3098 9084.896
# 3698.3098 9084.896

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to identify absorption and emission lines within user-specified alignment regions
def identify_lines_in_alignment_region(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                       alignment_region, threshold=0.1):
    # Check if the alignment region is provided
    if alignment_region is None or len(alignment_region) != 2:
        print("Invalid alignment region.")
        return np.array([]), np.array([])

    # Extract the alignment region for both spectra
    transit_mask = np.logical_and(transit_wavelength >= alignment_region[0], transit_wavelength <= alignment_region[1])
    non_transit_mask = np.logical_and(non_transit_wavelength >= alignment_region[0], non_transit_wavelength <= alignment_region[1])

    transit_wavelength_aligned = transit_wavelength[transit_mask]
    non_transit_wavelength_aligned = non_transit_wavelength[non_transit_mask]

    transit_flux_aligned = transit_flux[transit_mask]
    non_transit_flux_aligned = non_transit_flux[non_transit_mask]

    # Ensure both spectra have the same length in the alignment region
    if len(transit_flux_aligned) != len(non_transit_flux_aligned):
        print("Spectra have different lengths in the alignment region. Unable to perform direct subtraction.")
        return np.array([]), np.array([])

    # Calculate residuals (difference) between transit and non-transit flux in the alignment region
    residuals = transit_flux_aligned - non_transit_flux_aligned

    # Identify absorption lines (where residuals are negative)
    absorption_lines = transit_wavelength_aligned[residuals < -threshold]

    # Identify emission lines (where residuals are positive)
    emission_lines = transit_wavelength_aligned[residuals > threshold]

    return absorption_lines, emission_lines


# Blue arm alignment region
alignment_region_blue = [3698.3098, 9084.896]  # Replace with your specified alignment region

# Identify absorption and emission lines for the blue arm using specified alignment region
absorption_lines_blue, emission_lines_blue = identify_lines_in_alignment_region(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    alignment_region_blue
)

# Print or use the identified lines as needed
print("Absorption Lines (Blue Arm):", absorption_lines_blue)
print("Emission Lines (Blue Arm):", emission_lines_blue)

# Plot the spectra and identified lines for the blue arm using specified alignment region
plt.figure(figsize=(15, 8))
plt.plot(corrected_wavelength_blue_transit, normalized_blue, label='Transit Spectrum', color='blue')
plt.plot(corrected_wavelength_blue_non_transit, normalized_non_transit_blue, label='Non-Transit Spectrum', color='green')
#plt.scatter(absorption_lines_blue, np.ones_like(absorption_lines_blue), color='red', marker='v', label='Absorption Lines')
#plt.scatter(emission_lines_blue, np.ones_like(emission_lines_blue), color='purple', marker='^', label='Emission Lines')
plt.xlabel('Corrected Wavelength(Angstrom)')
plt.ylabel('Flux')
plt.legend(loc='upper right')  # Adjust legend position
plt.title('Blue Arm Spectra and Identified Lines in Alignment Region')
plt.show()
# Out:
# Absorption Lines (Blue Arm): [4409.964  4426.2466 4433.3896 ... 9059.823  9070.262  9072.352 ]
# Emission Lines (Blue Arm): [3698.3098 3699.1619 3700.0142 3700.8665 3701.7192 3702.572  3703.425
#  3704.2783 3705.1316 3705.9854 3706.839  3707.693  3708.5474 3709.4016
#  3710.2563 3711.111  3711.966  3712.8213 3713.6768 3714.5322 3715.3882
#  3716.2441 3717.1003 3717.9565 3718.8132 3719.67   3720.5269 3721.384
#  3722.2415 3723.099  3723.9568 3724.8147 3725.6729 3726.5312 3727.39
#  3728.2485 3729.1074 3729.9668 3730.826  3731.6855 3732.5454 3735.1257
#  3735.9863 3736.847  3737.7078 3738.569  3739.4304 3740.2917 3741.1536
#  3742.0154 3742.8777 3743.74   3744.6025 3745.465  3746.3281 3747.1912
#  3748.0544 3750.6455 3751.5098 3752.374  3753.2385 3754.1033 3754.968
#  3755.8333 3756.6985 3757.564  3758.4297 3759.2957 3760.1616 3761.028
#  3761.8945 3762.7612 3763.6282 3764.495  3765.3625 3766.23   3767.0977
#  3767.9656 3768.8335 3769.702  3770.5703 3771.4392 3772.3079 3773.177
#  3774.0464 3774.9158 3775.7856 3776.6555 3777.5256 3778.3958 3779.2664
#  3780.137  3781.0078 3781.879  3782.7502 3783.6218 3784.4934 3785.3655
#  3786.2375 3787.1099 3787.9822 3788.855  3789.7278 3790.601  3791.4744
#  3792.348  3793.2214 3794.0955 3794.9695 3795.8438 3796.7183 3797.593
#  3798.468  3799.343  3800.2185 3801.094  3801.9697 3802.8457 3803.7217
#  3804.5981 3805.4746 3806.3513 3807.2283 3808.1055 3808.9827 3809.8604
#  3810.738  3811.616  3812.4941 3813.3723 3814.251  3815.1296 3816.0085
#  3816.8877 3817.767  3818.6467 3819.5266 3820.4065 3821.2866 3822.167
#  3823.0476 3823.9285 3824.8093 3825.6904 3826.572  3827.4534 3828.3352
#  3829.2173 3830.0994 3830.982  3831.8645 3832.7473 3833.6304 3834.5134
#  3835.397  3836.2805 3837.1643 3838.9326 3839.8171 3840.7017 3841.5864
#  3842.4717 3843.357  3844.2422 3845.128  3846.014  3846.9    3847.7861
#  3848.6726 3849.5593 3850.4463 3851.3333 3852.2205 3853.1082 3853.9958
#  3854.8835 3855.7717 3856.6602 3857.5486 3858.4373 3859.3262 3860.2153
#  3861.1047 3861.9941 3862.884  3863.774  3864.664  3865.5544 3866.445
#  3867.3357 3868.2268 3869.118  3870.0093 3870.901  3871.7927 3872.6848
#  3873.577  3874.4692 3875.362  3876.255  3877.1477 3878.041  3878.9346
#  3879.8281 3880.722  3881.616  3882.5103 3883.4048 3884.2996 3885.1943
#  3886.0894 3886.9846 3887.8801 3888.776  3889.6719 3890.5679 3891.4644
#  3892.3608 3893.2576 3894.1545 3895.0518 3895.949  3896.8467 3897.7444
#  3898.6423 3899.5405 3900.439  3901.3374 3902.2363 3903.1353 3904.0344
#  3904.934  3905.8335 3906.7334 3907.6335 3908.5337 3909.4343 3910.335
#  3911.2358 3912.137  3913.038  3913.9397 3914.8413 3915.7432 3916.6453
#  3917.5476 3918.4502 3919.353  3920.2559 3921.1592 3922.0625 3922.966
#  3923.8699 3924.774  3925.678  3926.5825 3930.2021 3938.359  3939.266
#  3940.1736 3941.0813 3941.9893 3942.8975 3943.806  3944.7146 3945.6233
#  3946.5322 3947.4414 3948.3508 3949.2605 3950.1704 3951.0803 3951.9907
#  3952.9011 3953.8118 3954.7227 3955.6338 3956.5452 3957.4568 3958.3684
#  3959.2803 3960.1924 3961.1047 3962.0173 3962.9302 3964.7563 3971.1548
#  3972.9846 3973.9    3974.8154 3975.7312 3976.6472 3977.5632 3978.4797
#  3979.3962 3980.313  3981.23   3982.1472 3983.0647 3983.9822 3984.9001
#  3985.818  3986.7363 3987.6548 3988.5735 3989.4924 3990.4116 3991.3308
#  3992.2505 3993.1702 3994.09   3995.0103 3995.9307 3996.8513 3997.772
#  3999.6143 4000.5356 4001.4573 4002.3792 4003.3013 4004.2236 4005.146
#  4006.0688 4006.9917 4007.9148 4008.8381 4010.6855 4011.6096 4012.5337
#  4013.458  4014.3828 4015.3076 4016.2327 4017.158  4019.009  4019.935
#  4020.861  4021.7874 4022.7139 4024.5676 4025.4949 4026.4224 4027.3499
#  4028.2776 4029.2058 4030.134  4031.9912 4032.92   4033.849  4034.7786
#  4035.708  4036.6377 4037.5676 4038.4978 4039.4282 4040.359  4041.2898
#  4042.2207 4043.152  4044.0835 4045.0151 4045.947  4046.8792 4047.8115
#  4048.744  4049.6768 4050.6096 4051.543  4053.41   4055.2778 4056.212
#  4058.081  4059.016  4061.822  4062.7578 4063.6938 4065.5664 4066.503
#  4067.44   4068.377  4069.3142 4070.2517 4072.1272 4073.0654 4074.004
#  4077.7593 4079.6384 4080.5784 4081.5183 4082.4587 4083.3992 4084.3398
#  4086.2222 4088.105  4089.0469 4089.9888 4090.9312 4091.8735 4092.8162
#  4094.7024 4097.5327 4102.255  4103.1997 4104.145  4105.091  4106.0366
#  4107.9287 4111.7153 4113.61   4115.506  4118.3506 4119.2993 4122.147
#  4123.0967 4124.047  4125.9473 4126.8975 4129.7505 4135.4624 4140.228
#  4144.9995 4147.8647 4152.645  4162.2217]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# Function to identify absorption and emission lines within user-specified alignment regions
def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, min_snr=10, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate residuals (difference) between transit and non-transit flux in the common range
    residuals = flux_transit_interpolated - flux_non_transit_interpolated
    
    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold_with_snr(residuals, window_size, min_snr)

    # Identify absorption lines (where residuals are below the negative threshold)
    absorption_lines = common_range[residuals < -threshold]

    # Identify emission lines (where residuals are above the positive threshold)
    emission_lines = common_range[residuals > threshold]

    return absorption_lines, emission_lines, residuals

'''
def adaptive_threshold(residuals, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        threshold[i] = significance_factor * local_std

    return threshold
'''

def adaptive_threshold_with_snr(residuals, window_size, min_snr=10):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        snr = np.abs(residuals[i]) / local_std if local_std != 0 else 0  # Prevent division by zero
        threshold[i] = min_snr * local_std if snr >= min_snr else 0  # Set threshold based on minimum SNR

    return threshold

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)  # Replace with your specified alignment region

# Identify absorption and emission lines for the blue arm using specified alignment region
absorption_lines_blue, emission_lines_blue, residuals_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Print or use the identified lines and residuals as needed
print("Absorption Lines (Blue Arm):", absorption_lines_blue)
print("Emission Lines (Blue Arm):", emission_lines_blue)
# Out:
# Absorption Lines (Blue Arm): [4229.53344405 4230.6109768  4231.68850954 ... 9071.96560704 9073.04313979
#  9074.12067253]
# Emission Lines (Blue Arm): [3698.3098     3699.38733275 3700.46486549 3701.54239824 3702.61993099
#  3703.69746373 3704.77499648 3705.85252923 3706.93006197 3708.00759472
#  3709.08512747 3710.16266021 3711.24019296 3712.31772571 3713.39525845
#  3714.4727912  3715.55032394 3716.62785669 3717.70538944 3718.78292218
#  3719.86045493 3720.93798768 3722.01552042 3723.09305317 3724.17058592
#  3725.24811866 3726.32565141 3727.40318416 3728.4807169  3729.55824965
#  3730.6357824  3731.71331514 3732.79084789 3733.86838064 3734.94591338
#  3736.02344613 3737.10097888 3738.17851162 3739.25604437 3740.33357712
#  3741.41110986 3742.48864261 3743.56617536 3744.6437081  3745.72124085
#  3746.79877359 3747.87630634 3748.95383909 3750.03137183 3751.10890458
#  3752.18643733 3753.26397007 3754.34150282 3755.41903557 3756.49656831
#  3757.57410106 3758.65163381 3759.72916655 3760.8066993  3761.88423205
#  3762.96176479 3764.03929754 3765.11683029 3766.19436303 3767.27189578
#  3768.34942853 3769.42696127 3770.50449402 3771.58202677 3772.65955951
#  3773.73709226 3774.81462501 3775.89215775 3776.9696905  3778.04722324
#  3779.12475599 3780.20228874 3781.27982148 3782.35735423 3783.43488698
#  3784.51241972 3785.58995247 3786.66748522 3787.74501796 3788.82255071
#  3789.90008346 3790.9776162  3792.05514895 3793.1326817  3794.21021444
#  3795.28774719 3796.36527994 3797.44281268 3798.52034543 3799.59787818
#  3800.67541092 3801.75294367 3802.83047642 3803.90800916 3804.98554191
#  3806.06307465 3807.1406074  3808.21814015 3809.29567289 3810.37320564
#  3811.45073839 3812.52827113 3813.60580388 3814.68333663 3815.76086937
#  3816.83840212 3817.91593487 3818.99346761 3820.07100036 3821.14853311
#  3822.22606585 3823.3035986  3824.38113135 3825.45866409 3826.53619684
#  3827.61372959 3828.69126233 3829.76879508 3830.84632783 3831.92386057
#  3833.00139332 3834.07892607 3835.15645881 3836.23399156 3837.3115243
#  3838.38905705 3839.4665898  3840.54412254 3841.62165529 3842.69918804
#  3843.77672078 3844.85425353 3845.93178628 3847.00931902 3848.08685177
#  3849.16438452 3850.24191726 3851.31945001 3852.39698276 3853.4745155
#  3854.55204825 3855.629581   3856.70711374 3857.78464649 3858.86217924
#  3859.93971198 3861.01724473 3862.09477748 3863.17231022 3864.24984297
#  3865.32737572 3866.40490846 3867.48244121 3868.55997395 3869.6375067
#  3870.71503945 3871.79257219 3872.87010494 3873.94763769 3875.02517043
#  3876.10270318 3877.18023593 3878.25776867 3879.33530142 3880.41283417
#  3881.49036691 3882.56789966 3883.64543241 3884.72296515 3885.8004979
#  3886.87803065 3887.95556339 3889.03309614 3890.11062889 3891.18816163
#  3892.26569438 3893.34322713 3894.42075987 3895.49829262 3896.57582537
#  3897.65335811 3898.73089086 3899.8084236  3900.88595635 3901.9634891
#  3903.04102184 3904.11855459 3905.19608734 3906.27362008 3907.35115283
#  3908.42868558 3909.50621832 3910.58375107 3911.66128382 3912.73881656
#  3913.81634931 3914.89388206 3915.9714148  3917.04894755 3918.1264803
#  3919.20401304 3920.28154579 3921.35907854 3922.43661128 3923.51414403
#  3924.59167678 3925.66920952 3926.74674227 3927.82427502 3928.90180776
#  3929.97934051 3931.05687325 3932.134406   3933.21193875 3934.28947149
#  3935.36700424 3936.44453699 3937.52206973 3938.59960248 3939.67713523
#  3940.75466797 3941.83220072 3942.90973347 3943.98726621 3945.06479896
#  3946.14233171 3947.21986445 3948.2973972  3949.37492995 3950.45246269
#  3951.52999544 3952.60752819 3953.68506093 3954.76259368 3955.84012643
#  3956.91765917 3957.99519192 3959.07272466 3960.15025741 3961.22779016
#  3962.3053229  3963.38285565 3964.4603884  3965.53792114 3966.61545389
#  3967.69298664 3968.77051938 3969.84805213 3970.92558488 3972.00311762
#  3973.08065037 3974.15818312 3975.23571586 3976.31324861 3977.39078136
#  3978.4683141  3979.54584685 3980.6233796  3981.70091234 3982.77844509
#  3983.85597784 3984.93351058 3986.01104333 3987.08857608 3988.16610882
#  3989.24364157 3990.32117431 3991.39870706 3992.47623981 3993.55377255
#  3994.6313053  3995.70883805 3996.78637079 3997.86390354 3998.94143629
#  4000.01896903 4001.09650178 4002.17403453 4003.25156727 4004.32910002
#  4005.40663277 4006.48416551 4007.56169826 4008.63923101 4009.71676375
#  4010.7942965  4011.87182925 4012.94936199 4014.02689474 4015.10442749
#  4016.18196023 4017.25949298 4018.33702573 4019.41455847 4020.49209122
#  4021.56962396 4022.64715671 4023.72468946 4024.8022222  4025.87975495
#  4026.9572877  4028.03482044 4029.11235319 4030.18988594 4031.26741868
#  4032.34495143 4033.42248418 4034.50001692 4035.57754967 4036.65508242
#  4037.73261516 4038.81014791 4039.88768066 4040.9652134  4042.04274615
#  4043.1202789  4044.19781164 4045.27534439 4046.35287714 4047.43040988
#  4048.50794263 4049.58547538 4050.66300812 4051.74054087 4052.81807361
#  4053.89560636 4054.97313911 4056.05067185 4057.1282046  4058.20573735
#  4059.28327009 4060.36080284 4061.43833559 4062.51586833 4063.59340108
#  4064.67093383 4065.74846657 4066.82599932 4067.90353207 4068.98106481
#  4070.05859756 4071.13613031 4072.21366305 4073.2911958  4074.36872855
#  4075.44626129 4076.52379404 4077.60132679 4078.67885953 4079.75639228
#  4080.83392503 4081.91145777 4082.98899052 4084.06652326 4085.14405601
#  4086.22158876 4087.2991215  4088.37665425 4089.454187   4090.53171974
#  4091.60925249 4092.68678524 4093.76431798 4094.84185073 4095.91938348
#  4096.99691622 4098.07444897 4099.15198172 4100.22951446 4101.30704721
#  4102.38457996 4103.4621127  4104.53964545 4105.6171782  4106.69471094
#  4107.77224369 4108.84977644 4109.92730918 4111.00484193 4112.08237467
#  4113.15990742 4114.23744017 4115.31497291 4116.39250566 4117.47003841
#  4118.54757115 4119.6251039  4120.70263665 4121.78016939 4122.85770214
#  4123.93523489 4125.01276763 4126.09030038 4127.16783313 4128.24536587
#  4129.32289862 4130.40043137 4131.47796411 4132.55549686 4133.63302961
#  4134.71056235 4135.7880951  4136.86562785 4137.94316059 4139.02069334
#  4140.09822609 4141.17575883 4142.25329158 4143.33082432 4144.40835707
#  4145.48588982 4146.56342256 4147.64095531 4148.71848806 4149.7960208
#  4150.87355355 4151.9510863  4153.02861904 4154.10615179 4155.18368454
#  4156.26121728 4157.33875003 4158.41628278 4159.49381552 4160.57134827
#  4161.64888102 4162.72641376 4163.80394651 4164.88147926 4165.959012
#  4167.03654475 4168.1140775  4169.19161024 4170.26914299 4171.34667574
#  4172.42420848 4173.50174123 4174.57927397 4175.65680672 4176.73433947
#  4177.81187221 4178.88940496 4179.96693771 4181.04447045 4182.1220032
#  4183.19953595 4184.27706869 4185.35460144 4186.43213419 4187.50966693
#  4188.58719968 4189.66473243 4190.74226517 4191.81979792 4192.89733067
#  4193.97486341 4195.05239616 4196.12992891 4197.20746165 4198.2849944
#  4199.36252715 4200.44005989 4201.51759264 4202.59512539 4203.67265813
#  4204.75019088 4205.82772362 4206.90525637 4207.98278912 4209.06032186
#  4210.13785461 4211.21538736 4212.2929201  4213.37045285 4214.4479856
#  4215.52551834 4216.60305109 4217.68058384 4218.75811658 4219.83564933
#  4220.91318208 4221.99071482 4223.06824757 4224.14578032 4225.22331306
#  4226.30084581 4227.37837856 4228.4559113  4234.92110778 4235.99864053
#  4239.23123877 4240.30877151 4244.6189025  4246.77396799 4247.85150074
#  4248.92903349 4250.00656623 4255.39422997 4257.54929546 4260.7818937
#  4261.85942645 4262.93695919 4266.16955743 4267.24709018 4270.47968842
#  4271.55722116 4272.63475391 4273.71228666 4274.7898194  4276.9448849
#  4278.02241764 4279.09995039 4280.17748314 4281.25501588 4283.41008138
#  4286.64267962 4288.79774511 4290.9528106  4292.03034335 4293.1078761
#  4294.18540884 4295.26294159 4296.34047433 4297.41800708 4298.49553983
#  4300.65060532 4301.72813807 4302.80567081 4303.88320356 4304.96073631
#  4306.03826905 4307.1158018  4308.19333455 4309.27086729 4311.42593279
#  4312.50346553 4313.58099828 4314.65853103 4315.73606377 4316.81359652
#  4317.89112927 4320.04619476 4321.12372751 4334.05412046 4337.2867187
#  4339.4417842  4340.51931694 4341.59684969 4342.67438244 4343.75191518
#  4350.21711166 4362.06997187 4363.14750462 4367.45763561 4368.53516835]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# Function to identify absorption and emission lines within user-specified alignment regions
def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, min_snr=10, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate residuals (difference) between transit and non-transit flux in the common range
    residuals = flux_transit_interpolated - flux_non_transit_interpolated
    
    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold_with_snr(residuals, window_size, min_snr)

    # Identify absorption lines (where residuals are below the negative threshold)
    absorption_lines = common_range[residuals < -threshold]

    # Identify emission lines (where residuals are above the positive threshold)
    emission_lines = common_range[residuals > threshold]

    return absorption_lines, emission_lines, residuals, threshold
'''
def adaptive_threshold(residuals, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        threshold[i] = significance_factor * local_std

    return threshold
'''

def adaptive_threshold_with_snr(residuals, window_size, min_snr=10):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        snr = np.abs(residuals[i]) / local_std if local_std != 0 else 0  # Prevent division by zero
        threshold[i] = min_snr * local_std if snr >= min_snr else 0  # Set threshold based on minimum SNR

    return threshold

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)  # Replace with your specified alignment region

# Identify absorption and emission lines for the blue arm using specified alignment region
absorption_lines_blue, emission_lines_blue, residuals_blue, threshold_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Plot the residuals and identified lines
plt.figure(figsize=(15, 8))
plt.plot(common_range_blue, residuals_blue, label='Residuals', color='gray', linestyle='solid')

# Plot absorption lines
for wavelength, threshold_value in zip(absorption_lines_blue, -threshold_blue):
    plt.scatter(wavelength, threshold_value, color='blue', marker='v', label='Absorption Lines' if wavelength == absorption_lines_blue[0] else None)

# Plot emission lines
for wavelength, threshold_value in zip(emission_lines_blue, threshold_blue):
    plt.scatter(wavelength, threshold_value, color='green', marker='^', label='Emission Lines' if wavelength == emission_lines_blue[0] else None)

plt.axhline(0, color='black', linestyle='dashed', linewidth=1)
plt.xlabel('Corrected Wavelength(Angstrom)', fontweight='bold')
plt.ylabel('Residuals (Transit - Non-Transit Flux)', fontweight='bold')
plt.legend(loc='upper right')  # Adjust legend position
plt.title('Residuals and Identified Lines in Common Range', fontweight='bold')
# Set tick labels to bold
plt.tick_params(axis='both', which='major', labelsize=10, width=2, length=6, labelcolor='black', pad=6, direction='inout', bottom=True, top=True, left=True, right=True, grid_color='grey', grid_alpha=0.5, grid_linestyle='--', labelrotation=45, colors='black', grid_linewidth=1.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# Function to identify absorption and emission lines within user-specified alignment regions
def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, min_snr=10, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate residuals (difference) between transit and non-transit flux in the common range
    residuals = flux_transit_interpolated - flux_non_transit_interpolated
    
    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold_with_snr(residuals, window_size, min_snr)

    # Identify absorption lines (where residuals are below the negative threshold)
    absorption_lines = common_range[residuals < -threshold]

    # Identify emission lines (where residuals are above the positive threshold)
    emission_lines = common_range[residuals > threshold]

    return absorption_lines, emission_lines, residuals, threshold

def adaptive_threshold_with_snr(residuals, window_size, min_snr=10):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        snr = np.abs(residuals[i]) / local_std if local_std != 0 else 0  # Prevent division by zero
        threshold[i] = min_snr * local_std if snr >= min_snr else 0  # Set threshold based on minimum SNR

    return threshold

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)  # Replace with your specified alignment region

# Identify absorption and emission lines for the blue arm using specified alignment region
absorption_lines_blue, emission_lines_blue, residuals_blue, threshold_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Plot the residuals and identified lines
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(common_range_blue, residuals_blue, label='Residuals', color='gray', linestyle='solid')

# Plot absorption lines
for wavelength, threshold_value in zip(absorption_lines_blue, -threshold_blue):
    ax.scatter(wavelength, threshold_value, color='blue', marker='v', label='Absorption Lines' if wavelength == absorption_lines_blue[0] else None)

# Plot emission lines
for wavelength, threshold_value in zip(emission_lines_blue, threshold_blue):
    ax.scatter(wavelength, threshold_value, color='green', marker='^', label='Emission Lines' if wavelength == emission_lines_blue[0] else None)

ax.axhline(0, color='black', linestyle='dashed', linewidth=1)
ax.set_xlabel('Corrected Wavelength (Angstrom)', fontweight='bold', fontsize=20)
ax.set_ylabel('Flux Residuals (Transit - Non-Transit Flux)', fontweight='bold', fontsize=20)
ax.legend(loc='upper right')  # Adjust legend position
ax.set_title('Residuals and Identified Lines in Common Range', fontweight='bold', fontsize=20)

# Add inset manually
ax_inset = ax.inset_axes([0.6, 0.6, 0.3, 0.3])
ax_inset.plot(common_range_blue, residuals_blue)
ax_inset.set_xlim(6500, 7000)  # Set x-range for the inset axes
ax_inset.set_ylim(-0.3, -0.1)
ax.indicate_inset_zoom(ax_inset,edgecolor='red', lw =7)
ax_inset.set_title('Zoomed-in Residual spectrum')
# Set tick labels to bold
plt.tick_params(axis='both', which='major', labelsize=14, width=2, length=6, labelcolor='black', pad=6, direction='inout', bottom=True, top=True, left=True, right=True, grid_color='grey', grid_alpha=0.5, grid_linestyle='--', labelrotation=45, colors='black', grid_linewidth=1.5)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

def load_csv(file_path):
    df = pd.read_csv(file_path)
    # Drop rows with NaN values in the 'obs_wl_air(A)' column
    df.dropna(subset=['obs_wl_air(A)'], inplace=True)
    return df

def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, min_snr=10, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate residuals (difference) between transit and non-transit flux in the common range
    residuals = flux_transit_interpolated - flux_non_transit_interpolated
    
    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold_with_snr(residuals, window_size, min_snr)

    # Identify absorption lines (where residuals are below the negative threshold)
    absorption_lines = common_range[residuals < -threshold]

    # Identify emission lines (where residuals are above the positive threshold)
    emission_lines = common_range[residuals > threshold]

    return absorption_lines, emission_lines, residuals

'''
def adaptive_threshold(residuals, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        threshold[i] = significance_factor * local_std

    return threshold
'''

def adaptive_threshold_with_snr(residuals, window_size, min_snr=10):
    half_window = window_size // 2
    threshold = np.zeros_like(residuals)

    for i in range(len(residuals)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(residuals), i + half_window + 1)
        local_std = np.std(residuals[start_idx:end_idx])
        snr = np.abs(residuals[i]) / local_std if local_std != 0 else 0  # Prevent division by zero
        threshold[i] = min_snr * local_std if snr >= min_snr else 0  # Set threshold based on minimum SNR

    return threshold

# Function to cross-check wavelengths with CSV data
def cross_check_wavelengths_with_csv(wavelengths, df, tolerance=0.1):
    ions = []
    sp_nums = []

    # Iterate over each wavelength
    for wavelength in wavelengths:
        # Find the closest wavelength in the CSV data within the specified tolerance
        closest_matches = df[df['obs_wl_air(A)'].between(wavelength - tolerance, wavelength + tolerance)]

        # Extract corresponding ion and sp_num from the CSV data
        if not closest_matches.empty:
            ion = closest_matches['element'].values[0]
            sp_num = closest_matches['sp_num'].values[0]

            # Append results to lists
            ions.append(ion)
            sp_nums.append(sp_num)
        else:
            # Append placeholders if no match is found
            ions.append(None)
            sp_nums.append(None)

    return ions, sp_nums

# Function to print cross-checked results
def print_results(lines, ions, sp_nums, arm_name):
    print(f"Cross-checked {len(lines)} Lines ({arm_name} Arm):")
    
    min_length = min(len(lines), len(ions), len(sp_nums))
    
    for i in range(min_length):
        print(f"Wavelength: {lines[i]}, Ion: {ions[i]}, sp_num: {sp_nums[i]}")

# Load CSV data
df = load_csv('lines.csv')

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)
absorption_lines_blue, emission_lines_blue, residuals_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Cross-check absorption and emission lines for the Blue Arm
ions_blue, sp_nums_blue = cross_check_wavelengths_with_csv(absorption_lines_blue, df)
print_results(absorption_lines_blue, ions_blue, sp_nums_blue, "Blue Absorption")
print_results(emission_lines_blue, ions_blue, sp_nums_blue, "Blue Emission")  # Corrected line
# Out:
# Cross-checked 4430 Lines (Blue Absorption Arm):
# Wavelength: 4229.5334440488095, Ion: None, sp_num: None
# Wavelength: 4230.610976795359, Ion: None, sp_num: None
# Wavelength: 4231.688509541908, Ion: None, sp_num: None
# Wavelength: 4232.766042288458, Ion: None, sp_num: None
# Wavelength: 4233.843575035007, Ion: None, sp_num: None
# Wavelength: 4237.076173274655, Ion: None, sp_num: None
# Wavelength: 4238.153706021204, Ion: None, sp_num: None
# Wavelength: 4241.386304260852, Ion: None, sp_num: None
# Wavelength: 4242.463837007402, Ion: None, sp_num: None
# Wavelength: 4243.541369753951, Ion: None, sp_num: None
# Wavelength: 4245.6964352470495, Ion: None, sp_num: None
# Wavelength: 4251.084098979796, Ion: None, sp_num: None
# Wavelength: 4252.161631726345, Ion: None, sp_num: None
# Wavelength: 4253.239164472895, Ion: None, sp_num: None
# Wavelength: 4254.316697219444, Ion: None, sp_num: None
# Wavelength: 4256.471762712543, Ion: None, sp_num: None
# Wavelength: 4258.626828205641, Ion: None, sp_num: None
# Wavelength: 4259.704360952191, Ion: None, sp_num: None
# Wavelength: 4264.014491938387, Ion: None, sp_num: None
# Wavelength: 4265.092024684937, Ion: None, sp_num: None
# Wavelength: 4268.324622924585, Ion: None, sp_num: None
# Wavelength: 4269.402155671134, Ion: None, sp_num: None
# Wavelength: 4275.86735215043, Ion: None, sp_num: None
# Wavelength: 4282.332548629726, Ion: None, sp_num: None
# Wavelength: 4284.487614122825, Ion: None, sp_num: None
# Wavelength: 4285.565146869374, Ion: None, sp_num: None
# Wavelength: 4287.720212362473, Ion: None, sp_num: None
# Wavelength: 4289.875277855571, Ion: None, sp_num: None
# Wavelength: 4299.573072574515, Ion: None, sp_num: None
# Wavelength: 4310.348400040008, Ion: None, sp_num: None
# Wavelength: 4318.968662012403, Ion: None, sp_num: None
# Wavelength: 4322.201260252051, Ion: None, sp_num: None
# Wavelength: 4323.2787929986, Ion: None, sp_num: None
# Wavelength: 4324.35632574515, Ion: None, sp_num: None
# Wavelength: 4325.433858491699, Ion: None, sp_num: None
# Wavelength: 4326.511391238248, Ion: None, sp_num: None
# Wavelength: 4327.5889239847975, Ion: None, sp_num: None
# Wavelength: 4328.666456731346, Ion: None, sp_num: None
# Wavelength: 4329.743989477895, Ion: None, sp_num: None
# Wavelength: 4330.821522224445, Ion: None, sp_num: None
# Wavelength: 4331.899054970994, Ion: None, sp_num: None
# Wavelength: 4332.976587717543, Ion: None, sp_num: None
# Wavelength: 4335.131653210642, Ion: None, sp_num: None
# Wavelength: 4336.209185957192, Ion: None, sp_num: None
# Wavelength: 4338.36425145029, Ion: None, sp_num: None
# Wavelength: 4344.829447929586, Ion: None, sp_num: None
# Wavelength: 4345.906980676135, Ion: None, sp_num: None
# Wavelength: 4346.984513422684, Ion: None, sp_num: None
# Wavelength: 4348.062046169234, Ion: None, sp_num: None
# Wavelength: 4349.139578915783, Ion: None, sp_num: None
# Wavelength: 4351.294644408882, Ion: None, sp_num: None
# Wavelength: 4352.372177155431, Ion: None, sp_num: None
# Wavelength: 4353.449709901981, Ion: None, sp_num: None
# Wavelength: 4354.52724264853, Ion: None, sp_num: None
# Wavelength: 4355.604775395079, Ion: None, sp_num: None
# Wavelength: 4356.682308141629, Ion: None, sp_num: None
# Wavelength: 4357.759840888178, Ion: None, sp_num: None
# Wavelength: 4358.837373634728, Ion: None, sp_num: None
# Wavelength: 4359.9149063812765, Ion: None, sp_num: None
# Wavelength: 4360.9924391278255, Ion: None, sp_num: None
# Wavelength: 4364.225037367473, Ion: None, sp_num: None
# Wavelength: 4365.302570114023, Ion: None, sp_num: None
# Wavelength: 4366.380102860572, Ion: None, sp_num: None
# Wavelength: 4369.61270110022, Ion: None, sp_num: None
# Wavelength: 4370.69023384677, Ion: None, sp_num: None
# Wavelength: 4371.767766593319, Ion: None, sp_num: None
# Wavelength: 4372.845299339868, Ion: None, sp_num: None
# Wavelength: 4373.922832086418, Ion: None, sp_num: None
# Wavelength: 4375.000364832967, Ion: None, sp_num: None
# Wavelength: 4376.0778975795165, Ion: None, sp_num: None
# Wavelength: 4377.1554303260655, Ion: None, sp_num: None
# Wavelength: 4378.232963072614, Ion: None, sp_num: None
# Wavelength: 4379.310495819164, Ion: None, sp_num: None
# Wavelength: 4380.388028565713, Ion: None, sp_num: None
# Wavelength: 4381.465561312262, Ion: None, sp_num: None
# Wavelength: 4382.543094058812, Ion: None, sp_num: None
# Wavelength: 4383.620626805361, Ion: None, sp_num: None
# Wavelength: 4384.69815955191, Ion: None, sp_num: None
# Wavelength: 4385.77569229846, Ion: None, sp_num: None
# Wavelength: 4386.853225045009, Ion: None, sp_num: None
# Wavelength: 4387.930757791559, Ion: None, sp_num: None
# Wavelength: 4389.008290538108, Ion: None, sp_num: None
# Wavelength: 4390.085823284657, Ion: None, sp_num: None
# Wavelength: 4391.163356031207, Ion: None, sp_num: None
# Wavelength: 4392.240888777756, Ion: None, sp_num: None
# Wavelength: 4393.318421524305, Ion: None, sp_num: None
# Wavelength: 4394.395954270854, Ion: None, sp_num: None
# Wavelength: 4395.473487017403, Ion: None, sp_num: None
# Wavelength: 4396.551019763953, Ion: None, sp_num: None
# Wavelength: 4397.628552510502, Ion: None, sp_num: None
# Wavelength: 4398.706085257051, Ion: None, sp_num: None
# Wavelength: 4399.783618003601, Ion: None, sp_num: None
# Wavelength: 4400.86115075015, Ion: None, sp_num: None
# Wavelength: 4401.938683496699, Ion: None, sp_num: None
# Wavelength: 4403.016216243249, Ion: None, sp_num: None
# Wavelength: 4404.093748989798, Ion: None, sp_num: None
# Wavelength: 4405.171281736348, Ion: None, sp_num: None
# Wavelength: 4406.248814482897, Ion: None, sp_num: None
# Wavelength: 4407.326347229446, Ion: None, sp_num: None
# Wavelength: 4408.403879975996, Ion: None, sp_num: None
# Wavelength: 4409.4814127225445, Ion: None, sp_num: None
# Wavelength: 4410.558945469094, Ion: None, sp_num: None
# Wavelength: 4411.636478215643, Ion: None, sp_num: None
# Wavelength: 4412.714010962192, Ion: None, sp_num: None
# Wavelength: 4413.791543708742, Ion: None, sp_num: None
# Wavelength: 4414.869076455291, Ion: None, sp_num: None
# Wavelength: 4415.94660920184, Ion: None, sp_num: None
# Wavelength: 4417.02414194839, Ion: None, sp_num: None
# Wavelength: 4418.101674694939, Ion: None, sp_num: None
# Wavelength: 4419.179207441488, Ion: None, sp_num: None
# Wavelength: 4420.256740188038, Ion: None, sp_num: None
# Wavelength: 4421.334272934587, Ion: None, sp_num: None
# Wavelength: 4422.411805681137, Ion: None, sp_num: None
# Wavelength: 4423.489338427686, Ion: None, sp_num: None
# Wavelength: 4424.566871174235, Ion: None, sp_num: None
# Wavelength: 4425.6444039207845, Ion: None, sp_num: None
# Wavelength: 4426.7219366673335, Ion: None, sp_num: None
# Wavelength: 4427.799469413883, Ion: None, sp_num: None
# Wavelength: 4428.877002160432, Ion: None, sp_num: None
# Wavelength: 4429.954534906981, Ion: None, sp_num: None
# Wavelength: 4431.032067653531, Ion: None, sp_num: None
# Wavelength: 4432.10960040008, Ion: None, sp_num: None
# Wavelength: 4433.187133146629, Ion: None, sp_num: None
# Wavelength: 4434.264665893179, Ion: None, sp_num: None
# Wavelength: 4435.342198639728, Ion: None, sp_num: None
# Wavelength: 4436.419731386277, Ion: None, sp_num: None
# Wavelength: 4437.497264132827, Ion: None, sp_num: None
# Wavelength: 4438.574796879376, Ion: None, sp_num: None
# Wavelength: 4439.652329625926, Ion: None, sp_num: None
# Wavelength: 4440.729862372475, Ion: None, sp_num: None
# Wavelength: 4441.807395119024, Ion: None, sp_num: None
# Wavelength: 4442.884927865573, Ion: None, sp_num: None
# Wavelength: 4443.962460612122, Ion: None, sp_num: None
# Wavelength: 4445.039993358672, Ion: None, sp_num: None
# Wavelength: 4446.117526105221, Ion: None, sp_num: None
# Wavelength: 4447.19505885177, Ion: None, sp_num: None
# Wavelength: 4448.27259159832, Ion: None, sp_num: None
# Wavelength: 4449.350124344869, Ion: None, sp_num: None
# Wavelength: 4450.427657091418, Ion: None, sp_num: None
# Wavelength: 4451.505189837968, Ion: None, sp_num: None
# Wavelength: 4452.582722584517, Ion: None, sp_num: None
# Wavelength: 4453.660255331066, Ion: None, sp_num: None
# Wavelength: 4454.737788077616, Ion: None, sp_num: None
# Wavelength: 4455.815320824165, Ion: None, sp_num: None
# Wavelength: 4456.892853570715, Ion: None, sp_num: None
# Wavelength: 4457.970386317264, Ion: None, sp_num: None
# Wavelength: 4459.0479190638125, Ion: None, sp_num: None
# Wavelength: 4460.125451810362, Ion: None, sp_num: None
# Wavelength: 4461.202984556911, Ion: None, sp_num: None
# Wavelength: 4462.280517303461, Ion: None, sp_num: None
# Wavelength: 4463.35805005001, Ion: None, sp_num: None
# Wavelength: 4464.435582796559, Ion: None, sp_num: None
# Wavelength: 4465.513115543109, Ion: None, sp_num: None
# Wavelength: 4466.590648289658, Ion: None, sp_num: None
# Wavelength: 4467.668181036208, Ion: None, sp_num: None
# Wavelength: 4468.745713782757, Ion: None, sp_num: None
# Wavelength: 4469.823246529306, Ion: None, sp_num: None
# Wavelength: 4470.900779275856, Ion: None, sp_num: None
# Wavelength: 4471.978312022405, Ion: None, sp_num: None
# Wavelength: 4473.055844768954, Ion: None, sp_num: None
# Wavelength: 4474.1333775155035, Ion: None, sp_num: None
# Wavelength: 4475.2109102620525, Ion: None, sp_num: None
# Wavelength: 4476.2884430086015, Ion: None, sp_num: None
# Wavelength: 4477.365975755151, Ion: None, sp_num: None
# Wavelength: 4478.4435085017, Ion: None, sp_num: None
# Wavelength: 4479.52104124825, Ion: None, sp_num: None
# Wavelength: 4480.598573994799, Ion: None, sp_num: None
# Wavelength: 4481.676106741348, Ion: None, sp_num: None
# Wavelength: 4482.753639487898, Ion: None, sp_num: None
# Wavelength: 4483.831172234447, Ion: None, sp_num: None
# Wavelength: 4484.908704980997, Ion: None, sp_num: None
# Wavelength: 4485.986237727546, Ion: None, sp_num: None
# Wavelength: 4487.063770474095, Ion: None, sp_num: None
# Wavelength: 4488.141303220645, Ion: None, sp_num: None
# Wavelength: 4489.218835967194, Ion: None, sp_num: None
# Wavelength: 4490.296368713743, Ion: None, sp_num: None
# Wavelength: 4491.3739014602925, Ion: None, sp_num: None
# Wavelength: 4492.451434206841, Ion: None, sp_num: None
# Wavelength: 4493.52896695339, Ion: None, sp_num: None
# Wavelength: 4494.60649969994, Ion: None, sp_num: None
# Wavelength: 4495.684032446489, Ion: None, sp_num: None
# Wavelength: 4496.761565193039, Ion: None, sp_num: None
# Wavelength: 4497.839097939588, Ion: None, sp_num: None
# Wavelength: 4498.916630686137, Ion: None, sp_num: None
# Wavelength: 4499.994163432687, Ion: None, sp_num: None
# Wavelength: 4501.071696179236, Ion: None, sp_num: None
# Wavelength: 4502.149228925786, Ion: None, sp_num: None
# Wavelength: 4503.226761672335, Ion: None, sp_num: None
# Wavelength: 4504.304294418884, Ion: None, sp_num: None
# Wavelength: 4505.381827165434, Ion: None, sp_num: None
# Wavelength: 4506.459359911983, Ion: None, sp_num: None
# Wavelength: 4507.5368926585315, Ion: None, sp_num: None
# Wavelength: 4508.614425405081, Ion: None, sp_num: None
# Wavelength: 4509.69195815163, Ion: None, sp_num: None
# Wavelength: 4510.769490898179, Ion: None, sp_num: None
# Wavelength: 4511.847023644729, Ion: None, sp_num: None
# Wavelength: 4512.924556391278, Ion: None, sp_num: None
# Wavelength: 4514.002089137828, Ion: None, sp_num: None
# Wavelength: 4515.079621884377, Ion: None, sp_num: None
# Wavelength: 4516.157154630926, Ion: None, sp_num: None
# Wavelength: 4517.234687377476, Ion: None, sp_num: None
# Wavelength: 4518.312220124025, Ion: None, sp_num: None
# Wavelength: 4519.389752870575, Ion: None, sp_num: None
# Wavelength: 4520.467285617124, Ion: None, sp_num: None
# Wavelength: 4521.544818363673, Ion: None, sp_num: None
# Wavelength: 4522.622351110223, Ion: None, sp_num: None
# Wavelength: 4523.6998838567715, Ion: None, sp_num: None
# Wavelength: 4524.7774166033205, Ion: None, sp_num: None
# Wavelength: 4525.85494934987, Ion: None, sp_num: None
# Wavelength: 4526.932482096419, Ion: None, sp_num: None
# Wavelength: 4528.010014842968, Ion: None, sp_num: None
# Wavelength: 4529.087547589518, Ion: None, sp_num: None
# Wavelength: 4530.165080336067, Ion: None, sp_num: None
# Wavelength: 4531.242613082617, Ion: None, sp_num: None
# Wavelength: 4532.320145829166, Ion: None, sp_num: None
# Wavelength: 4533.397678575715, Ion: None, sp_num: None
# Wavelength: 4534.475211322265, Ion: None, sp_num: None
# Wavelength: 4535.552744068814, Ion: None, sp_num: None
# Wavelength: 4536.630276815364, Ion: None, sp_num: None
# Wavelength: 4537.707809561913, Ion: None, sp_num: None
# Wavelength: 4538.785342308462, Ion: None, sp_num: None
# Wavelength: 4539.8628750550115, Ion: None, sp_num: None
# Wavelength: 4540.9404078015605, Ion: None, sp_num: None
# Wavelength: 4542.017940548109, Ion: None, sp_num: None
# Wavelength: 4543.095473294659, Ion: None, sp_num: None
# Wavelength: 4544.173006041208, Ion: None, sp_num: None
# Wavelength: 4545.250538787757, Ion: None, sp_num: None
# Wavelength: 4546.328071534307, Ion: None, sp_num: None
# Wavelength: 4547.405604280856, Ion: None, sp_num: None
# Wavelength: 4548.483137027406, Ion: None, sp_num: None
# Wavelength: 4549.560669773955, Ion: None, sp_num: None
# Wavelength: 4550.638202520504, Ion: None, sp_num: None
# Wavelength: 4551.715735267054, Ion: None, sp_num: None
# Wavelength: 4552.793268013603, Ion: None, sp_num: None
# Wavelength: 4553.870800760153, Ion: None, sp_num: None
# Wavelength: 4554.948333506702, Ion: None, sp_num: None
# Wavelength: 4556.025866253251, Ion: None, sp_num: None
# Wavelength: 4557.1033989998, Ion: None, sp_num: None
# Wavelength: 4558.180931746349, Ion: None, sp_num: None
# Wavelength: 4559.258464492898, Ion: None, sp_num: None
# Wavelength: 4560.335997239448, Ion: None, sp_num: None
# Wavelength: 4561.413529985997, Ion: None, sp_num: None
# Wavelength: 4562.491062732546, Ion: None, sp_num: None
# Wavelength: 4563.568595479096, Ion: None, sp_num: None
# Wavelength: 4564.646128225645, Ion: None, sp_num: None
# Wavelength: 4565.723660972195, Ion: None, sp_num: None
# Wavelength: 4566.801193718744, Ion: None, sp_num: None
# Wavelength: 4567.878726465293, Ion: None, sp_num: None
# Wavelength: 4568.956259211843, Ion: None, sp_num: None
# Wavelength: 4570.033791958392, Ion: None, sp_num: None
# Wavelength: 4571.111324704942, Ion: None, sp_num: None
# Wavelength: 4572.188857451491, Ion: None, sp_num: None
# Wavelength: 4573.2663901980395, Ion: None, sp_num: None
# Wavelength: 4574.343922944589, Ion: None, sp_num: None
# Wavelength: 4575.421455691138, Ion: None, sp_num: None
# Wavelength: 4576.498988437687, Ion: None, sp_num: None
# Wavelength: 4577.576521184237, Ion: None, sp_num: None
# Wavelength: 4578.654053930786, Ion: None, sp_num: None
# Wavelength: 4579.731586677335, Ion: None, sp_num: None
# Wavelength: 4580.809119423885, Ion: None, sp_num: None
# Wavelength: 4581.886652170434, Ion: None, sp_num: None
# Wavelength: 4582.964184916984, Ion: None, sp_num: None
# Wavelength: 4584.041717663533, Ion: None, sp_num: None
# Wavelength: 4585.119250410082, Ion: None, sp_num: None
# Wavelength: 4586.196783156632, Ion: None, sp_num: None
# Wavelength: 4587.274315903181, Ion: None, sp_num: None
# Wavelength: 4588.3518486497305, Ion: None, sp_num: None
# Wavelength: 4589.4293813962795, Ion: None, sp_num: None
# Wavelength: 4590.5069141428285, Ion: None, sp_num: None
# Wavelength: 4591.584446889378, Ion: None, sp_num: None
# Wavelength: 4592.661979635927, Ion: None, sp_num: None
# Wavelength: 4593.739512382476, Ion: None, sp_num: None
# Wavelength: 4594.817045129026, Ion: None, sp_num: None
# Wavelength: 4595.894577875575, Ion: None, sp_num: None
# Wavelength: 4596.972110622125, Ion: None, sp_num: None
# Wavelength: 4598.049643368674, Ion: None, sp_num: None
# Wavelength: 4599.127176115223, Ion: None, sp_num: None
# Wavelength: 4600.204708861773, Ion: None, sp_num: None
# Wavelength: 4601.282241608322, Ion: None, sp_num: None
# Wavelength: 4602.359774354871, Ion: None, sp_num: None
# Wavelength: 4603.437307101421, Ion: None, sp_num: None
# Wavelength: 4604.51483984797, Ion: None, sp_num: None
# Wavelength: 4605.5923725945195, Ion: None, sp_num: None
# Wavelength: 4606.669905341068, Ion: None, sp_num: None
# Wavelength: 4607.747438087617, Ion: None, sp_num: None
# Wavelength: 4608.824970834167, Ion: None, sp_num: None
# Wavelength: 4609.902503580716, Ion: None, sp_num: None
# Wavelength: 4610.980036327266, Ion: None, sp_num: None
# Wavelength: 4612.057569073815, Ion: None, sp_num: None
# Wavelength: 4613.135101820364, Ion: None, sp_num: None
# Wavelength: 4614.212634566914, Ion: None, sp_num: None
# Wavelength: 4615.290167313463, Ion: None, sp_num: None
# Wavelength: 4616.367700060012, Ion: None, sp_num: None
# Wavelength: 4617.445232806562, Ion: None, sp_num: None
# Wavelength: 4618.522765553111, Ion: None, sp_num: None
# Wavelength: 4619.60029829966, Ion: None, sp_num: None
# Wavelength: 4620.67783104621, Ion: None, sp_num: None
# Wavelength: 4621.7553637927585, Ion: None, sp_num: None
# Wavelength: 4622.832896539308, Ion: None, sp_num: None
# Wavelength: 4623.910429285857, Ion: None, sp_num: None
# Wavelength: 4624.987962032406, Ion: None, sp_num: None
# Wavelength: 4626.065494778956, Ion: None, sp_num: None
# Wavelength: 4627.143027525505, Ion: None, sp_num: None
# Wavelength: 4628.220560272055, Ion: None, sp_num: None
# Wavelength: 4629.298093018604, Ion: None, sp_num: None
# Wavelength: 4630.375625765153, Ion: None, sp_num: None
# Wavelength: 4631.453158511703, Ion: None, sp_num: None
# Wavelength: 4632.530691258252, Ion: None, sp_num: None
# Wavelength: 4633.608224004801, Ion: None, sp_num: None
# Wavelength: 4634.685756751351, Ion: None, sp_num: None
# Wavelength: 4635.7632894979, Ion: None, sp_num: None
# Wavelength: 4636.840822244449, Ion: None, sp_num: None
# Wavelength: 4637.9183549909985, Ion: None, sp_num: None
# Wavelength: 4638.9958877375475, Ion: None, sp_num: None
# Wavelength: 4640.073420484097, Ion: None, sp_num: None
# Wavelength: 4641.150953230646, Ion: None, sp_num: None
# Wavelength: 4642.228485977195, Ion: None, sp_num: None
# Wavelength: 4643.306018723745, Ion: None, sp_num: None
# Wavelength: 4644.383551470294, Ion: None, sp_num: None
# Wavelength: 4645.461084216844, Ion: None, sp_num: None
# Wavelength: 4646.538616963393, Ion: None, sp_num: None
# Wavelength: 4647.616149709942, Ion: None, sp_num: None
# Wavelength: 4648.693682456492, Ion: None, sp_num: None
# Wavelength: 4649.771215203041, Ion: None, sp_num: None
# Wavelength: 4650.84874794959, Ion: None, sp_num: None
# Wavelength: 4651.92628069614, Ion: None, sp_num: None
# Wavelength: 4653.003813442689, Ion: None, sp_num: None
# Wavelength: 4654.081346189238, Ion: None, sp_num: None
# Wavelength: 4655.1588789357875, Ion: None, sp_num: None
# Wavelength: 4656.236411682336, Ion: None, sp_num: None
# Wavelength: 4657.313944428886, Ion: None, sp_num: None
# Wavelength: 4658.391477175435, Ion: None, sp_num: None
# Wavelength: 4659.469009921984, Ion: None, sp_num: None
# Wavelength: 4660.546542668534, Ion: None, sp_num: None
# Wavelength: 4661.624075415083, Ion: None, sp_num: None
# Wavelength: 4662.701608161633, Ion: None, sp_num: None
# Wavelength: 4663.779140908182, Ion: None, sp_num: None
# Wavelength: 4664.856673654731, Ion: None, sp_num: None
# Wavelength: 4665.934206401281, Ion: None, sp_num: None
# Wavelength: 4667.01173914783, Ion: None, sp_num: None
# Wavelength: 4668.089271894379, Ion: None, sp_num: None
# Wavelength: 4669.166804640929, Ion: None, sp_num: None
# Wavelength: 4670.244337387478, Ion: None, sp_num: None
# Wavelength: 4671.3218701340265, Ion: None, sp_num: None
# Wavelength: 4672.399402880576, Ion: None, sp_num: None
# Wavelength: 4673.476935627125, Ion: None, sp_num: None
# Wavelength: 4674.554468373675, Ion: None, sp_num: None
# Wavelength: 4675.632001120224, Ion: None, sp_num: None
# Wavelength: 4676.709533866773, Ion: None, sp_num: None
# Wavelength: 4677.787066613323, Ion: None, sp_num: None
# Wavelength: 4678.864599359872, Ion: None, sp_num: None
# Wavelength: 4679.942132106422, Ion: None, sp_num: None
# Wavelength: 4681.019664852971, Ion: None, sp_num: None
# Wavelength: 4682.09719759952, Ion: None, sp_num: None
# Wavelength: 4683.17473034607, Ion: None, sp_num: None
# Wavelength: 4684.252263092619, Ion: None, sp_num: None
# Wavelength: 4685.329795839168, Ion: None, sp_num: None
# Wavelength: 4686.407328585718, Ion: None, sp_num: None
# Wavelength: 4687.4848613322665, Ion: None, sp_num: None
# Wavelength: 4688.5623940788155, Ion: None, sp_num: None
# Wavelength: 4689.639926825365, Ion: None, sp_num: None
# Wavelength: 4690.717459571914, Ion: None, sp_num: None
# Wavelength: 4691.794992318464, Ion: None, sp_num: None
# Wavelength: 4692.872525065013, Ion: None, sp_num: None
# Wavelength: 4693.950057811562, Ion: None, sp_num: None
# Wavelength: 4695.027590558112, Ion: None, sp_num: None
# Wavelength: 4696.105123304661, Ion: None, sp_num: None
# Wavelength: 4697.182656051211, Ion: None, sp_num: None
# Wavelength: 4698.26018879776, Ion: None, sp_num: None
# Wavelength: 4699.337721544309, Ion: None, sp_num: None
# Wavelength: 4700.415254290859, Ion: None, sp_num: None
# Wavelength: 4701.492787037408, Ion: None, sp_num: None
# Wavelength: 4702.570319783957, Ion: None, sp_num: None
# Wavelength: 4703.6478525305065, Ion: None, sp_num: None
# Wavelength: 4704.7253852770555, Ion: None, sp_num: None
# Wavelength: 4705.802918023604, Ion: None, sp_num: None
# Wavelength: 4706.880450770154, Ion: None, sp_num: None
# Wavelength: 4707.957983516703, Ion: None, sp_num: None
# Wavelength: 4709.035516263253, Ion: None, sp_num: None
# Wavelength: 4710.113049009802, Ion: None, sp_num: None
# Wavelength: 4711.190581756351, Ion: None, sp_num: None
# Wavelength: 4712.268114502901, Ion: None, sp_num: None
# Wavelength: 4713.34564724945, Ion: None, sp_num: None
# Wavelength: 4714.423179996, Ion: None, sp_num: None
# Wavelength: 4715.500712742549, Ion: None, sp_num: None
# Wavelength: 4716.578245489098, Ion: None, sp_num: None
# Wavelength: 4717.655778235648, Ion: None, sp_num: None
# Wavelength: 4718.733310982197, Ion: None, sp_num: None
# Wavelength: 4719.810843728746, Ion: None, sp_num: None
# Wavelength: 4720.888376475295, Ion: None, sp_num: None
# Wavelength: 4721.965909221844, Ion: None, sp_num: None
# Wavelength: 4723.043441968393, Ion: None, sp_num: None
# Wavelength: 4724.120974714943, Ion: None, sp_num: None
# Wavelength: 4725.198507461492, Ion: None, sp_num: None
# Wavelength: 4726.276040208042, Ion: None, sp_num: None
# Wavelength: 4727.353572954591, Ion: None, sp_num: None
# Wavelength: 4728.43110570114, Ion: None, sp_num: None
# Wavelength: 4729.50863844769, Ion: None, sp_num: None
# Wavelength: 4730.586171194239, Ion: None, sp_num: None
# Wavelength: 4731.663703940789, Ion: None, sp_num: None
# Wavelength: 4732.741236687338, Ion: None, sp_num: None
# Wavelength: 4733.818769433887, Ion: None, sp_num: None
# Wavelength: 4734.896302180437, Ion: None, sp_num: None
# Wavelength: 4735.973834926986, Ion: None, sp_num: None
# Wavelength: 4737.051367673535, Ion: None, sp_num: None
# Wavelength: 4738.128900420084, Ion: None, sp_num: None
# Wavelength: 4739.206433166633, Ion: None, sp_num: None
# Wavelength: 4740.283965913182, Ion: None, sp_num: None
# Wavelength: 4741.361498659732, Ion: None, sp_num: None
# Wavelength: 4742.439031406281, Ion: None, sp_num: None
# Wavelength: 4743.516564152831, Ion: None, sp_num: None
# Wavelength: 4744.59409689938, Ion: None, sp_num: None
# Wavelength: 4745.671629645929, Ion: None, sp_num: None
# Wavelength: 4746.749162392479, Ion: None, sp_num: None
# Wavelength: 4747.826695139028, Ion: None, sp_num: None
# Wavelength: 4748.904227885578, Ion: None, sp_num: None
# Wavelength: 4749.981760632127, Ion: None, sp_num: None
# Wavelength: 4751.059293378676, Ion: None, sp_num: None
# Wavelength: 4752.1368261252255, Ion: None, sp_num: None
# Wavelength: 4753.2143588717745, Ion: None, sp_num: None
# Wavelength: 4754.291891618324, Ion: None, sp_num: None
# Wavelength: 4755.369424364873, Ion: None, sp_num: None
# Wavelength: 4756.446957111422, Ion: None, sp_num: None
# Wavelength: 4757.524489857971, Ion: None, sp_num: None
# Wavelength: 4758.602022604521, Ion: None, sp_num: None
# Wavelength: 4759.67955535107, Ion: None, sp_num: None
# Wavelength: 4760.75708809762, Ion: None, sp_num: None
# Wavelength: 4761.834620844169, Ion: None, sp_num: None
# Wavelength: 4762.912153590718, Ion: None, sp_num: None
# Wavelength: 4763.989686337268, Ion: None, sp_num: None
# Wavelength: 4765.067219083817, Ion: None, sp_num: None
# Wavelength: 4766.144751830367, Ion: None, sp_num: None
# Wavelength: 4767.222284576916, Ion: None, sp_num: None
# Wavelength: 4768.299817323465, Ion: None, sp_num: None
# Wavelength: 4769.3773500700145, Ion: None, sp_num: None
# Wavelength: 4770.454882816563, Ion: None, sp_num: None
# Wavelength: 4771.532415563113, Ion: None, sp_num: None
# Wavelength: 4772.609948309662, Ion: None, sp_num: None
# Wavelength: 4773.687481056211, Ion: None, sp_num: None
# Wavelength: 4774.76501380276, Ion: None, sp_num: None
# Wavelength: 4775.84254654931, Ion: None, sp_num: None
# Wavelength: 4776.920079295859, Ion: None, sp_num: None
# Wavelength: 4777.997612042409, Ion: None, sp_num: None
# Wavelength: 4779.075144788958, Ion: None, sp_num: None
# Wavelength: 4780.152677535507, Ion: None, sp_num: None
# Wavelength: 4781.230210282057, Ion: None, sp_num: None
# Wavelength: 4782.307743028606, Ion: None, sp_num: None
# Wavelength: 4783.385275775156, Ion: None, sp_num: None
# Wavelength: 4784.462808521705, Ion: None, sp_num: None
# Wavelength: 4785.5403412682535, Ion: None, sp_num: None
# Wavelength: 4786.617874014803, Ion: None, sp_num: None
# Wavelength: 4787.695406761352, Ion: None, sp_num: None
# Wavelength: 4788.772939507902, Ion: None, sp_num: None
# Wavelength: 4789.850472254451, Ion: None, sp_num: None
# Wavelength: 4790.928005001, Ion: None, sp_num: None
# Wavelength: 4792.005537747549, Ion: None, sp_num: None
# Wavelength: 4793.083070494099, Ion: None, sp_num: None
# Wavelength: 4794.160603240648, Ion: None, sp_num: None
# Wavelength: 4795.238135987198, Ion: None, sp_num: None
# Wavelength: 4796.315668733747, Ion: None, sp_num: None
# Wavelength: 4797.393201480296, Ion: None, sp_num: None
# Wavelength: 4798.470734226846, Ion: None, sp_num: None
# Wavelength: 4799.548266973395, Ion: None, sp_num: None
# Wavelength: 4800.625799719945, Ion: None, sp_num: None
# Wavelength: 4801.7033324664935, Ion: None, sp_num: None
# Wavelength: 4802.7808652130425, Ion: None, sp_num: None
# Wavelength: 4803.858397959592, Ion: None, sp_num: None
# Wavelength: 4804.935930706141, Ion: None, sp_num: None
# Wavelength: 4806.013463452691, Ion: None, sp_num: None
# Wavelength: 4807.09099619924, Ion: None, sp_num: None
# Wavelength: 4808.168528945789, Ion: None, sp_num: None
# Wavelength: 4809.246061692339, Ion: None, sp_num: None
# Wavelength: 4810.323594438888, Ion: None, sp_num: None
# Wavelength: 4811.401127185438, Ion: Cr, sp_num: 1
# Wavelength: 4812.478659931987, Ion: Mo, sp_num: 1
# Wavelength: 4813.556192678536, Ion: Ti, sp_num: 1
# Wavelength: 4814.633725425085, Ion: None, sp_num: None
# Wavelength: 4815.711258171635, Ion: Fe, sp_num: 1
# Wavelength: 4816.788790918184, Ion: Th, sp_num: 2
# Wavelength: 4817.8663236647335, Ion: Ti, sp_num: 1
# Wavelength: 4818.9438564112825, Ion: Pd, sp_num: 1
# Wavelength: 4820.021389157831, Ion: Th, sp_num: 2
# Wavelength: 4821.098921904381, Ion: None, sp_num: None
# Wavelength: 4822.17645465093, Ion: None, sp_num: None
# Wavelength: 4823.25398739748, Ion: None, sp_num: None
# Wavelength: 4824.331520144029, Ion: None, sp_num: None
# Wavelength: 4825.409052890578, Ion: Th, sp_num: 2
# Wavelength: 4826.486585637128, Ion: None, sp_num: None
# Wavelength: 4827.564118383677, Ion: None, sp_num: None
# Wavelength: 4828.641651130227, Ion: None, sp_num: None
# Wavelength: 4829.719183876776, Ion: Th, sp_num: 2
# Wavelength: 4830.796716623325, Ion: Cr, sp_num: 1
# Wavelength: 4831.874249369874, Ion: Mo, sp_num: 1
# Wavelength: 4832.951782116424, Ion: Th, sp_num: 2
# Wavelength: 4834.029314862973, Ion: Fe, sp_num: 1
# Wavelength: 4835.106847609522, Ion: Dy, sp_num: 2
# Wavelength: 4836.184380356071, Ion: None, sp_num: None
# Wavelength: 4837.26191310262, Ion: Fe, sp_num: 1
# Wavelength: 4838.33944584917, Ion: Yb, sp_num: 2
# Wavelength: 4839.416978595719, Ion: Fe, sp_num: 1
# Wavelength: 4840.494511342269, Ion: Th, sp_num: 2
# Wavelength: 4841.572044088818, Ion: None, sp_num: None
# Wavelength: 4842.649576835367, Ion: Th, sp_num: 2
# Wavelength: 4843.727109581917, Ion: Cu, sp_num: 1
# Wavelength: 4844.804642328466, Ion: None, sp_num: None
# Wavelength: 4845.882175075016, Ion: Ru, sp_num: 1
# Wavelength: 4846.959707821565, Ion: Fe, sp_num: 1
# Wavelength: 4848.037240568114, Ion: V, sp_num: 1
# Wavelength: 4849.114773314663, Ion: Sm, sp_num: 2
# Wavelength: 4850.192306061213, Ion: V, sp_num: 1
# Wavelength: 4851.2698388077615, Ion: K, sp_num: 1
# Wavelength: 4852.347371554311, Ion: Cr, sp_num: 1
# Wavelength: 4853.42490430086, Ion: None, sp_num: None
# Wavelength: 4854.502437047409, Ion: None, sp_num: None
# Wavelength: 4855.579969793959, Ion: Y, sp_num: 1
# Wavelength: 4856.657502540508, Ion: V, sp_num: 1
# Wavelength: 4857.735035287058, Ion: None, sp_num: None
# Wavelength: 4858.812568033607, Ion: Ti, sp_num: 1
# Wavelength: 4859.890100780156, Ion: None, sp_num: None
# Wavelength: 4860.967633526706, Ion: None, sp_num: None
# Wavelength: 4862.045166273255, Ion: None, sp_num: None
# Wavelength: 4863.122699019805, Ion: Cr, sp_num: 1
# Wavelength: 4864.200231766354, Ion: None, sp_num: None
# Wavelength: 4865.277764512903, Ion: Cr, sp_num: 1
# Wavelength: 4866.355297259452, Ion: Gd, sp_num: 2
# Wavelength: 4867.4328300060015, Ion: Zr, sp_num: 1
# Wavelength: 4868.5103627525505, Ion: None, sp_num: None
# Wavelength: 4869.5878954991, Ion: Ti, sp_num: 1
# Wavelength: 4870.665428245649, Ion: None, sp_num: None
# Wavelength: 4871.742960992198, Ion: None, sp_num: None
# Wavelength: 4872.820493738748, Ion: None, sp_num: None
# Wavelength: 4873.898026485297, Ion: Sr, sp_num: 1
# Wavelength: 4874.975559231847, Ion: None, sp_num: None
# Wavelength: 4876.053091978396, Ion: Ti, sp_num: 1
# Wavelength: 4877.130624724945, Ion: None, sp_num: None
# Wavelength: 4878.208157471495, Ion: None, sp_num: None
# Wavelength: 4879.285690218044, Ion: None, sp_num: None
# Wavelength: 4880.363222964594, Ion: None, sp_num: None
# Wavelength: 4881.440755711143, Ion: Cr, sp_num: 1
# Wavelength: 4882.518288457692, Ion: Th, sp_num: 2
# Wavelength: 4883.595821204241, Ion: Fe, sp_num: 1
# Wavelength: 4884.67335395079, Ion: None, sp_num: None
# Wavelength: 4885.750886697339, Ion: None, sp_num: None
# Wavelength: 4886.828419443889, Ion: Na, sp_num: 2
# Wavelength: 4887.905952190438, Ion: Y, sp_num: 1
# Wavelength: 4888.983484936987, Ion: Cr, sp_num: 1
# Wavelength: 4890.061017683537, Ion: Fe, sp_num: 1
# Wavelength: 4891.138550430086, Ion: Ho, sp_num: 2
# Wavelength: 4892.216083176636, Ion: Fe, sp_num: 1
# Wavelength: 4893.293615923185, Ion: Ti, sp_num: 1
# Wavelength: 4894.371148669734, Ion: Ti, sp_num: 1
# Wavelength: 4895.448681416284, Ion: None, sp_num: None
# Wavelength: 4896.526214162833, Ion: None, sp_num: None
# Wavelength: 4897.603746909383, Ion: Th, sp_num: 2
# Wavelength: 4898.681279655932, Ion: None, sp_num: None
# Wavelength: 4899.7588124024805, Ion: V, sp_num: 1
# Wavelength: 4900.8363451490295, Ion: None, sp_num: None
# Wavelength: 4901.913877895579, Ion: Ti, sp_num: 1
# Wavelength: 4902.991410642128, Ion: None, sp_num: None
# Wavelength: 4904.068943388678, Ion: None, sp_num: None
# Wavelength: 4905.146476135227, Ion: Ti, sp_num: 1
# Wavelength: 4906.224008881776, Ion: None, sp_num: None
# Wavelength: 4907.301541628326, Ion: None, sp_num: None
# Wavelength: 4908.379074374875, Ion: Ho, sp_num: 2
# Wavelength: 4909.456607121425, Ion: Fe, sp_num: 1
# Wavelength: 4910.534139867974, Ion: Ti, sp_num: 1
# Wavelength: 4911.611672614523, Ion: Th, sp_num: 2
# Wavelength: 4912.689205361073, Ion: None, sp_num: None
# Wavelength: 4913.766738107622, Ion: None, sp_num: None
# Wavelength: 4914.844270854172, Ion: None, sp_num: None
# Wavelength: 4915.9218036007205, Ion: None, sp_num: None
# Wavelength: 4916.9993363472695, Ion: None, sp_num: None
# Wavelength: 4918.0768690938185, Ion: None, sp_num: None
# Wavelength: 4919.154401840368, Ion: Ti, sp_num: 1
# Wavelength: 4920.231934586917, Ion: Fe, sp_num: 1
# Wavelength: 4921.309467333467, Ion: Ti, sp_num: 1
# Wavelength: 4922.387000080016, Ion: Cr, sp_num: 1
# Wavelength: 4923.464532826565, Ion: None, sp_num: None
# Wavelength: 4924.542065573115, Ion: Dy, sp_num: 2
# Wavelength: 4925.619598319664, Ion: Fe, sp_num: 1
# Wavelength: 4926.697131066214, Ion: Fe, sp_num: 1
# Wavelength: 4927.774663812763, Ion: Y, sp_num: 1
# Wavelength: 4928.852196559312, Ion: Fe, sp_num: 1
# Wavelength: 4929.929729305862, Ion: None, sp_num: None
# Wavelength: 4931.007262052411, Ion: Th, sp_num: 2
# Wavelength: 4932.0847947989605, Ion: None, sp_num: None
# Wavelength: 4933.1623275455095, Ion: None, sp_num: None
# Wavelength: 4934.239860292058, Ion: None, sp_num: None
# Wavelength: 4935.317393038607, Ion: Th, sp_num: 2
# Wavelength: 4936.394925785157, Ion: V, sp_num: 1
# Wavelength: 4937.472458531706, Ion: None, sp_num: None
# Wavelength: 4938.549991278256, Ion: Yb, sp_num: 2
# Wavelength: 4939.627524024805, Ion: Fe, sp_num: 1
# Wavelength: 4940.705056771354, Ion: Fe, sp_num: 1
# Wavelength: 4941.782589517904, Ion: None, sp_num: None
# Wavelength: 4942.860122264453, Ion: Ti, sp_num: 1
# Wavelength: 4943.937655011003, Ion: Fe, sp_num: 1
# Wavelength: 4945.015187757552, Ion: None, sp_num: None
# Wavelength: 4946.092720504101, Ion: None, sp_num: None
# Wavelength: 4947.170253250651, Ion: Th, sp_num: 2
# Wavelength: 4948.2477859972, Ion: None, sp_num: None
# Wavelength: 4949.325318743749, Ion: Ti, sp_num: 1
# Wavelength: 4950.402851490298, Ion: None, sp_num: None
# Wavelength: 4951.480384236847, Ion: Y, sp_num: 1
# Wavelength: 4952.557916983397, Ion: None, sp_num: None
# Wavelength: 4953.635449729946, Ion: None, sp_num: None
# Wavelength: 4954.712982476496, Ion: None, sp_num: None
# Wavelength: 4955.790515223045, Ion: Th, sp_num: 2
# Wavelength: 4956.868047969594, Ion: None, sp_num: None
# Wavelength: 4957.945580716143, Ion: None, sp_num: None
# Wavelength: 4959.023113462693, Ion: Fe, sp_num: 1
# Wavelength: 4960.100646209242, Ion: Th, sp_num: 2
# Wavelength: 4961.178178955792, Ion: Th, sp_num: 2
# Wavelength: 4962.255711702341, Ion: None, sp_num: None
# Wavelength: 4963.33324444889, Ion: Fe, sp_num: 1
# Wavelength: 4964.41077719544, Ion: Th, sp_num: 2
# Wavelength: 4965.4883099419885, Ion: Th, sp_num: 2
# Wavelength: 4966.565842688538, Ion: None, sp_num: None
# Wavelength: 4967.643375435087, Ion: Fe, sp_num: 1
# Wavelength: 4968.720908181636, Ion: Ti, sp_num: 1
# Wavelength: 4969.798440928186, Ion: Th, sp_num: 2
# Wavelength: 4970.875973674735, Ion: None, sp_num: None
# Wavelength: 4971.953506421285, Ion: Fe, sp_num: 1
# Wavelength: 4973.031039167834, Ion: Sr, sp_num: 1
# Wavelength: 4974.108571914383, Ion: Th, sp_num: 2
# Wavelength: 4975.186104660932, Ion: Th, sp_num: 2
# Wavelength: 4976.263637407482, Ion: None, sp_num: None
# Wavelength: 4977.341170154031, Ion: Th, sp_num: 2
# Wavelength: 4978.418702900581, Ion: None, sp_num: None
# Wavelength: 4979.49623564713, Ion: Th, sp_num: 2
# Wavelength: 4980.573768393679, Ion: Mo, sp_num: 1
# Wavelength: 4981.6513011402285, Ion: Fe, sp_num: 1
# Wavelength: 4982.7288338867775, Ion: None, sp_num: None
# Wavelength: 4983.806366633327, Ion: Fe, sp_num: 1
# Wavelength: 4984.883899379876, Ion: Cr, sp_num: 1
# Wavelength: 4985.961432126425, Ion: V, sp_num: 1
# Wavelength: 4987.038964872975, Ion: None, sp_num: None
# Wavelength: 4988.116497619524, Ion: None, sp_num: None
# Wavelength: 4989.194030366074, Ion: None, sp_num: None
# Wavelength: 4990.271563112623, Ion: Fe, sp_num: 1
# Wavelength: 4991.349095859172, Ion: Nd, sp_num: 2
# Wavelength: 4992.426628605721, Ion: Th, sp_num: 2
# Wavelength: 4993.504161352271, Ion: None, sp_num: None
# Wavelength: 4994.58169409882, Ion: None, sp_num: None
# Wavelength: 4995.65922684537, Ion: None, sp_num: None
# Wavelength: 4996.736759591919, Ion: Fe, sp_num: 1
# Wavelength: 4997.814292338468, Ion: None, sp_num: None
# Wavelength: 4998.891825085017, Ion: None, sp_num: None
# Wavelength: 4999.969357831566, Ion: Cr, sp_num: 1
# Wavelength: 5001.046890578116, Ion: None, sp_num: None
# Wavelength: 5002.124423324665, Ion: None, sp_num: None
# Wavelength: 5003.201956071214, Ion: Fe, sp_num: 1
# Wavelength: 5004.279488817764, Ion: Fe, sp_num: 1
# Wavelength: 5005.357021564313, Ion: Fe, sp_num: 1
# Wavelength: 5006.434554310863, Ion: Cr, sp_num: 1
# Wavelength: 5007.512087057412, Ion: Si, sp_num: 1
# Wavelength: 5008.589619803961, Ion: Ti, sp_num: 1
# Wavelength: 5009.66715255051, Ion: Th, sp_num: 2
# Wavelength: 5010.74468529706, Ion: None, sp_num: None
# Wavelength: 5011.822218043609, Ion: None, sp_num: None
# Wavelength: 5012.899750790159, Ion: Zr, sp_num: 1
# Wavelength: 5013.977283536708, Ion: None, sp_num: None
# Wavelength: 5015.0548162832565, Ion: Th, sp_num: 2
# Wavelength: 5016.132349029806, Ion: None, sp_num: None
# Wavelength: 5017.209881776355, Ion: Th, sp_num: 2
# Wavelength: 5018.287414522905, Ion: None, sp_num: None
# Wavelength: 5019.364947269454, Ion: Tm, sp_num: 2
# Wavelength: 5020.442480016003, Ion: None, sp_num: None
# Wavelength: 5021.520012762553, Ion: Ti, sp_num: 1
# Wavelength: 5022.597545509102, Ion: None, sp_num: None
# Wavelength: 5023.675078255652, Ion: Fe, sp_num: 1
# Wavelength: 5024.752611002201, Ion: Ti, sp_num: 1
# Wavelength: 5025.83014374875, Ion: None, sp_num: None
# Wavelength: 5026.907676495299, Ion: Cr, sp_num: 1
# Wavelength: 5027.985209241849, Ion: None, sp_num: None
# Wavelength: 5029.062741988398, Ion: Fe, sp_num: 1
# Wavelength: 5030.1402747349475, Ion: None, sp_num: None
# Wavelength: 5031.2178074814965, Ion: None, sp_num: None
# Wavelength: 5032.2953402280455, Ion: None, sp_num: None
# Wavelength: 5033.372872974595, Ion: Fe, sp_num: 1
# Wavelength: 5034.450405721144, Ion: V, sp_num: 1
# Wavelength: 5035.527938467694, Ion: Tm, sp_num: 2
# Wavelength: 5036.605471214243, Ion: Th, sp_num: 2
# Wavelength: 5037.683003960792, Ion: None, sp_num: None
# Wavelength: 5038.760536707342, Ion: Th, sp_num: 2
# Wavelength: 5039.838069453891, Ion: Ti, sp_num: 1
# Wavelength: 5040.915602200441, Ion: None, sp_num: None
# Wavelength: 5041.99313494699, Ion: Th, sp_num: 2
# Wavelength: 5043.070667693539, Ion: Ca, sp_num: 1
# Wavelength: 5044.148200440088, Ion: None, sp_num: None
# Wavelength: 5045.225733186638, Ion: None, sp_num: None
# Wavelength: 5046.303265933187, Ion: None, sp_num: None
# Wavelength: 5047.3807986797365, Ion: None, sp_num: None
# Wavelength: 5048.458331426285, Ion: None, sp_num: None
# Wavelength: 5049.535864172834, Ion: La, sp_num: 2
# Wavelength: 5050.613396919384, Ion: None, sp_num: None
# Wavelength: 5051.690929665933, Ion: None, sp_num: None
# Wavelength: 5052.768462412483, Ion: Th, sp_num: 2
# Wavelength: 5053.845995159032, Ion: None, sp_num: None
# Wavelength: 5054.923527905581, Ion: None, sp_num: None
# Wavelength: 5056.001060652131, Ion: Fe, sp_num: 1
# Wavelength: 5057.07859339868, Ion: None, sp_num: None
# Wavelength: 5058.15612614523, Ion: Fe, sp_num: 1
# Wavelength: 5059.233658891779, Ion: Th, sp_num: 2
# Wavelength: 5060.311191638328, Ion: None, sp_num: None
# Wavelength: 5061.388724384877, Ion: Fe, sp_num: 1
# Wavelength: 5062.466257131427, Ion: None, sp_num: None
# Wavelength: 5063.5437898779755, Ion: Ti, sp_num: 1
# Wavelength: 5064.621322624525, Ion: Cr, sp_num: 1
# Wavelength: 5065.698855371074, Ion: Th, sp_num: 2
# Wavelength: 5066.776388117623, Ion: None, sp_num: None
# Wavelength: 5067.853920864173, Ion: None, sp_num: None
# Wavelength: 5068.931453610722, Ion: None, sp_num: None
# Wavelength: 5070.008986357272, Ion: Zn, sp_num: 1
# Wavelength: 5071.086519103821, Ion: None, sp_num: None
# Wavelength: 5072.16405185037, Ion: None, sp_num: None
# Wavelength: 5073.24158459692, Ion: Th, sp_num: 2
# Wavelength: 5074.319117343469, Ion: Cr, sp_num: 1
# Wavelength: 5075.396650090019, Ion: Fe, sp_num: 1
# Wavelength: 5076.474182836568, Ion: None, sp_num: None
# Wavelength: 5077.551715583117, Ion: Th, sp_num: 2
# Wavelength: 5078.629248329667, Ion: None, sp_num: None
# Wavelength: 5079.7067810762155, Ion: Zr, sp_num: 1
# Wavelength: 5080.784313822765, Ion: None, sp_num: None
# Wavelength: 5081.861846569314, Ion: Fe, sp_num: 1
# Wavelength: 5082.939379315863, Ion: None, sp_num: None
# Wavelength: 5084.016912062412, Ion: None, sp_num: None
# Wavelength: 5085.094444808962, Ion: None, sp_num: None
# Wavelength: 5086.171977555511, Ion: None, sp_num: None
# Wavelength: 5087.249510302061, Ion: Cd, sp_num: 1
# Wavelength: 5088.32704304861, Ion: V, sp_num: 1
# Wavelength: 5089.404575795159, Ion: None, sp_num: None
# Wavelength: 5090.482108541709, Ion: None, sp_num: None
# Wavelength: 5091.559641288258, Ion: None, sp_num: None
# Wavelength: 5092.637174034808, Ion: None, sp_num: None
# Wavelength: 5093.714706781357, Ion: Gd, sp_num: 2
# Wavelength: 5094.792239527906, Ion: Cr, sp_num: 1
# Wavelength: 5095.8697722744555, Ion: None, sp_num: None
# Wavelength: 5096.9473050210045, Ion: None, sp_num: None
# Wavelength: 5098.024837767554, Ion: Th, sp_num: 2
# Wavelength: 5099.102370514103, Ion: None, sp_num: None
# Wavelength: 5100.179903260652, Ion: Fe, sp_num: 1
# Wavelength: 5101.257436007201, Ion: None, sp_num: None
# Wavelength: 5102.334968753751, Ion: Gd, sp_num: 2
# Wavelength: 5103.4125015003, Ion: None, sp_num: None
# Wavelength: 5104.49003424685, Ion: Sm, sp_num: 2
# Wavelength: 5105.567566993399, Ion: Fe, sp_num: 1
# Wavelength: 5106.645099739948, Ion: V, sp_num: 1
# Wavelength: 5107.722632486498, Ion: Th, sp_num: 2
# Wavelength: 5108.800165233047, Ion: Fe, sp_num: 1
# Wavelength: 5109.877697979597, Ion: Fe, sp_num: 1
# Wavelength: 5110.955230726146, Ion: Na, sp_num: 1
# Wavelength: 5112.032763472695, Ion: None, sp_num: None
# Wavelength: 5113.110296219244, Ion: None, sp_num: None
# Wavelength: 5114.187828965793, Ion: None, sp_num: None
# Wavelength: 5115.265361712343, Ion: Ti, sp_num: 1
# Wavelength: 5116.342894458892, Ion: Mo, sp_num: 1
# Wavelength: 5117.420427205441, Ion: None, sp_num: None
# Wavelength: 5118.49795995199, Ion: Pd, sp_num: 1
# Wavelength: 5119.57549269854, Ion: None, sp_num: None
# Wavelength: 5120.653025445089, Ion: None, sp_num: None
# Wavelength: 5121.730558191639, Ion: None, sp_num: None
# Wavelength: 5122.808090938188, Ion: None, sp_num: None
# Wavelength: 5123.885623684737, Ion: Th, sp_num: 2
# Wavelength: 5124.963156431287, Ion: Cr, sp_num: 1
# Wavelength: 5126.040689177836, Ion: Fe, sp_num: 1
# Wavelength: 5127.118221924386, Ion: None, sp_num: None
# Wavelength: 5128.195754670935, Ion: None, sp_num: None
# Wavelength: 5129.2732874174835, Ion: None, sp_num: None
# Wavelength: 5130.350820164033, Ion: None, sp_num: None
# Wavelength: 5131.428352910582, Ion: None, sp_num: None
# Wavelength: 5132.505885657132, Ion: Th, sp_num: 2
# Wavelength: 5133.583418403681, Ion: Th, sp_num: 2
# Wavelength: 5134.66095115023, Ion: None, sp_num: None
# Wavelength: 5135.738483896779, Ion: None, sp_num: None
# Wavelength: 5136.816016643329, Ion: None, sp_num: None
# Wavelength: 5137.893549389878, Ion: Ru, sp_num: 1
# Wavelength: 5138.971082136428, Ion: V, sp_num: 1
# Wavelength: 5140.048614882977, Ion: Cr, sp_num: 1
# Wavelength: 5141.126147629526, Ion: Dy, sp_num: 2
# Wavelength: 5142.203680376076, Ion: Th, sp_num: 2
# Wavelength: 5143.281213122625, Ion: None, sp_num: None
# Wavelength: 5144.3587458691745, Ion: Fe, sp_num: 1
# Wavelength: 5145.4362786157235, Ion: None, sp_num: None
# Wavelength: 5146.5138113622725, Ion: Th, sp_num: 2
# Wavelength: 5147.591344108822, Ion: None, sp_num: None
# Wavelength: 5148.668876855371, Ion: Ru, sp_num: 1
# Wavelength: 5149.746409601921, Ion: Fe, sp_num: 1
# Wavelength: 5150.82394234847, Ion: Tm, sp_num: 2
# Wavelength: 5151.901475095019, Ion: None, sp_num: None
# Wavelength: 5152.979007841568, Ion: None, sp_num: None
# Wavelength: 5154.056540588118, Ion: Cs, sp_num: 1
# Wavelength: 5155.134073334667, Ion: Th, sp_num: 2
# Wavelength: 5156.211606081217, Ion: None, sp_num: None
# Wavelength: 5157.289138827766, Ion: Ni, sp_num: 1
# Wavelength: 5158.366671574315, Ion: V, sp_num: 1
# Wavelength: 5159.444204320865, Ion: Zr, sp_num: 1
# Wavelength: 5160.521737067414, Ion: Fe, sp_num: 1
# Wavelength: 5161.5992698139635, Ion: Sn, sp_num: 1
# Wavelength: 5162.676802560512, Ion: Fe, sp_num: 1
# Wavelength: 5163.754335307061, Ion: Fe, sp_num: 1
# Wavelength: 5164.831868053611, Ion: None, sp_num: None
# Wavelength: 5165.90940080016, Ion: Gd, sp_num: 2
# Wavelength: 5166.98693354671, Ion: Sr, sp_num: 1
# Wavelength: 5168.064466293259, Ion: None, sp_num: None
# Wavelength: 5169.141999039808, Ion: Fe, sp_num: 1
# Wavelength: 5170.219531786357, Ion: None, sp_num: None
# Wavelength: 5171.297064532907, Ion: V, sp_num: 1
# Wavelength: 5172.374597279456, Ion: Ru, sp_num: 1
# Wavelength: 5173.452130026006, Ion: V, sp_num: 1
# Wavelength: 5174.529662772555, Ion: Fe, sp_num: 1
# Wavelength: 5175.607195519104, Ion: Mo, sp_num: 1
# Wavelength: 5176.684728265654, Ion: None, sp_num: None
# Wavelength: 5177.7622610122025, Ion: Gd, sp_num: 2
# Wavelength: 5178.839793758752, Ion: Cr, sp_num: 1
# Wavelength: 5179.917326505301, Ion: V, sp_num: 1
# Wavelength: 5180.99485925185, Ion: None, sp_num: None
# Wavelength: 5182.0723919984, Ion: V, sp_num: 1
# Wavelength: 5183.149924744949, Ion: None, sp_num: None
# Wavelength: 5184.227457491499, Ion: V, sp_num: 1
# Wavelength: 5185.304990238048, Ion: Ti, sp_num: 1
# Wavelength: 5186.382522984597, Ion: None, sp_num: None
# Wavelength: 5187.460055731146, Ion: Th, sp_num: 2
# Wavelength: 5188.537588477696, Ion: Zr, sp_num: 1
# Wavelength: 5189.615121224245, Ion: La, sp_num: 2
# Wavelength: 5190.692653970795, Ion: None, sp_num: None
# Wavelength: 5191.770186717344, Ion: None, sp_num: None
# Wavelength: 5192.847719463893, Ion: Pr, sp_num: 2
# Wavelength: 5193.9252522104425, Ion: None, sp_num: None
# Wavelength: 5195.0027849569915, Ion: Cr, sp_num: 1
# Wavelength: 5196.080317703541, Ion: Cr, sp_num: 1
# Wavelength: 5197.15785045009, Ion: None, sp_num: None
# Wavelength: 5198.235383196639, Ion: Cs, sp_num: 1
# Wavelength: 5199.312915943189, Ion: Fe, sp_num: 1
# Wavelength: 5200.390448689738, Ion: None, sp_num: None
# Wavelength: 5201.467981436288, Ion: None, sp_num: None
# Wavelength: 5202.545514182837, Ion: Ti, sp_num: 1
# Wavelength: 5203.623046929386, Ion: Ru, sp_num: 1
# Wavelength: 5204.700579675935, Ion: Na, sp_num: 2
# Wavelength: 5205.778112422485, Ion: U, sp_num: 2
# Wavelength: 5206.855645169034, Ion: None, sp_num: None
# Wavelength: 5207.933177915584, Ion: Th, sp_num: 2
# Wavelength: 5209.010710662133, Ion: None, sp_num: None
# Wavelength: 5210.088243408682, Ion: Na, sp_num: 2
# Wavelength: 5211.1657761552315, Ion: None, sp_num: None
# Wavelength: 5212.24330890178, Ion: None, sp_num: None
# Wavelength: 5213.32084164833, Ion: Mo, sp_num: 1
# Wavelength: 5214.398374394879, Ion: Er, sp_num: 2
# Wavelength: 5215.475907141428, Ion: None, sp_num: None
# Wavelength: 5216.553439887978, Ion: Er, sp_num: 2
# Wavelength: 5217.630972634527, Ion: Cr, sp_num: 1
# Wavelength: 5218.708505381077, Ion: None, sp_num: None
# Wavelength: 5219.786038127626, Ion: Er, sp_num: 2
# Wavelength: 5220.863570874175, Ion: Mo, sp_num: 1
# Wavelength: 5221.941103620725, Ion: None, sp_num: None
# Wavelength: 5223.018636367274, Ion: None, sp_num: None
# Wavelength: 5224.096169113824, Ion: Cr, sp_num: 1
# Wavelength: 5225.173701860373, Ion: Ti, sp_num: 1
# Wavelength: 5226.251234606922, Ion: None, sp_num: None
# Wavelength: 5227.3287673534705, Ion: Cr, sp_num: 1
# Wavelength: 5228.40630010002, Ion: Fe, sp_num: 1
# Wavelength: 5229.483832846569, Ion: Cr, sp_num: 1
# Wavelength: 5230.561365593119, Ion: None, sp_num: None
# Wavelength: 5231.638898339668, Ion: Cr, sp_num: 1
# Wavelength: 5232.716431086217, Ion: None, sp_num: None
# Wavelength: 5233.793963832767, Ion: Mo, sp_num: 1
# Wavelength: 5234.871496579316, Ion: None, sp_num: None
# Wavelength: 5235.949029325866, Ion: None, sp_num: None
# Wavelength: 5237.026562072415, Ion: None, sp_num: None
# Wavelength: 5238.104094818964, Ion: Cr, sp_num: 1
# Wavelength: 5239.181627565514, Ion: Th, sp_num: 2
# Wavelength: 5240.259160312063, Ion: None, sp_num: None
# Wavelength: 5241.336693058613, Ion: Nd, sp_num: 2
# Wavelength: 5242.414225805162, Ion: V, sp_num: 1
# Wavelength: 5243.4917585517105, Ion: Th, sp_num: 2
# Wavelength: 5244.5692912982595, Ion: None, sp_num: None
# Wavelength: 5245.646824044809, Ion: Th, sp_num: 2
# Wavelength: 5246.724356791358, Ion: None, sp_num: None
# Wavelength: 5247.801889537908, Ion: Ti, sp_num: 1
# Wavelength: 5248.879422284457, Ion: None, sp_num: None
# Wavelength: 5249.956955031006, Ion: V, sp_num: 1
# Wavelength: 5251.034487777556, Ion: Nd, sp_num: 2
# Wavelength: 5252.112020524105, Ion: Fe, sp_num: 1
# Wavelength: 5253.189553270655, Ion: Ru, sp_num: 1
# Wavelength: 5254.267086017204, Ion: Th, sp_num: 2
# Wavelength: 5255.344618763753, Ion: Ba, sp_num: 1
# Wavelength: 5256.422151510303, Ion: Cr, sp_num: 1
# Wavelength: 5257.499684256852, Ion: Th, sp_num: 2
# Wavelength: 5258.5772170034015, Ion: Er, sp_num: 2
# Wavelength: 5259.6547497499505, Ion: V, sp_num: 1
# Wavelength: 5260.7322824964995, Ion: None, sp_num: None
# Wavelength: 5261.809815243048, Ion: V, sp_num: 1
# Wavelength: 5262.887347989598, Ion: None, sp_num: None
# Wavelength: 5263.964880736147, Ion: None, sp_num: None
# ...
# Wavelength: 3984.9335105821165, Ion: None, sp_num: None
# Wavelength: 3986.011043328666, Ion: None, sp_num: None
# Wavelength: 3987.0885760752153, Ion: None, sp_num: None
# Wavelength: 3988.1661088217643, Ion: None, sp_num: None
# Wavelength: 3989.2436415683137, Ion: None, sp_num: None
# Wavelength: 3990.321174314863, Ion: None, sp_num: None
# Wavelength: 3991.398707061412, Ion: None, sp_num: None
# Wavelength: 3992.4762398079615, Ion: None, sp_num: None
# Wavelength: 3993.553772554511, Ion: None, sp_num: None
# Wavelength: 3994.6313053010604, Ion: None, sp_num: None
# Wavelength: 3995.70883804761, Ion: None, sp_num: None
# Wavelength: 3996.7863707941588, Ion: None, sp_num: None
# Wavelength: 3997.863903540708, Ion: None, sp_num: None
# Wavelength: 3998.9414362872576, Ion: None, sp_num: None
# Wavelength: 4000.0189690338066, Ion: None, sp_num: None
# Wavelength: 4001.096501780356, Ion: None, sp_num: None
# Wavelength: 4002.1740345269054, Ion: None, sp_num: None
# Wavelength: 4003.251567273455, Ion: None, sp_num: None
# Wavelength: 4004.3291000200043, Ion: None, sp_num: None
# Wavelength: 4005.4066327665532, Ion: None, sp_num: None
# Wavelength: 4006.4841655131027, Ion: None, sp_num: None
# Wavelength: 4007.561698259652, Ion: None, sp_num: None
# Wavelength: 4008.639231006201, Ion: None, sp_num: None
# Wavelength: 4009.7167637527505, Ion: None, sp_num: None
# Wavelength: 4010.7942964993, Ion: None, sp_num: None
# Wavelength: 4011.8718292458493, Ion: None, sp_num: None
# Wavelength: 4012.9493619923987, Ion: None, sp_num: None
# Wavelength: 4014.0268947389477, Ion: None, sp_num: None
# Wavelength: 4015.104427485497, Ion: None, sp_num: None
# Wavelength: 4016.1819602320465, Ion: None, sp_num: None
# Wavelength: 4017.259492978596, Ion: None, sp_num: None
# Wavelength: 4018.337025725145, Ion: None, sp_num: None
# Wavelength: 4019.4145584716944, Ion: None, sp_num: None
# Wavelength: 4020.492091218244, Ion: None, sp_num: None
# Wavelength: 4021.569623964793, Ion: None, sp_num: None
# Wavelength: 4022.647156711342, Ion: None, sp_num: None
# Wavelength: 4023.7246894578916, Ion: None, sp_num: None
# Wavelength: 4024.802222204441, Ion: None, sp_num: None
# Wavelength: 4025.8797549509904, Ion: None, sp_num: None
# Wavelength: 4026.9572876975394, Ion: None, sp_num: None
# Wavelength: 4028.034820444089, Ion: None, sp_num: None
# Wavelength: 4029.1123531906383, Ion: None, sp_num: None
# Wavelength: 4030.1898859371877, Ion: None, sp_num: None
# Wavelength: 4031.2674186837367, Ion: None, sp_num: None
# Wavelength: 4032.344951430286, Ion: None, sp_num: None
# Wavelength: 4033.4224841768355, Ion: None, sp_num: None
# Wavelength: 4034.500016923385, Ion: None, sp_num: None
# Wavelength: 4035.577549669934, Ion: None, sp_num: None
# Wavelength: 4036.6550824164833, Ion: None, sp_num: None
# Wavelength: 4037.7326151630327, Ion: None, sp_num: None
# Wavelength: 4038.810147909582, Ion: None, sp_num: None
# Wavelength: 4039.887680656131, Ion: None, sp_num: None
# Wavelength: 4040.9652134026805, Ion: None, sp_num: None
# Wavelength: 4042.04274614923, Ion: None, sp_num: None
# Wavelength: 4043.1202788957794, Ion: None, sp_num: None
# Wavelength: 4044.1978116423284, Ion: None, sp_num: None
# Wavelength: 4045.275344388878, Ion: None, sp_num: None
# Wavelength: 4046.352877135427, Ion: None, sp_num: None
# Wavelength: 4047.4304098819766, Ion: None, sp_num: None
# Wavelength: 4048.5079426285256, Ion: None, sp_num: None
# Wavelength: 4049.585475375075, Ion: None, sp_num: None
# Wavelength: 4050.6630081216244, Ion: None, sp_num: None
# Wavelength: 4051.740540868174, Ion: None, sp_num: None
# Wavelength: 4052.818073614723, Ion: None, sp_num: None
# Wavelength: 4053.8956063612723, Ion: None, sp_num: None
# Wavelength: 4054.9731391078217, Ion: None, sp_num: None
# Wavelength: 4056.050671854371, Ion: None, sp_num: None
# Wavelength: 4057.12820460092, Ion: None, sp_num: None
# Wavelength: 4058.2057373474695, Ion: None, sp_num: None
# Wavelength: 4059.283270094019, Ion: None, sp_num: None
# Wavelength: 4060.3608028405683, Ion: None, sp_num: None
# Wavelength: 4061.4383355871173, Ion: None, sp_num: None
# Wavelength: 4062.5158683336667, Ion: None, sp_num: None
# Wavelength: 4063.593401080216, Ion: None, sp_num: None
# Wavelength: 4064.6709338267656, Ion: None, sp_num: None
# Wavelength: 4065.7484665733145, Ion: None, sp_num: None
# Wavelength: 4066.825999319864, Ion: None, sp_num: None
# Wavelength: 4067.9035320664134, Ion: None, sp_num: None
# Wavelength: 4068.981064812963, Ion: None, sp_num: None
# Wavelength: 4070.058597559512, Ion: None, sp_num: None
# Wavelength: 4071.136130306061, Ion: None, sp_num: None
# Wavelength: 4072.2136630526106, Ion: None, sp_num: None
# Wavelength: 4073.29119579916, Ion: None, sp_num: None
# Wavelength: 4074.368728545709, Ion: None, sp_num: None
# Wavelength: 4075.4462612922584, Ion: None, sp_num: None
# Wavelength: 4076.523794038808, Ion: None, sp_num: None
# Wavelength: 4077.6013267853573, Ion: None, sp_num: None
# Wavelength: 4078.6788595319067, Ion: None, sp_num: None
# Wavelength: 4079.7563922784557, Ion: None, sp_num: None
# Wavelength: 4080.833925025005, Ion: None, sp_num: None
# Wavelength: 4081.9114577715545, Ion: None, sp_num: None
# Wavelength: 4082.9889905181035, Ion: None, sp_num: None
# Wavelength: 4084.066523264653, Ion: None, sp_num: None
# Wavelength: 4085.1440560112023, Ion: None, sp_num: None
# Wavelength: 4086.2215887577518, Ion: None, sp_num: None
# Wavelength: 4087.299121504301, Ion: None, sp_num: None
# Wavelength: 4088.37665425085, Ion: None, sp_num: None
# Wavelength: 4089.4541869973996, Ion: None, sp_num: None
# Wavelength: 4090.531719743949, Ion: None, sp_num: None
# Wavelength: 4091.609252490498, Ion: None, sp_num: None
# Wavelength: 4092.6867852370474, Ion: None, sp_num: None
# Wavelength: 4093.764317983597, Ion: None, sp_num: None
# Wavelength: 4094.8418507301462, Ion: None, sp_num: None
# Wavelength: 4095.9193834766957, Ion: None, sp_num: None
# Wavelength: 4096.996916223245, Ion: None, sp_num: None
# Wavelength: 4098.074448969794, Ion: None, sp_num: None
# Wavelength: 4099.1519817163435, Ion: None, sp_num: None
# Wavelength: 4100.229514462892, Ion: None, sp_num: None
# Wavelength: 4101.307047209442, Ion: None, sp_num: None
# Wavelength: 4102.384579955991, Ion: None, sp_num: None
# Wavelength: 4103.46211270254, Ion: None, sp_num: None
# Wavelength: 4104.53964544909, Ion: None, sp_num: None
# Wavelength: 4105.617178195639, Ion: None, sp_num: None
# Wavelength: 4106.694710942189, Ion: None, sp_num: None
# Wavelength: 4107.772243688738, Ion: None, sp_num: None
# Wavelength: 4108.849776435287, Ion: None, sp_num: None
# Wavelength: 4109.927309181837, Ion: None, sp_num: None
# Wavelength: 4111.004841928386, Ion: None, sp_num: None
# Wavelength: 4112.082374674935, Ion: None, sp_num: None
# Wavelength: 4113.159907421485, Ion: None, sp_num: None
# Wavelength: 4114.237440168034, Ion: None, sp_num: None
# Wavelength: 4115.3149729145825, Ion: None, sp_num: None
# Wavelength: 4116.392505661132, Ion: None, sp_num: None
# Wavelength: 4117.470038407681, Ion: None, sp_num: None
# Wavelength: 4118.547571154231, Ion: None, sp_num: None
# Wavelength: 4119.62510390078, Ion: None, sp_num: None
# Wavelength: 4120.702636647329, Ion: None, sp_num: None
# Wavelength: 4121.780169393879, Ion: None, sp_num: None
# Wavelength: 4122.857702140428, Ion: None, sp_num: None
# Wavelength: 4123.935234886978, Ion: None, sp_num: None
# Wavelength: 4125.012767633527, Ion: None, sp_num: None
# Wavelength: 4126.090300380076, Ion: None, sp_num: None
# Wavelength: 4127.167833126626, Ion: None, sp_num: None
# Wavelength: 4128.245365873175, Ion: None, sp_num: None
# Wavelength: 4129.322898619724, Ion: None, sp_num: None
# Wavelength: 4130.400431366274, Ion: None, sp_num: None
# Wavelength: 4131.4779641128225, Ion: None, sp_num: None
# Wavelength: 4132.5554968593715, Ion: None, sp_num: None
# Wavelength: 4133.633029605921, Ion: None, sp_num: None
# Wavelength: 4134.71056235247, Ion: None, sp_num: None
# Wavelength: 4135.78809509902, Ion: None, sp_num: None
# Wavelength: 4136.865627845569, Ion: None, sp_num: None
# Wavelength: 4137.943160592118, Ion: None, sp_num: None
# Wavelength: 4139.020693338668, Ion: None, sp_num: None
# Wavelength: 4140.098226085217, Ion: None, sp_num: None
# Wavelength: 4141.175758831767, Ion: None, sp_num: None
# Wavelength: 4142.253291578316, Ion: None, sp_num: None
# Wavelength: 4143.330824324865, Ion: None, sp_num: None
# Wavelength: 4144.408357071415, Ion: None, sp_num: None
# Wavelength: 4145.485889817964, Ion: None, sp_num: None
# Wavelength: 4146.563422564513, Ion: None, sp_num: None
# Wavelength: 4147.6409553110625, Ion: None, sp_num: None
# Wavelength: 4148.7184880576115, Ion: None, sp_num: None
# Wavelength: 4149.796020804161, Ion: None, sp_num: None
# Wavelength: 4150.87355355071, Ion: None, sp_num: None
# Wavelength: 4151.951086297259, Ion: None, sp_num: None
# Wavelength: 4153.028619043809, Ion: None, sp_num: None
# Wavelength: 4154.106151790358, Ion: None, sp_num: None
# Wavelength: 4155.183684536907, Ion: None, sp_num: None
# Wavelength: 4156.261217283457, Ion: None, sp_num: None
# Wavelength: 4157.338750030006, Ion: None, sp_num: None
# Wavelength: 4158.416282776556, Ion: None, sp_num: None
# Wavelength: 4159.493815523105, Ion: None, sp_num: None
# Wavelength: 4160.571348269654, Ion: None, sp_num: None
# Wavelength: 4161.648881016204, Ion: None, sp_num: None
# Wavelength: 4162.726413762753, Ion: None, sp_num: None
# Wavelength: 4163.803946509302, Ion: None, sp_num: None
# Wavelength: 4164.881479255851, Ion: None, sp_num: None
# Wavelength: 4165.9590120024, Ion: None, sp_num: None
# Wavelength: 4167.03654474895, Ion: None, sp_num: None
# Wavelength: 4168.114077495499, Ion: None, sp_num: None
# Wavelength: 4169.191610242048, Ion: None, sp_num: None
# Wavelength: 4170.269142988598, Ion: None, sp_num: None
# Wavelength: 4171.346675735147, Ion: None, sp_num: None
# Wavelength: 4172.424208481696, Ion: None, sp_num: None
# Wavelength: 4173.501741228246, Ion: None, sp_num: None
# Wavelength: 4174.579273974795, Ion: None, sp_num: None
# Wavelength: 4175.656806721345, Ion: None, sp_num: None
# Wavelength: 4176.734339467894, Ion: None, sp_num: None
# Wavelength: 4177.811872214443, Ion: None, sp_num: None
# Wavelength: 4178.889404960993, Ion: None, sp_num: None
# Wavelength: 4179.966937707542, Ion: None, sp_num: None
# Wavelength: 4181.0444704540905, Ion: None, sp_num: None
# Wavelength: 4182.12200320064, Ion: None, sp_num: None
# Wavelength: 4183.199535947189, Ion: None, sp_num: None
# Wavelength: 4184.277068693739, Ion: None, sp_num: None
# Wavelength: 4185.354601440288, Ion: None, sp_num: None
# Wavelength: 4186.432134186837, Ion: None, sp_num: None
# Wavelength: 4187.509666933387, Ion: None, sp_num: None
# Wavelength: 4188.587199679936, Ion: None, sp_num: None
# Wavelength: 4189.664732426485, Ion: None, sp_num: None
# Wavelength: 4190.742265173035, Ion: None, sp_num: None
# Wavelength: 4191.819797919584, Ion: None, sp_num: None
# Wavelength: 4192.897330666134, Ion: None, sp_num: None
# Wavelength: 4193.974863412683, Ion: None, sp_num: None
# Wavelength: 4195.052396159232, Ion: None, sp_num: None
# Wavelength: 4196.1299289057815, Ion: None, sp_num: None
# Wavelength: 4197.2074616523305, Ion: None, sp_num: None
# Wavelength: 4198.2849943988795, Ion: None, sp_num: None
# Wavelength: 4199.362527145429, Ion: None, sp_num: None
# Wavelength: 4200.440059891978, Ion: None, sp_num: None
# Wavelength: 4201.517592638528, Ion: None, sp_num: None
# Wavelength: 4202.595125385077, Ion: None, sp_num: None
# Wavelength: 4203.672658131626, Ion: None, sp_num: None
# Wavelength: 4204.750190878176, Ion: None, sp_num: None
# Wavelength: 4205.827723624725, Ion: None, sp_num: None
# Wavelength: 4206.905256371274, Ion: None, sp_num: None
# Wavelength: 4207.982789117824, Ion: Cr, sp_num: 1
# Wavelength: 4209.060321864373, Ion: Mo, sp_num: 1
# Wavelength: 4210.137854610923, Ion: Ti, sp_num: 1
# Wavelength: 4211.215387357472, Ion: None, sp_num: None
# Wavelength: 4212.292920104021, Ion: Fe, sp_num: 1
# Wavelength: 4213.3704528505705, Ion: Th, sp_num: 2
# Wavelength: 4214.447985597119, Ion: Ti, sp_num: 1
# Wavelength: 4215.525518343669, Ion: Pd, sp_num: 1
# Wavelength: 4216.603051090218, Ion: Th, sp_num: 2
# Wavelength: 4217.680583836767, Ion: None, sp_num: None
# Wavelength: 4218.758116583317, Ion: None, sp_num: None
# Wavelength: 4219.835649329866, Ion: None, sp_num: None
# Wavelength: 4220.913182076415, Ion: None, sp_num: None
# Wavelength: 4221.990714822965, Ion: Th, sp_num: 2
# Wavelength: 4223.068247569514, Ion: None, sp_num: None
# Wavelength: 4224.145780316063, Ion: None, sp_num: None
# Wavelength: 4225.223313062613, Ion: None, sp_num: None
# Wavelength: 4226.300845809162, Ion: Th, sp_num: 2
# Wavelength: 4227.378378555712, Ion: Cr, sp_num: 1
# Wavelength: 4228.455911302261, Ion: Mo, sp_num: 1
# Wavelength: 4234.921107781556, Ion: Th, sp_num: 2
# Wavelength: 4235.998640528106, Ion: Fe, sp_num: 1
# Wavelength: 4239.231238767754, Ion: Dy, sp_num: 2
# Wavelength: 4240.308771514303, Ion: None, sp_num: None
# Wavelength: 4244.618902500501, Ion: Fe, sp_num: 1
# Wavelength: 4246.7739679935985, Ion: Yb, sp_num: 2
# Wavelength: 4247.851500740148, Ion: Fe, sp_num: 1
# Wavelength: 4248.929033486697, Ion: Th, sp_num: 2
# Wavelength: 4250.006566233247, Ion: None, sp_num: None
# Wavelength: 4255.394229965993, Ion: Th, sp_num: 2
# Wavelength: 4257.549295459092, Ion: Cu, sp_num: 1
# Wavelength: 4260.78189369874, Ion: None, sp_num: None
# Wavelength: 4261.8594264452895, Ion: Ru, sp_num: 1
# Wavelength: 4262.9369591918385, Ion: Fe, sp_num: 1
# Wavelength: 4266.169557431486, Ion: V, sp_num: 1
# Wavelength: 4267.247090178036, Ion: Sm, sp_num: 2
# Wavelength: 4270.479688417684, Ion: V, sp_num: 1
# Wavelength: 4271.557221164233, Ion: K, sp_num: 1
# Wavelength: 4272.634753910782, Ion: Cr, sp_num: 1
# Wavelength: 4273.712286657332, Ion: None, sp_num: None
# Wavelength: 4274.789819403881, Ion: None, sp_num: None
# Wavelength: 4276.94488489698, Ion: Y, sp_num: 1
# Wavelength: 4278.022417643529, Ion: V, sp_num: 1
# Wavelength: 4279.099950390078, Ion: None, sp_num: None
# Wavelength: 4280.177483136627, Ion: Ti, sp_num: 1
# Wavelength: 4281.255015883176, Ion: None, sp_num: None
# Wavelength: 4283.410081376275, Ion: None, sp_num: None
# Wavelength: 4286.642679615923, Ion: None, sp_num: None
# Wavelength: 4288.797745109022, Ion: Cr, sp_num: 1
# Wavelength: 4290.952810602121, Ion: None, sp_num: None
# Wavelength: 4292.03034334867, Ion: Cr, sp_num: 1
# Wavelength: 4293.107876095219, Ion: Gd, sp_num: 2
# Wavelength: 4294.185408841769, Ion: Zr, sp_num: 1
# Wavelength: 4295.2629415883175, Ion: None, sp_num: None
# Wavelength: 4296.340474334867, Ion: Ti, sp_num: 1
# Wavelength: 4297.418007081416, Ion: None, sp_num: None
# Wavelength: 4298.495539827965, Ion: None, sp_num: None
# Wavelength: 4300.650605321064, Ion: None, sp_num: None
# Wavelength: 4301.728138067614, Ion: Sr, sp_num: 1
# Wavelength: 4302.805670814163, Ion: None, sp_num: None
# Wavelength: 4303.883203560712, Ion: Ti, sp_num: 1
# Wavelength: 4304.960736307262, Ion: None, sp_num: None
# Wavelength: 4306.038269053811, Ion: None, sp_num: None
# Wavelength: 4307.11580180036, Ion: None, sp_num: None
# Wavelength: 4308.19333454691, Ion: None, sp_num: None
# Wavelength: 4309.270867293459, Ion: Cr, sp_num: 1
# Wavelength: 4311.4259327865575, Ion: Th, sp_num: 2
# Wavelength: 4312.5034655331065, Ion: Fe, sp_num: 1
# Wavelength: 4313.580998279656, Ion: None, sp_num: None
# Wavelength: 4314.658531026205, Ion: None, sp_num: None
# Wavelength: 4315.736063772754, Ion: Na, sp_num: 2
# Wavelength: 4316.813596519304, Ion: Y, sp_num: 1
# Wavelength: 4317.891129265853, Ion: Cr, sp_num: 1
# Wavelength: 4320.046194758952, Ion: Fe, sp_num: 1
# Wavelength: 4321.123727505501, Ion: Ho, sp_num: 2
# Wavelength: 4334.054120464093, Ion: Fe, sp_num: 1
# Wavelength: 4337.286718703741, Ion: Ti, sp_num: 1
# Wavelength: 4339.44178419684, Ion: Ti, sp_num: 1
# Wavelength: 4340.519316943389, Ion: None, sp_num: None
# Wavelength: 4341.596849689939, Ion: None, sp_num: None
# Wavelength: 4342.674382436488, Ion: Th, sp_num: 2
# Wavelength: 4343.7519151830365, Ion: None, sp_num: None
# Wavelength: 4350.217111662332, Ion: V, sp_num: 1
# Wavelength: 4362.069971874375, Ion: None, sp_num: None
# Wavelength: 4363.147504620924, Ion: Ti, sp_num: 1
# Wavelength: 4367.457635607121, Ion: None, sp_num: None
# Wavelength: 4368.535168353671, Ion: None, sp_num: None

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

def identify_significant_lines(ratio_values, threshold_values, significance_factor):
    significant_absorption_lines = []
    significant_emission_lines = []
    for i in range(len(ratio_values)):
        if ratio_values[i] < 1 and ratio_values[i] < threshold_values[i]:
            significant_absorption_lines.append(i)
        elif ratio_values[i] > 1 and ratio_values[i] >  threshold_values[i]:
            significant_emission_lines.append(i)
    return significant_absorption_lines, significant_emission_lines

def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, significance_factor=1, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate the ratio of transit to non-transit flux
    ratio = np.zeros_like(flux_transit_interpolated)  # Initialize ratio array

    # Avoid division by zero
    non_zero_indices = flux_non_transit_interpolated != 0
    ratio[non_zero_indices] = flux_transit_interpolated[non_zero_indices] / flux_non_transit_interpolated[non_zero_indices]

    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold(ratio, window_size, significance_factor)

    # Identify significant absorption and emission lines
    significant_absorption_lines, significant_emission_lines = identify_significant_lines(ratio, threshold, significance_factor)

    return significant_absorption_lines, significant_emission_lines, ratio


'''
def adaptive_threshold(ratio_values, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        threshold[i] = max(0, min(1, significance_factor * local_std))

    return threshold
'''
def adaptive_threshold(ratio_values, window_size, significance_factor=1):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        snr = np.abs(ratio_values[i]) / local_std if local_std != 0 else 0  # Calculate SNR
        threshold[i] = significance_factor * snr

    return threshold

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)  # Replace with your specified alignment region

# Identify absorption and emission lines for the blue arm using specified alignment region
absorption_lines_blue, emission_lines_blue, ratio_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Print the identified lines for the blue arm
print("Absorption Lines (Blue Arm):", common_range_blue[absorption_lines_blue])
print("Emission Lines (Blue Arm):", common_range_blue[emission_lines_blue])
# Out:
# Absorption Lines (Blue Arm): [4229.53344405 4230.6109768  4231.68850954 ... 9067.65547606 9068.7330088
#  9069.81054155]
# Emission Lines (Blue Arm): []

# %%
def identify_significant_lines(ratio_values, threshold_values, significance_factor):
    significant_absorption_lines = []
    significant_emission_lines = []
    for i in range(len(ratio_values)):
        if ratio_values[i] < 1 and ratio_values[i] <  threshold_values[i]:
            significant_absorption_lines.append(i)
        elif ratio_values[i] > 1 and ratio_values[i] >  threshold_values[i]:
            significant_emission_lines.append(i)
    return significant_absorption_lines, significant_emission_lines

def plot_significant_lines(wavelengths, values, significant_lines, color, marker, label):
    plt.scatter(wavelengths[significant_lines], values[significant_lines], color=color, marker=marker, label=label)

def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, significance_factor=1, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate the ratio of transit to non-transit flux
    ratio = np.zeros_like(flux_transit_interpolated)  # Initialize ratio array

    # Avoid division by zero
    non_zero_indices = flux_non_transit_interpolated != 0
    ratio[non_zero_indices] = flux_transit_interpolated[non_zero_indices] / flux_non_transit_interpolated[non_zero_indices]

    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold(ratio, window_size, significance_factor)

    # Identify significant absorption and emission lines
    significant_absorption_lines, significant_emission_lines = identify_significant_lines(ratio, threshold, significance_factor)

    return significant_absorption_lines, significant_emission_lines, ratio, threshold
'''
def adaptive_threshold(ratio_values, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        threshold[i] = max(0, min(1, significance_factor * local_std))

    return threshold
'''
def adaptive_threshold(ratio_values, window_size, significance_factor=1):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        snr = np.abs(ratio_values[i]) / local_std if local_std != 0 else 0  # Calculate SNR
        threshold[i] = significance_factor * snr

    return threshold

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)  # Replace with your specified alignment region

# Identify significant absorption and emission lines for the blue arm using specified alignment region
significant_absorption_lines_blue, significant_emission_lines_blue, ratio_blue, threshold_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Plot the ratio spectrum and identified significant lines
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(common_range_blue, ratio_blue, label='Ratio Spectrum', color='gray', linestyle='dashed')

# Plot significant absorption lines
plot_significant_lines(common_range_blue, ratio_blue, significant_absorption_lines_blue, 'blue', 'v', 'Absorption Lines')

# Plot significant emission lines
plot_significant_lines(common_range_blue, ratio_blue, significant_emission_lines_blue, 'green', '^', 'Emission Lines')

# Plot the adaptive threshold
# plt.plot(common_range_blue, threshold_blue, label='Threshold', color='red', linestyle='dotted')

ax.set_xlabel('Corrected Wavelength(Angstrom)', fontweight='bold', fontsize=20)
ax.set_ylabel('Flux Ratio (Transit / Non-Transit Flux)', fontweight='bold', fontsize=20)
ax.legend(loc='upper right')  # Adjust legend position
ax.set_title('Ratio Spectrum and Identified Significant Lines in Common Range', fontweight='bold', fontsize=20)

# Create inset manually for zoomed-in part
ax_inset = ax.inset_axes([0.6, 0.6, 0.3, 0.3])
ax_inset.plot(common_range_blue, ratio_blue)
ax_inset.set_xlim(6750, 7000)  # Set x-range for the inset axes
ax_inset.set_ylim(0.5, 1.00)
ax.indicate_inset_zoom(ax_inset,edgecolor='red', lw =7)
ax_inset.set_title('Zoomed-in Ratio Spectrum')
# Set tick labels to bold
plt.tick_params(axis='both', which='major', labelsize=14, width=2, length=6, labelcolor='black', pad=6, direction='inout', bottom=True, top=True, left=True, right=True, grid_color='grey', grid_alpha=0.5, grid_linestyle='--', labelrotation=45, colors='black', grid_linewidth=1.5)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

def load_csv(file_path):
    df = pd.read_csv(file_path)
    # Drop rows with NaN values in the 'obs_wl_air(A)' column
    df.dropna(subset=['obs_wl_air(A)'], inplace=True)
    return df

def identify_significant_lines(ratio_values, threshold_values, significance_factor=1):
    significant_absorption_lines = []
    significant_emission_lines = []
    for i in range(len(ratio_values)):
        if ratio_values[i] < 1 and ratio_values[i] <  threshold_values[i]:
            significant_absorption_lines.append(i)
        elif ratio_values[i] > 1 and ratio_values[i] >  threshold_values[i]:
            significant_emission_lines.append(i)
    return significant_absorption_lines, significant_emission_lines

def identify_lines_in_common_range(transit_wavelength, transit_flux, non_transit_wavelength, non_transit_flux,
                                   common_range, significance_factor=1, window_size=10):
    # Ensure common_range is not empty
    if len(common_range) == 0:
        print("No common wavelength range found.")
        return np.array([]), np.array([]), np.array([])

    # Interpolate flux values for one spectrum onto the wavelength grid of the other
    f_transit = interp1d(transit_wavelength, transit_flux, kind='linear', fill_value="extrapolate")
    f_non_transit = interp1d(non_transit_wavelength, non_transit_flux, kind='linear', fill_value="extrapolate")

    # Evaluate interpolated flux values at the common wavelength range
    flux_transit_interpolated = f_transit(common_range)
    flux_non_transit_interpolated = f_non_transit(common_range)

    # Calculate the ratio of transit to non-transit flux
    ratio = np.zeros_like(flux_transit_interpolated)  # Initialize ratio array

    # Avoid division by zero
    non_zero_indices = flux_non_transit_interpolated != 0
    ratio[non_zero_indices] = flux_transit_interpolated[non_zero_indices] / flux_non_transit_interpolated[non_zero_indices]

    # Calculate adaptive threshold for each data point using rolling window
    threshold = adaptive_threshold(ratio, window_size, significance_factor)

    # Identify significant absorption and emission lines
    significant_absorption_lines, significant_emission_lines = identify_significant_lines(ratio, threshold, significance_factor)

    return significant_absorption_lines, significant_emission_lines, ratio, threshold
'''
def adaptive_threshold(ratio_values, window_size, significance_factor=3):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        threshold[i] = max(0, min(1, significance_factor * local_std))

    return threshold
'''

def adaptive_threshold(ratio_values, window_size, significance_factor=1):
    half_window = window_size // 2
    threshold = np.zeros_like(ratio_values)

    for i in range(len(ratio_values)):
        start_idx = max(0, i - half_window)
        end_idx = min(len(ratio_values), i + half_window + 1)
        local_std = np.std(ratio_values[start_idx:end_idx])
        snr = np.abs(ratio_values[i]) / local_std if local_std != 0 else 0  # Calculate SNR
        threshold[i] = significance_factor * snr

    return threshold

#cross check function
def cross_check_wavelengths_with_csv(wavelengths, df, tolerance=0.1):
    # Initialize lists to store results
    ions = []
    sp_nums = []

    # Iterate over each wavelength
    for wavelength in wavelengths:
        # Find the closest wavelength in the CSV data within the specified tolerance
        closest_matches = df[df['obs_wl_air(A)'].between(wavelength - tolerance, wavelength + tolerance)]

        # Extract corresponding ion and sp_num from the CSV data
        if not closest_matches.empty:
            ion = closest_matches['element'].values[0]
            sp_num = closest_matches['sp_num'].values[0]

            # Append results to lists
            ions.append(ion)
            sp_nums.append(sp_num)
        else:
            # Append placeholders if no match is found
            ions.append(None)
            sp_nums.append(None)

    return ions, sp_nums


def print_results(wavelengths, ions, sp_nums, arm_name):
    print(f"Cross-checked {len(wavelengths)} Lines ({arm_name} Arm):")
    
    min_length = min(len(wavelengths), len(ions), len(sp_nums))
    
    for i in range(min_length):
        print(f"Wavelength: {wavelengths[i]}, Ion: {ions[i]}, sp_num: {sp_nums[i]}")

# Load your CSV data
df = load_csv('lines.csv')

# Blue arm alignment region
common_range_blue = np.linspace(3698.3098, 9084.896, 5000)
absorption_lines_blue, emission_lines_blue, ratio_blue, threshold_blue = identify_lines_in_common_range(
    corrected_wavelength_blue_transit, normalized_blue,
    corrected_wavelength_blue_non_transit, normalized_non_transit_blue,
    common_range_blue
)

# Cross-check absorption and emission lines for the Blue Arm
ions_blue, sp_nums_blue = cross_check_wavelengths_with_csv([common_range_blue[i] for i in absorption_lines_blue], df)
print_results([common_range_blue[i] for i in absorption_lines_blue], ions_blue, sp_nums_blue, "Blue Absorption")
ions_blue, sp_nums_blue = cross_check_wavelengths_with_csv([common_range_blue[i] for i in emission_lines_blue], df)
print_results([common_range_blue[i] for i in emission_lines_blue], ions_blue, sp_nums_blue, "Blue Emission")  # Corrected line
# Out:
# Cross-checked 4426 Lines (Blue Absorption Arm):
# Wavelength: 4229.5334440488095, Ion: None, sp_num: None
# Wavelength: 4230.610976795359, Ion: None, sp_num: None
# Wavelength: 4231.688509541908, Ion: None, sp_num: None
# Wavelength: 4232.766042288458, Ion: None, sp_num: None
# Wavelength: 4233.843575035007, Ion: None, sp_num: None
# Wavelength: 4237.076173274655, Ion: None, sp_num: None
# Wavelength: 4238.153706021204, Ion: None, sp_num: None
# Wavelength: 4241.386304260852, Ion: None, sp_num: None
# Wavelength: 4242.463837007402, Ion: None, sp_num: None
# Wavelength: 4243.541369753951, Ion: None, sp_num: None
# Wavelength: 4245.6964352470495, Ion: None, sp_num: None
# Wavelength: 4251.084098979796, Ion: None, sp_num: None
# Wavelength: 4252.161631726345, Ion: None, sp_num: None
# Wavelength: 4253.239164472895, Ion: None, sp_num: None
# Wavelength: 4254.316697219444, Ion: None, sp_num: None
# Wavelength: 4256.471762712543, Ion: None, sp_num: None
# Wavelength: 4258.626828205641, Ion: None, sp_num: None
# Wavelength: 4259.704360952191, Ion: None, sp_num: None
# Wavelength: 4264.014491938387, Ion: None, sp_num: None
# Wavelength: 4265.092024684937, Ion: None, sp_num: None
# Wavelength: 4268.324622924585, Ion: None, sp_num: None
# Wavelength: 4269.402155671134, Ion: None, sp_num: None
# Wavelength: 4275.86735215043, Ion: None, sp_num: None
# Wavelength: 4282.332548629726, Ion: None, sp_num: None
# Wavelength: 4284.487614122825, Ion: None, sp_num: None
# Wavelength: 4285.565146869374, Ion: None, sp_num: None
# Wavelength: 4287.720212362473, Ion: None, sp_num: None
# Wavelength: 4289.875277855571, Ion: None, sp_num: None
# Wavelength: 4299.573072574515, Ion: None, sp_num: None
# Wavelength: 4310.348400040008, Ion: None, sp_num: None
# Wavelength: 4318.968662012403, Ion: None, sp_num: None
# Wavelength: 4322.201260252051, Ion: None, sp_num: None
# Wavelength: 4323.2787929986, Ion: None, sp_num: None
# Wavelength: 4324.35632574515, Ion: None, sp_num: None
# Wavelength: 4325.433858491699, Ion: None, sp_num: None
# Wavelength: 4326.511391238248, Ion: None, sp_num: None
# Wavelength: 4327.5889239847975, Ion: None, sp_num: None
# Wavelength: 4328.666456731346, Ion: None, sp_num: None
# Wavelength: 4329.743989477895, Ion: None, sp_num: None
# Wavelength: 4330.821522224445, Ion: None, sp_num: None
# Wavelength: 4331.899054970994, Ion: None, sp_num: None
# Wavelength: 4332.976587717543, Ion: None, sp_num: None
# Wavelength: 4335.131653210642, Ion: None, sp_num: None
# Wavelength: 4336.209185957192, Ion: None, sp_num: None
# Wavelength: 4338.36425145029, Ion: None, sp_num: None
# Wavelength: 4344.829447929586, Ion: None, sp_num: None
# Wavelength: 4345.906980676135, Ion: None, sp_num: None
# Wavelength: 4346.984513422684, Ion: None, sp_num: None
# Wavelength: 4348.062046169234, Ion: None, sp_num: None
# Wavelength: 4349.139578915783, Ion: None, sp_num: None
# Wavelength: 4351.294644408882, Ion: None, sp_num: None
# Wavelength: 4352.372177155431, Ion: None, sp_num: None
# Wavelength: 4353.449709901981, Ion: None, sp_num: None
# Wavelength: 4354.52724264853, Ion: None, sp_num: None
# Wavelength: 4355.604775395079, Ion: None, sp_num: None
# Wavelength: 4356.682308141629, Ion: None, sp_num: None
# Wavelength: 4357.759840888178, Ion: None, sp_num: None
# Wavelength: 4358.837373634728, Ion: None, sp_num: None
# Wavelength: 4359.9149063812765, Ion: None, sp_num: None
# Wavelength: 4360.9924391278255, Ion: None, sp_num: None
# Wavelength: 4364.225037367473, Ion: None, sp_num: None
# Wavelength: 4365.302570114023, Ion: None, sp_num: None
# Wavelength: 4366.380102860572, Ion: None, sp_num: None
# Wavelength: 4369.61270110022, Ion: None, sp_num: None
# Wavelength: 4370.69023384677, Ion: None, sp_num: None
# Wavelength: 4371.767766593319, Ion: None, sp_num: None
# Wavelength: 4372.845299339868, Ion: None, sp_num: None
# Wavelength: 4373.922832086418, Ion: None, sp_num: None
# Wavelength: 4375.000364832967, Ion: None, sp_num: None
# Wavelength: 4376.0778975795165, Ion: None, sp_num: None
# Wavelength: 4377.1554303260655, Ion: None, sp_num: None
# Wavelength: 4378.232963072614, Ion: None, sp_num: None
# Wavelength: 4379.310495819164, Ion: None, sp_num: None
# Wavelength: 4380.388028565713, Ion: None, sp_num: None
# Wavelength: 4381.465561312262, Ion: None, sp_num: None
# Wavelength: 4382.543094058812, Ion: None, sp_num: None
# Wavelength: 4383.620626805361, Ion: None, sp_num: None
# Wavelength: 4384.69815955191, Ion: None, sp_num: None
# Wavelength: 4385.77569229846, Ion: None, sp_num: None
# Wavelength: 4386.853225045009, Ion: None, sp_num: None
# Wavelength: 4387.930757791559, Ion: None, sp_num: None
# Wavelength: 4389.008290538108, Ion: None, sp_num: None
# Wavelength: 4390.085823284657, Ion: None, sp_num: None
# Wavelength: 4391.163356031207, Ion: None, sp_num: None
# Wavelength: 4392.240888777756, Ion: None, sp_num: None
# Wavelength: 4393.318421524305, Ion: None, sp_num: None
# Wavelength: 4394.395954270854, Ion: None, sp_num: None
# Wavelength: 4395.473487017403, Ion: None, sp_num: None
# Wavelength: 4396.551019763953, Ion: None, sp_num: None
# Wavelength: 4397.628552510502, Ion: None, sp_num: None
# Wavelength: 4398.706085257051, Ion: None, sp_num: None
# Wavelength: 4399.783618003601, Ion: None, sp_num: None
# Wavelength: 4400.86115075015, Ion: None, sp_num: None
# Wavelength: 4401.938683496699, Ion: None, sp_num: None
# Wavelength: 4403.016216243249, Ion: None, sp_num: None
# Wavelength: 4404.093748989798, Ion: None, sp_num: None
# Wavelength: 4405.171281736348, Ion: None, sp_num: None
# Wavelength: 4406.248814482897, Ion: None, sp_num: None
# Wavelength: 4407.326347229446, Ion: None, sp_num: None
# Wavelength: 4408.403879975996, Ion: None, sp_num: None
# Wavelength: 4409.4814127225445, Ion: None, sp_num: None
# Wavelength: 4410.558945469094, Ion: None, sp_num: None
# Wavelength: 4411.636478215643, Ion: None, sp_num: None
# Wavelength: 4412.714010962192, Ion: None, sp_num: None
# Wavelength: 4413.791543708742, Ion: None, sp_num: None
# Wavelength: 4414.869076455291, Ion: None, sp_num: None
# Wavelength: 4415.94660920184, Ion: None, sp_num: None
# Wavelength: 4417.02414194839, Ion: None, sp_num: None
# Wavelength: 4418.101674694939, Ion: None, sp_num: None
# Wavelength: 4419.179207441488, Ion: None, sp_num: None
# Wavelength: 4420.256740188038, Ion: None, sp_num: None
# Wavelength: 4421.334272934587, Ion: None, sp_num: None
# Wavelength: 4422.411805681137, Ion: None, sp_num: None
# Wavelength: 4423.489338427686, Ion: None, sp_num: None
# Wavelength: 4424.566871174235, Ion: None, sp_num: None
# Wavelength: 4425.6444039207845, Ion: None, sp_num: None
# Wavelength: 4426.7219366673335, Ion: None, sp_num: None
# Wavelength: 4427.799469413883, Ion: None, sp_num: None
# Wavelength: 4428.877002160432, Ion: None, sp_num: None
# Wavelength: 4429.954534906981, Ion: None, sp_num: None
# Wavelength: 4431.032067653531, Ion: None, sp_num: None
# Wavelength: 4432.10960040008, Ion: None, sp_num: None
# Wavelength: 4433.187133146629, Ion: None, sp_num: None
# Wavelength: 4434.264665893179, Ion: None, sp_num: None
# Wavelength: 4435.342198639728, Ion: None, sp_num: None
# Wavelength: 4436.419731386277, Ion: None, sp_num: None
# Wavelength: 4437.497264132827, Ion: None, sp_num: None
# Wavelength: 4438.574796879376, Ion: None, sp_num: None
# Wavelength: 4439.652329625926, Ion: None, sp_num: None
# Wavelength: 4440.729862372475, Ion: None, sp_num: None
# Wavelength: 4441.807395119024, Ion: None, sp_num: None
# Wavelength: 4442.884927865573, Ion: None, sp_num: None
# Wavelength: 4443.962460612122, Ion: None, sp_num: None
# Wavelength: 4445.039993358672, Ion: None, sp_num: None
# Wavelength: 4446.117526105221, Ion: None, sp_num: None
# Wavelength: 4447.19505885177, Ion: None, sp_num: None
# Wavelength: 4448.27259159832, Ion: None, sp_num: None
# Wavelength: 4449.350124344869, Ion: None, sp_num: None
# Wavelength: 4450.427657091418, Ion: None, sp_num: None
# Wavelength: 4451.505189837968, Ion: None, sp_num: None
# Wavelength: 4452.582722584517, Ion: None, sp_num: None
# Wavelength: 4453.660255331066, Ion: None, sp_num: None
# Wavelength: 4454.737788077616, Ion: None, sp_num: None
# Wavelength: 4455.815320824165, Ion: None, sp_num: None
# Wavelength: 4456.892853570715, Ion: None, sp_num: None
# Wavelength: 4457.970386317264, Ion: None, sp_num: None
# Wavelength: 4459.0479190638125, Ion: None, sp_num: None
# Wavelength: 4460.125451810362, Ion: None, sp_num: None
# Wavelength: 4461.202984556911, Ion: None, sp_num: None
# Wavelength: 4462.280517303461, Ion: None, sp_num: None
# Wavelength: 4463.35805005001, Ion: None, sp_num: None
# Wavelength: 4464.435582796559, Ion: None, sp_num: None
# Wavelength: 4465.513115543109, Ion: None, sp_num: None
# Wavelength: 4466.590648289658, Ion: None, sp_num: None
# Wavelength: 4467.668181036208, Ion: None, sp_num: None
# Wavelength: 4468.745713782757, Ion: None, sp_num: None
# Wavelength: 4469.823246529306, Ion: None, sp_num: None
# Wavelength: 4470.900779275856, Ion: None, sp_num: None
# Wavelength: 4471.978312022405, Ion: None, sp_num: None
# Wavelength: 4473.055844768954, Ion: None, sp_num: None
# Wavelength: 4474.1333775155035, Ion: None, sp_num: None
# Wavelength: 4475.2109102620525, Ion: None, sp_num: None
# Wavelength: 4476.2884430086015, Ion: None, sp_num: None
# Wavelength: 4477.365975755151, Ion: None, sp_num: None
# Wavelength: 4478.4435085017, Ion: None, sp_num: None
# Wavelength: 4479.52104124825, Ion: None, sp_num: None
# Wavelength: 4480.598573994799, Ion: None, sp_num: None
# Wavelength: 4481.676106741348, Ion: None, sp_num: None
# Wavelength: 4482.753639487898, Ion: None, sp_num: None
# Wavelength: 4483.831172234447, Ion: None, sp_num: None
# Wavelength: 4484.908704980997, Ion: None, sp_num: None
# Wavelength: 4485.986237727546, Ion: None, sp_num: None
# Wavelength: 4487.063770474095, Ion: None, sp_num: None
# Wavelength: 4488.141303220645, Ion: None, sp_num: None
# Wavelength: 4489.218835967194, Ion: None, sp_num: None
# Wavelength: 4490.296368713743, Ion: None, sp_num: None
# Wavelength: 4491.3739014602925, Ion: None, sp_num: None
# Wavelength: 4492.451434206841, Ion: None, sp_num: None
# Wavelength: 4493.52896695339, Ion: None, sp_num: None
# Wavelength: 4494.60649969994, Ion: None, sp_num: None
# Wavelength: 4495.684032446489, Ion: None, sp_num: None
# Wavelength: 4496.761565193039, Ion: None, sp_num: None
# Wavelength: 4497.839097939588, Ion: None, sp_num: None
# Wavelength: 4498.916630686137, Ion: None, sp_num: None
# Wavelength: 4499.994163432687, Ion: None, sp_num: None
# Wavelength: 4501.071696179236, Ion: None, sp_num: None
# Wavelength: 4502.149228925786, Ion: None, sp_num: None
# Wavelength: 4503.226761672335, Ion: None, sp_num: None
# Wavelength: 4504.304294418884, Ion: None, sp_num: None
# Wavelength: 4505.381827165434, Ion: None, sp_num: None
# Wavelength: 4506.459359911983, Ion: None, sp_num: None
# Wavelength: 4507.5368926585315, Ion: None, sp_num: None
# Wavelength: 4508.614425405081, Ion: None, sp_num: None
# Wavelength: 4509.69195815163, Ion: None, sp_num: None
# Wavelength: 4510.769490898179, Ion: None, sp_num: None
# Wavelength: 4511.847023644729, Ion: None, sp_num: None
# Wavelength: 4512.924556391278, Ion: None, sp_num: None
# Wavelength: 4514.002089137828, Ion: None, sp_num: None
# Wavelength: 4515.079621884377, Ion: None, sp_num: None
# Wavelength: 4516.157154630926, Ion: None, sp_num: None
# Wavelength: 4517.234687377476, Ion: None, sp_num: None
# Wavelength: 4518.312220124025, Ion: None, sp_num: None
# Wavelength: 4519.389752870575, Ion: None, sp_num: None
# Wavelength: 4520.467285617124, Ion: None, sp_num: None
# Wavelength: 4521.544818363673, Ion: None, sp_num: None
# Wavelength: 4522.622351110223, Ion: None, sp_num: None
# Wavelength: 4523.6998838567715, Ion: None, sp_num: None
# Wavelength: 4524.7774166033205, Ion: None, sp_num: None
# Wavelength: 4525.85494934987, Ion: None, sp_num: None
# Wavelength: 4526.932482096419, Ion: None, sp_num: None
# Wavelength: 4528.010014842968, Ion: None, sp_num: None
# Wavelength: 4529.087547589518, Ion: None, sp_num: None
# Wavelength: 4530.165080336067, Ion: None, sp_num: None
# Wavelength: 4531.242613082617, Ion: None, sp_num: None
# Wavelength: 4532.320145829166, Ion: None, sp_num: None
# Wavelength: 4533.397678575715, Ion: None, sp_num: None
# Wavelength: 4534.475211322265, Ion: None, sp_num: None
# Wavelength: 4535.552744068814, Ion: None, sp_num: None
# Wavelength: 4536.630276815364, Ion: None, sp_num: None
# Wavelength: 4537.707809561913, Ion: None, sp_num: None
# Wavelength: 4538.785342308462, Ion: None, sp_num: None
# Wavelength: 4539.8628750550115, Ion: None, sp_num: None
# Wavelength: 4540.9404078015605, Ion: None, sp_num: None
# Wavelength: 4542.017940548109, Ion: None, sp_num: None
# Wavelength: 4543.095473294659, Ion: None, sp_num: None
# Wavelength: 4544.173006041208, Ion: None, sp_num: None
# Wavelength: 4545.250538787757, Ion: None, sp_num: None
# Wavelength: 4546.328071534307, Ion: None, sp_num: None
# Wavelength: 4547.405604280856, Ion: None, sp_num: None
# Wavelength: 4548.483137027406, Ion: None, sp_num: None
# Wavelength: 4549.560669773955, Ion: None, sp_num: None
# Wavelength: 4550.638202520504, Ion: None, sp_num: None
# Wavelength: 4551.715735267054, Ion: None, sp_num: None
# Wavelength: 4552.793268013603, Ion: None, sp_num: None
# Wavelength: 4553.870800760153, Ion: None, sp_num: None
# Wavelength: 4554.948333506702, Ion: None, sp_num: None
# Wavelength: 4556.025866253251, Ion: None, sp_num: None
# Wavelength: 4557.1033989998, Ion: None, sp_num: None
# Wavelength: 4558.180931746349, Ion: None, sp_num: None
# Wavelength: 4559.258464492898, Ion: None, sp_num: None
# Wavelength: 4560.335997239448, Ion: None, sp_num: None
# Wavelength: 4561.413529985997, Ion: None, sp_num: None
# Wavelength: 4562.491062732546, Ion: None, sp_num: None
# Wavelength: 4563.568595479096, Ion: None, sp_num: None
# Wavelength: 4564.646128225645, Ion: None, sp_num: None
# Wavelength: 4565.723660972195, Ion: None, sp_num: None
# Wavelength: 4566.801193718744, Ion: None, sp_num: None
# Wavelength: 4567.878726465293, Ion: None, sp_num: None
# Wavelength: 4568.956259211843, Ion: None, sp_num: None
# Wavelength: 4570.033791958392, Ion: None, sp_num: None
# Wavelength: 4571.111324704942, Ion: None, sp_num: None
# Wavelength: 4572.188857451491, Ion: None, sp_num: None
# Wavelength: 4573.2663901980395, Ion: None, sp_num: None
# Wavelength: 4574.343922944589, Ion: None, sp_num: None
# Wavelength: 4575.421455691138, Ion: None, sp_num: None
# Wavelength: 4576.498988437687, Ion: None, sp_num: None
# Wavelength: 4577.576521184237, Ion: None, sp_num: None
# Wavelength: 4578.654053930786, Ion: None, sp_num: None
# Wavelength: 4579.731586677335, Ion: None, sp_num: None
# Wavelength: 4580.809119423885, Ion: None, sp_num: None
# Wavelength: 4581.886652170434, Ion: None, sp_num: None
# Wavelength: 4582.964184916984, Ion: None, sp_num: None
# Wavelength: 4584.041717663533, Ion: None, sp_num: None
# Wavelength: 4585.119250410082, Ion: None, sp_num: None
# Wavelength: 4586.196783156632, Ion: None, sp_num: None
# Wavelength: 4587.274315903181, Ion: None, sp_num: None
# Wavelength: 4588.3518486497305, Ion: None, sp_num: None
# Wavelength: 4589.4293813962795, Ion: None, sp_num: None
# Wavelength: 4590.5069141428285, Ion: None, sp_num: None
# Wavelength: 4591.584446889378, Ion: None, sp_num: None
# Wavelength: 4592.661979635927, Ion: None, sp_num: None
# Wavelength: 4593.739512382476, Ion: None, sp_num: None
# Wavelength: 4594.817045129026, Ion: None, sp_num: None
# Wavelength: 4595.894577875575, Ion: None, sp_num: None
# Wavelength: 4596.972110622125, Ion: None, sp_num: None
# Wavelength: 4598.049643368674, Ion: None, sp_num: None
# Wavelength: 4599.127176115223, Ion: None, sp_num: None
# Wavelength: 4600.204708861773, Ion: None, sp_num: None
# Wavelength: 4601.282241608322, Ion: None, sp_num: None
# Wavelength: 4602.359774354871, Ion: None, sp_num: None
# Wavelength: 4603.437307101421, Ion: None, sp_num: None
# Wavelength: 4604.51483984797, Ion: None, sp_num: None
# Wavelength: 4605.5923725945195, Ion: None, sp_num: None
# Wavelength: 4606.669905341068, Ion: None, sp_num: None
# Wavelength: 4607.747438087617, Ion: None, sp_num: None
# Wavelength: 4608.824970834167, Ion: None, sp_num: None
# Wavelength: 4609.902503580716, Ion: None, sp_num: None
# Wavelength: 4610.980036327266, Ion: None, sp_num: None
# Wavelength: 4612.057569073815, Ion: None, sp_num: None
# Wavelength: 4613.135101820364, Ion: None, sp_num: None
# Wavelength: 4614.212634566914, Ion: None, sp_num: None
# Wavelength: 4615.290167313463, Ion: None, sp_num: None
# Wavelength: 4616.367700060012, Ion: None, sp_num: None
# Wavelength: 4617.445232806562, Ion: None, sp_num: None
# Wavelength: 4618.522765553111, Ion: None, sp_num: None
# Wavelength: 4619.60029829966, Ion: None, sp_num: None
# Wavelength: 4620.67783104621, Ion: None, sp_num: None
# Wavelength: 4621.7553637927585, Ion: None, sp_num: None
# Wavelength: 4622.832896539308, Ion: None, sp_num: None
# Wavelength: 4623.910429285857, Ion: None, sp_num: None
# Wavelength: 4624.987962032406, Ion: None, sp_num: None
# Wavelength: 4626.065494778956, Ion: None, sp_num: None
# Wavelength: 4627.143027525505, Ion: None, sp_num: None
# Wavelength: 4628.220560272055, Ion: None, sp_num: None
# Wavelength: 4629.298093018604, Ion: None, sp_num: None
# Wavelength: 4630.375625765153, Ion: None, sp_num: None
# Wavelength: 4631.453158511703, Ion: None, sp_num: None
# Wavelength: 4632.530691258252, Ion: None, sp_num: None
# Wavelength: 4633.608224004801, Ion: None, sp_num: None
# Wavelength: 4634.685756751351, Ion: None, sp_num: None
# Wavelength: 4635.7632894979, Ion: None, sp_num: None
# Wavelength: 4636.840822244449, Ion: None, sp_num: None
# Wavelength: 4637.9183549909985, Ion: None, sp_num: None
# Wavelength: 4638.9958877375475, Ion: None, sp_num: None
# Wavelength: 4640.073420484097, Ion: None, sp_num: None
# Wavelength: 4641.150953230646, Ion: None, sp_num: None
# Wavelength: 4642.228485977195, Ion: None, sp_num: None
# Wavelength: 4643.306018723745, Ion: None, sp_num: None
# Wavelength: 4644.383551470294, Ion: None, sp_num: None
# Wavelength: 4645.461084216844, Ion: None, sp_num: None
# Wavelength: 4646.538616963393, Ion: None, sp_num: None
# Wavelength: 4647.616149709942, Ion: None, sp_num: None
# Wavelength: 4648.693682456492, Ion: None, sp_num: None
# Wavelength: 4649.771215203041, Ion: None, sp_num: None
# Wavelength: 4650.84874794959, Ion: None, sp_num: None
# Wavelength: 4651.92628069614, Ion: None, sp_num: None
# Wavelength: 4653.003813442689, Ion: None, sp_num: None
# Wavelength: 4654.081346189238, Ion: None, sp_num: None
# Wavelength: 4655.1588789357875, Ion: None, sp_num: None
# Wavelength: 4656.236411682336, Ion: None, sp_num: None
# Wavelength: 4657.313944428886, Ion: None, sp_num: None
# Wavelength: 4658.391477175435, Ion: None, sp_num: None
# Wavelength: 4659.469009921984, Ion: None, sp_num: None
# Wavelength: 4660.546542668534, Ion: None, sp_num: None
# Wavelength: 4661.624075415083, Ion: None, sp_num: None
# Wavelength: 4662.701608161633, Ion: None, sp_num: None
# Wavelength: 4663.779140908182, Ion: None, sp_num: None
# Wavelength: 4664.856673654731, Ion: None, sp_num: None
# Wavelength: 4665.934206401281, Ion: None, sp_num: None
# Wavelength: 4667.01173914783, Ion: None, sp_num: None
# Wavelength: 4668.089271894379, Ion: None, sp_num: None
# Wavelength: 4669.166804640929, Ion: None, sp_num: None
# Wavelength: 4670.244337387478, Ion: None, sp_num: None
# Wavelength: 4671.3218701340265, Ion: None, sp_num: None
# Wavelength: 4672.399402880576, Ion: None, sp_num: None
# Wavelength: 4673.476935627125, Ion: None, sp_num: None
# Wavelength: 4674.554468373675, Ion: None, sp_num: None
# Wavelength: 4675.632001120224, Ion: None, sp_num: None
# Wavelength: 4676.709533866773, Ion: None, sp_num: None
# Wavelength: 4677.787066613323, Ion: None, sp_num: None
# Wavelength: 4678.864599359872, Ion: None, sp_num: None
# Wavelength: 4679.942132106422, Ion: None, sp_num: None
# Wavelength: 4681.019664852971, Ion: None, sp_num: None
# Wavelength: 4682.09719759952, Ion: None, sp_num: None
# Wavelength: 4683.17473034607, Ion: None, sp_num: None
# Wavelength: 4684.252263092619, Ion: None, sp_num: None
# Wavelength: 4685.329795839168, Ion: None, sp_num: None
# Wavelength: 4686.407328585718, Ion: None, sp_num: None
# Wavelength: 4687.4848613322665, Ion: None, sp_num: None
# Wavelength: 4688.5623940788155, Ion: None, sp_num: None
# Wavelength: 4689.639926825365, Ion: None, sp_num: None
# Wavelength: 4690.717459571914, Ion: None, sp_num: None
# Wavelength: 4691.794992318464, Ion: None, sp_num: None
# Wavelength: 4692.872525065013, Ion: None, sp_num: None
# Wavelength: 4693.950057811562, Ion: None, sp_num: None
# Wavelength: 4695.027590558112, Ion: None, sp_num: None
# Wavelength: 4696.105123304661, Ion: None, sp_num: None
# Wavelength: 4697.182656051211, Ion: None, sp_num: None
# Wavelength: 4698.26018879776, Ion: None, sp_num: None
# Wavelength: 4699.337721544309, Ion: None, sp_num: None
# Wavelength: 4700.415254290859, Ion: None, sp_num: None
# Wavelength: 4701.492787037408, Ion: None, sp_num: None
# Wavelength: 4702.570319783957, Ion: None, sp_num: None
# Wavelength: 4703.6478525305065, Ion: None, sp_num: None
# Wavelength: 4704.7253852770555, Ion: None, sp_num: None
# Wavelength: 4705.802918023604, Ion: None, sp_num: None
# Wavelength: 4706.880450770154, Ion: None, sp_num: None
# Wavelength: 4707.957983516703, Ion: None, sp_num: None
# Wavelength: 4709.035516263253, Ion: None, sp_num: None
# Wavelength: 4710.113049009802, Ion: None, sp_num: None
# Wavelength: 4711.190581756351, Ion: None, sp_num: None
# Wavelength: 4712.268114502901, Ion: None, sp_num: None
# Wavelength: 4713.34564724945, Ion: None, sp_num: None
# Wavelength: 4714.423179996, Ion: None, sp_num: None
# Wavelength: 4715.500712742549, Ion: None, sp_num: None
# Wavelength: 4716.578245489098, Ion: None, sp_num: None
# Wavelength: 4717.655778235648, Ion: None, sp_num: None
# Wavelength: 4718.733310982197, Ion: None, sp_num: None
# Wavelength: 4719.810843728746, Ion: None, sp_num: None
# Wavelength: 4720.888376475295, Ion: None, sp_num: None
# Wavelength: 4721.965909221844, Ion: None, sp_num: None
# Wavelength: 4723.043441968393, Ion: None, sp_num: None
# Wavelength: 4724.120974714943, Ion: None, sp_num: None
# Wavelength: 4725.198507461492, Ion: None, sp_num: None
# Wavelength: 4726.276040208042, Ion: None, sp_num: None
# Wavelength: 4727.353572954591, Ion: None, sp_num: None
# Wavelength: 4728.43110570114, Ion: None, sp_num: None
# Wavelength: 4729.50863844769, Ion: None, sp_num: None
# Wavelength: 4730.586171194239, Ion: None, sp_num: None
# Wavelength: 4731.663703940789, Ion: None, sp_num: None
# Wavelength: 4732.741236687338, Ion: None, sp_num: None
# Wavelength: 4733.818769433887, Ion: None, sp_num: None
# Wavelength: 4734.896302180437, Ion: None, sp_num: None
# Wavelength: 4735.973834926986, Ion: None, sp_num: None
# Wavelength: 4737.051367673535, Ion: None, sp_num: None
# Wavelength: 4738.128900420084, Ion: None, sp_num: None
# Wavelength: 4739.206433166633, Ion: None, sp_num: None
# Wavelength: 4740.283965913182, Ion: None, sp_num: None
# Wavelength: 4741.361498659732, Ion: None, sp_num: None
# Wavelength: 4742.439031406281, Ion: None, sp_num: None
# Wavelength: 4743.516564152831, Ion: None, sp_num: None
# Wavelength: 4744.59409689938, Ion: None, sp_num: None
# Wavelength: 4745.671629645929, Ion: None, sp_num: None
# Wavelength: 4746.749162392479, Ion: None, sp_num: None
# Wavelength: 4747.826695139028, Ion: None, sp_num: None
# Wavelength: 4748.904227885578, Ion: None, sp_num: None
# Wavelength: 4749.981760632127, Ion: None, sp_num: None
# Wavelength: 4751.059293378676, Ion: None, sp_num: None
# Wavelength: 4752.1368261252255, Ion: None, sp_num: None
# Wavelength: 4753.2143588717745, Ion: None, sp_num: None
# Wavelength: 4754.291891618324, Ion: None, sp_num: None
# Wavelength: 4755.369424364873, Ion: None, sp_num: None
# Wavelength: 4756.446957111422, Ion: None, sp_num: None
# Wavelength: 4757.524489857971, Ion: None, sp_num: None
# Wavelength: 4758.602022604521, Ion: None, sp_num: None
# Wavelength: 4759.67955535107, Ion: None, sp_num: None
# Wavelength: 4760.75708809762, Ion: None, sp_num: None
# Wavelength: 4761.834620844169, Ion: None, sp_num: None
# Wavelength: 4762.912153590718, Ion: None, sp_num: None
# Wavelength: 4763.989686337268, Ion: None, sp_num: None
# Wavelength: 4765.067219083817, Ion: None, sp_num: None
# Wavelength: 4766.144751830367, Ion: None, sp_num: None
# Wavelength: 4767.222284576916, Ion: None, sp_num: None
# Wavelength: 4768.299817323465, Ion: None, sp_num: None
# Wavelength: 4769.3773500700145, Ion: None, sp_num: None
# Wavelength: 4770.454882816563, Ion: None, sp_num: None
# Wavelength: 4771.532415563113, Ion: None, sp_num: None
# Wavelength: 4772.609948309662, Ion: None, sp_num: None
# Wavelength: 4773.687481056211, Ion: None, sp_num: None
# Wavelength: 4774.76501380276, Ion: None, sp_num: None
# Wavelength: 4775.84254654931, Ion: None, sp_num: None
# Wavelength: 4776.920079295859, Ion: None, sp_num: None
# Wavelength: 4777.997612042409, Ion: None, sp_num: None
# Wavelength: 4779.075144788958, Ion: None, sp_num: None
# Wavelength: 4780.152677535507, Ion: None, sp_num: None
# Wavelength: 4781.230210282057, Ion: None, sp_num: None
# Wavelength: 4782.307743028606, Ion: None, sp_num: None
# Wavelength: 4783.385275775156, Ion: None, sp_num: None
# Wavelength: 4784.462808521705, Ion: None, sp_num: None
# Wavelength: 4785.5403412682535, Ion: None, sp_num: None
# Wavelength: 4786.617874014803, Ion: None, sp_num: None
# Wavelength: 4787.695406761352, Ion: None, sp_num: None
# Wavelength: 4788.772939507902, Ion: None, sp_num: None
# Wavelength: 4789.850472254451, Ion: None, sp_num: None
# Wavelength: 4790.928005001, Ion: None, sp_num: None
# Wavelength: 4792.005537747549, Ion: None, sp_num: None
# Wavelength: 4793.083070494099, Ion: None, sp_num: None
# Wavelength: 4794.160603240648, Ion: None, sp_num: None
# Wavelength: 4795.238135987198, Ion: None, sp_num: None
# Wavelength: 4796.315668733747, Ion: None, sp_num: None
# Wavelength: 4797.393201480296, Ion: None, sp_num: None
# Wavelength: 4798.470734226846, Ion: None, sp_num: None
# Wavelength: 4799.548266973395, Ion: None, sp_num: None
# Wavelength: 4800.625799719945, Ion: None, sp_num: None
# Wavelength: 4801.7033324664935, Ion: None, sp_num: None
# Wavelength: 4802.7808652130425, Ion: None, sp_num: None
# Wavelength: 4803.858397959592, Ion: None, sp_num: None
# Wavelength: 4804.935930706141, Ion: None, sp_num: None
# Wavelength: 4806.013463452691, Ion: None, sp_num: None
# Wavelength: 4807.09099619924, Ion: None, sp_num: None
# Wavelength: 4808.168528945789, Ion: None, sp_num: None
# Wavelength: 4809.246061692339, Ion: None, sp_num: None
# Wavelength: 4810.323594438888, Ion: None, sp_num: None
# Wavelength: 4811.401127185438, Ion: Cr, sp_num: 1
# Wavelength: 4812.478659931987, Ion: Mo, sp_num: 1
# Wavelength: 4813.556192678536, Ion: Ti, sp_num: 1
# Wavelength: 4814.633725425085, Ion: None, sp_num: None
# Wavelength: 4815.711258171635, Ion: Fe, sp_num: 1
# Wavelength: 4816.788790918184, Ion: Th, sp_num: 2
# Wavelength: 4817.8663236647335, Ion: Ti, sp_num: 1
# Wavelength: 4818.9438564112825, Ion: Pd, sp_num: 1
# Wavelength: 4820.021389157831, Ion: Th, sp_num: 2
# Wavelength: 4821.098921904381, Ion: None, sp_num: None
# Wavelength: 4822.17645465093, Ion: None, sp_num: None
# Wavelength: 4823.25398739748, Ion: None, sp_num: None
# Wavelength: 4824.331520144029, Ion: None, sp_num: None
# Wavelength: 4825.409052890578, Ion: Th, sp_num: 2
# Wavelength: 4826.486585637128, Ion: None, sp_num: None
# Wavelength: 4827.564118383677, Ion: None, sp_num: None
# Wavelength: 4828.641651130227, Ion: None, sp_num: None
# Wavelength: 4829.719183876776, Ion: Th, sp_num: 2
# Wavelength: 4830.796716623325, Ion: Cr, sp_num: 1
# Wavelength: 4831.874249369874, Ion: Mo, sp_num: 1
# Wavelength: 4832.951782116424, Ion: Th, sp_num: 2
# Wavelength: 4834.029314862973, Ion: Fe, sp_num: 1
# Wavelength: 4835.106847609522, Ion: Dy, sp_num: 2
# Wavelength: 4836.184380356071, Ion: None, sp_num: None
# Wavelength: 4837.26191310262, Ion: Fe, sp_num: 1
# Wavelength: 4838.33944584917, Ion: Yb, sp_num: 2
# Wavelength: 4839.416978595719, Ion: Fe, sp_num: 1
# Wavelength: 4840.494511342269, Ion: Th, sp_num: 2
# Wavelength: 4841.572044088818, Ion: None, sp_num: None
# Wavelength: 4842.649576835367, Ion: Th, sp_num: 2
# Wavelength: 4843.727109581917, Ion: Cu, sp_num: 1
# Wavelength: 4844.804642328466, Ion: None, sp_num: None
# Wavelength: 4845.882175075016, Ion: Ru, sp_num: 1
# Wavelength: 4846.959707821565, Ion: Fe, sp_num: 1
# Wavelength: 4848.037240568114, Ion: V, sp_num: 1
# Wavelength: 4849.114773314663, Ion: Sm, sp_num: 2
# Wavelength: 4850.192306061213, Ion: V, sp_num: 1
# Wavelength: 4851.2698388077615, Ion: K, sp_num: 1
# Wavelength: 4852.347371554311, Ion: Cr, sp_num: 1
# Wavelength: 4853.42490430086, Ion: None, sp_num: None
# Wavelength: 4854.502437047409, Ion: None, sp_num: None
# Wavelength: 4855.579969793959, Ion: Y, sp_num: 1
# Wavelength: 4856.657502540508, Ion: V, sp_num: 1
# Wavelength: 4857.735035287058, Ion: None, sp_num: None
# Wavelength: 4858.812568033607, Ion: Ti, sp_num: 1
# Wavelength: 4859.890100780156, Ion: None, sp_num: None
# Wavelength: 4860.967633526706, Ion: None, sp_num: None
# Wavelength: 4862.045166273255, Ion: None, sp_num: None
# Wavelength: 4863.122699019805, Ion: Cr, sp_num: 1
# Wavelength: 4864.200231766354, Ion: None, sp_num: None
# Wavelength: 4865.277764512903, Ion: Cr, sp_num: 1
# Wavelength: 4866.355297259452, Ion: Gd, sp_num: 2
# Wavelength: 4867.4328300060015, Ion: Zr, sp_num: 1
# Wavelength: 4868.5103627525505, Ion: None, sp_num: None
# Wavelength: 4869.5878954991, Ion: Ti, sp_num: 1
# Wavelength: 4870.665428245649, Ion: None, sp_num: None
# Wavelength: 4871.742960992198, Ion: None, sp_num: None
# Wavelength: 4872.820493738748, Ion: None, sp_num: None
# Wavelength: 4873.898026485297, Ion: Sr, sp_num: 1
# Wavelength: 4874.975559231847, Ion: None, sp_num: None
# Wavelength: 4876.053091978396, Ion: Ti, sp_num: 1
# Wavelength: 4877.130624724945, Ion: None, sp_num: None
# Wavelength: 4878.208157471495, Ion: None, sp_num: None
# Wavelength: 4879.285690218044, Ion: None, sp_num: None
# Wavelength: 4880.363222964594, Ion: None, sp_num: None
# Wavelength: 4881.440755711143, Ion: Cr, sp_num: 1
# Wavelength: 4882.518288457692, Ion: Th, sp_num: 2
# Wavelength: 4883.595821204241, Ion: Fe, sp_num: 1
# Wavelength: 4884.67335395079, Ion: None, sp_num: None
# Wavelength: 4885.750886697339, Ion: None, sp_num: None
# Wavelength: 4886.828419443889, Ion: Na, sp_num: 2
# Wavelength: 4887.905952190438, Ion: Y, sp_num: 1
# Wavelength: 4888.983484936987, Ion: Cr, sp_num: 1
# Wavelength: 4890.061017683537, Ion: Fe, sp_num: 1
# Wavelength: 4891.138550430086, Ion: Ho, sp_num: 2
# Wavelength: 4892.216083176636, Ion: Fe, sp_num: 1
# Wavelength: 4893.293615923185, Ion: Ti, sp_num: 1
# Wavelength: 4894.371148669734, Ion: Ti, sp_num: 1
# Wavelength: 4895.448681416284, Ion: None, sp_num: None
# Wavelength: 4896.526214162833, Ion: None, sp_num: None
# Wavelength: 4897.603746909383, Ion: Th, sp_num: 2
# Wavelength: 4898.681279655932, Ion: None, sp_num: None
# Wavelength: 4899.7588124024805, Ion: V, sp_num: 1
# Wavelength: 4900.8363451490295, Ion: None, sp_num: None
# Wavelength: 4901.913877895579, Ion: Ti, sp_num: 1
# Wavelength: 4902.991410642128, Ion: None, sp_num: None
# Wavelength: 4904.068943388678, Ion: None, sp_num: None
# Wavelength: 4905.146476135227, Ion: Ti, sp_num: 1
# Wavelength: 4906.224008881776, Ion: None, sp_num: None
# Wavelength: 4907.301541628326, Ion: None, sp_num: None
# Wavelength: 4908.379074374875, Ion: Ho, sp_num: 2
# Wavelength: 4909.456607121425, Ion: Fe, sp_num: 1
# Wavelength: 4910.534139867974, Ion: Ti, sp_num: 1
# Wavelength: 4911.611672614523, Ion: Th, sp_num: 2
# Wavelength: 4912.689205361073, Ion: None, sp_num: None
# Wavelength: 4913.766738107622, Ion: None, sp_num: None
# Wavelength: 4914.844270854172, Ion: None, sp_num: None
# Wavelength: 4915.9218036007205, Ion: None, sp_num: None
# Wavelength: 4916.9993363472695, Ion: None, sp_num: None
# Wavelength: 4918.0768690938185, Ion: None, sp_num: None
# Wavelength: 4919.154401840368, Ion: Ti, sp_num: 1
# Wavelength: 4920.231934586917, Ion: Fe, sp_num: 1
# Wavelength: 4921.309467333467, Ion: Ti, sp_num: 1
# Wavelength: 4922.387000080016, Ion: Cr, sp_num: 1
# Wavelength: 4923.464532826565, Ion: None, sp_num: None
# Wavelength: 4924.542065573115, Ion: Dy, sp_num: 2
# Wavelength: 4925.619598319664, Ion: Fe, sp_num: 1
# Wavelength: 4926.697131066214, Ion: Fe, sp_num: 1
# Wavelength: 4927.774663812763, Ion: Y, sp_num: 1
# Wavelength: 4928.852196559312, Ion: Fe, sp_num: 1
# Wavelength: 4929.929729305862, Ion: None, sp_num: None
# Wavelength: 4931.007262052411, Ion: Th, sp_num: 2
# Wavelength: 4932.0847947989605, Ion: None, sp_num: None
# Wavelength: 4933.1623275455095, Ion: None, sp_num: None
# Wavelength: 4934.239860292058, Ion: None, sp_num: None
# Wavelength: 4935.317393038607, Ion: Th, sp_num: 2
# Wavelength: 4936.394925785157, Ion: V, sp_num: 1
# Wavelength: 4937.472458531706, Ion: None, sp_num: None
# Wavelength: 4938.549991278256, Ion: Yb, sp_num: 2
# Wavelength: 4939.627524024805, Ion: Fe, sp_num: 1
# Wavelength: 4940.705056771354, Ion: Fe, sp_num: 1
# Wavelength: 4941.782589517904, Ion: None, sp_num: None
# Wavelength: 4942.860122264453, Ion: Ti, sp_num: 1
# Wavelength: 4943.937655011003, Ion: Fe, sp_num: 1
# Wavelength: 4945.015187757552, Ion: None, sp_num: None
# Wavelength: 4946.092720504101, Ion: None, sp_num: None
# Wavelength: 4947.170253250651, Ion: Th, sp_num: 2
# Wavelength: 4948.2477859972, Ion: None, sp_num: None
# Wavelength: 4949.325318743749, Ion: Ti, sp_num: 1
# Wavelength: 4950.402851490298, Ion: None, sp_num: None
# Wavelength: 4951.480384236847, Ion: Y, sp_num: 1
# Wavelength: 4952.557916983397, Ion: None, sp_num: None
# Wavelength: 4953.635449729946, Ion: None, sp_num: None
# Wavelength: 4954.712982476496, Ion: None, sp_num: None
# Wavelength: 4955.790515223045, Ion: Th, sp_num: 2
# Wavelength: 4956.868047969594, Ion: None, sp_num: None
# Wavelength: 4957.945580716143, Ion: None, sp_num: None
# Wavelength: 4959.023113462693, Ion: Fe, sp_num: 1
# Wavelength: 4960.100646209242, Ion: Th, sp_num: 2
# Wavelength: 4961.178178955792, Ion: Th, sp_num: 2
# Wavelength: 4962.255711702341, Ion: None, sp_num: None
# Wavelength: 4963.33324444889, Ion: Fe, sp_num: 1
# Wavelength: 4964.41077719544, Ion: Th, sp_num: 2
# Wavelength: 4965.4883099419885, Ion: Th, sp_num: 2
# Wavelength: 4966.565842688538, Ion: None, sp_num: None
# Wavelength: 4967.643375435087, Ion: Fe, sp_num: 1
# Wavelength: 4968.720908181636, Ion: Ti, sp_num: 1
# Wavelength: 4969.798440928186, Ion: Th, sp_num: 2
# Wavelength: 4970.875973674735, Ion: None, sp_num: None
# Wavelength: 4971.953506421285, Ion: Fe, sp_num: 1
# Wavelength: 4973.031039167834, Ion: Sr, sp_num: 1
# Wavelength: 4974.108571914383, Ion: Th, sp_num: 2
# Wavelength: 4975.186104660932, Ion: Th, sp_num: 2
# Wavelength: 4976.263637407482, Ion: None, sp_num: None
# Wavelength: 4977.341170154031, Ion: Th, sp_num: 2
# Wavelength: 4978.418702900581, Ion: None, sp_num: None
# Wavelength: 4979.49623564713, Ion: Th, sp_num: 2
# Wavelength: 4980.573768393679, Ion: Mo, sp_num: 1
# Wavelength: 4981.6513011402285, Ion: Fe, sp_num: 1
# Wavelength: 4982.7288338867775, Ion: None, sp_num: None
# Wavelength: 4983.806366633327, Ion: Fe, sp_num: 1
# Wavelength: 4984.883899379876, Ion: Cr, sp_num: 1
# Wavelength: 4985.961432126425, Ion: V, sp_num: 1
# Wavelength: 4987.038964872975, Ion: None, sp_num: None
# Wavelength: 4988.116497619524, Ion: None, sp_num: None
# Wavelength: 4989.194030366074, Ion: None, sp_num: None
# Wavelength: 4990.271563112623, Ion: Fe, sp_num: 1
# Wavelength: 4991.349095859172, Ion: Nd, sp_num: 2
# Wavelength: 4992.426628605721, Ion: Th, sp_num: 2
# Wavelength: 4993.504161352271, Ion: None, sp_num: None
# Wavelength: 4994.58169409882, Ion: None, sp_num: None
# Wavelength: 4995.65922684537, Ion: None, sp_num: None
# Wavelength: 4996.736759591919, Ion: Fe, sp_num: 1
# Wavelength: 4997.814292338468, Ion: None, sp_num: None
# Wavelength: 4998.891825085017, Ion: None, sp_num: None
# Wavelength: 4999.969357831566, Ion: Cr, sp_num: 1
# Wavelength: 5001.046890578116, Ion: None, sp_num: None
# Wavelength: 5002.124423324665, Ion: None, sp_num: None
# Wavelength: 5003.201956071214, Ion: Fe, sp_num: 1
# Wavelength: 5004.279488817764, Ion: Fe, sp_num: 1
# Wavelength: 5005.357021564313, Ion: Fe, sp_num: 1
# Wavelength: 5006.434554310863, Ion: Cr, sp_num: 1
# Wavelength: 5007.512087057412, Ion: Si, sp_num: 1
# Wavelength: 5008.589619803961, Ion: Ti, sp_num: 1
# Wavelength: 5009.66715255051, Ion: Th, sp_num: 2
# Wavelength: 5010.74468529706, Ion: None, sp_num: None
# Wavelength: 5011.822218043609, Ion: None, sp_num: None
# Wavelength: 5012.899750790159, Ion: Zr, sp_num: 1
# Wavelength: 5013.977283536708, Ion: None, sp_num: None
# Wavelength: 5015.0548162832565, Ion: Th, sp_num: 2
# Wavelength: 5016.132349029806, Ion: None, sp_num: None
# Wavelength: 5017.209881776355, Ion: Th, sp_num: 2
# Wavelength: 5018.287414522905, Ion: None, sp_num: None
# Wavelength: 5019.364947269454, Ion: Tm, sp_num: 2
# Wavelength: 5020.442480016003, Ion: None, sp_num: None
# Wavelength: 5021.520012762553, Ion: Ti, sp_num: 1
# Wavelength: 5022.597545509102, Ion: None, sp_num: None
# Wavelength: 5023.675078255652, Ion: Fe, sp_num: 1
# Wavelength: 5024.752611002201, Ion: Ti, sp_num: 1
# Wavelength: 5025.83014374875, Ion: None, sp_num: None
# Wavelength: 5026.907676495299, Ion: Cr, sp_num: 1
# Wavelength: 5027.985209241849, Ion: None, sp_num: None
# Wavelength: 5029.062741988398, Ion: Fe, sp_num: 1
# Wavelength: 5030.1402747349475, Ion: None, sp_num: None
# Wavelength: 5031.2178074814965, Ion: None, sp_num: None
# Wavelength: 5032.2953402280455, Ion: None, sp_num: None
# Wavelength: 5033.372872974595, Ion: Fe, sp_num: 1
# Wavelength: 5034.450405721144, Ion: V, sp_num: 1
# Wavelength: 5035.527938467694, Ion: Tm, sp_num: 2
# Wavelength: 5036.605471214243, Ion: Th, sp_num: 2
# Wavelength: 5037.683003960792, Ion: None, sp_num: None
# Wavelength: 5038.760536707342, Ion: Th, sp_num: 2
# Wavelength: 5039.838069453891, Ion: Ti, sp_num: 1
# Wavelength: 5040.915602200441, Ion: None, sp_num: None
# Wavelength: 5041.99313494699, Ion: Th, sp_num: 2
# Wavelength: 5043.070667693539, Ion: Ca, sp_num: 1
# Wavelength: 5044.148200440088, Ion: None, sp_num: None
# Wavelength: 5045.225733186638, Ion: None, sp_num: None
# Wavelength: 5046.303265933187, Ion: None, sp_num: None
# Wavelength: 5047.3807986797365, Ion: None, sp_num: None
# Wavelength: 5048.458331426285, Ion: None, sp_num: None
# Wavelength: 5049.535864172834, Ion: La, sp_num: 2
# Wavelength: 5050.613396919384, Ion: None, sp_num: None
# Wavelength: 5051.690929665933, Ion: None, sp_num: None
# Wavelength: 5052.768462412483, Ion: Th, sp_num: 2
# Wavelength: 5053.845995159032, Ion: None, sp_num: None
# Wavelength: 5054.923527905581, Ion: None, sp_num: None
# Wavelength: 5056.001060652131, Ion: Fe, sp_num: 1
# Wavelength: 5057.07859339868, Ion: None, sp_num: None
# Wavelength: 5058.15612614523, Ion: Fe, sp_num: 1
# Wavelength: 5059.233658891779, Ion: Th, sp_num: 2
# Wavelength: 5060.311191638328, Ion: None, sp_num: None
# Wavelength: 5061.388724384877, Ion: Fe, sp_num: 1
# Wavelength: 5062.466257131427, Ion: None, sp_num: None
# Wavelength: 5063.5437898779755, Ion: Ti, sp_num: 1
# Wavelength: 5064.621322624525, Ion: Cr, sp_num: 1
# Wavelength: 5065.698855371074, Ion: Th, sp_num: 2
# Wavelength: 5066.776388117623, Ion: None, sp_num: None
# Wavelength: 5067.853920864173, Ion: None, sp_num: None
# Wavelength: 5068.931453610722, Ion: None, sp_num: None
# Wavelength: 5070.008986357272, Ion: Zn, sp_num: 1
# Wavelength: 5071.086519103821, Ion: None, sp_num: None
# Wavelength: 5072.16405185037, Ion: None, sp_num: None
# Wavelength: 5073.24158459692, Ion: Th, sp_num: 2
# Wavelength: 5074.319117343469, Ion: Cr, sp_num: 1
# Wavelength: 5075.396650090019, Ion: Fe, sp_num: 1
# Wavelength: 5076.474182836568, Ion: None, sp_num: None
# Wavelength: 5077.551715583117, Ion: Th, sp_num: 2
# Wavelength: 5078.629248329667, Ion: None, sp_num: None
# Wavelength: 5079.7067810762155, Ion: Zr, sp_num: 1
# Wavelength: 5080.784313822765, Ion: None, sp_num: None
# Wavelength: 5081.861846569314, Ion: Fe, sp_num: 1
# Wavelength: 5082.939379315863, Ion: None, sp_num: None
# Wavelength: 5084.016912062412, Ion: None, sp_num: None
# Wavelength: 5085.094444808962, Ion: None, sp_num: None
# Wavelength: 5086.171977555511, Ion: None, sp_num: None
# Wavelength: 5087.249510302061, Ion: Cd, sp_num: 1
# Wavelength: 5088.32704304861, Ion: V, sp_num: 1
# Wavelength: 5089.404575795159, Ion: None, sp_num: None
# Wavelength: 5090.482108541709, Ion: None, sp_num: None
# Wavelength: 5091.559641288258, Ion: None, sp_num: None
# Wavelength: 5092.637174034808, Ion: None, sp_num: None
# Wavelength: 5093.714706781357, Ion: Gd, sp_num: 2
# Wavelength: 5094.792239527906, Ion: Cr, sp_num: 1
# Wavelength: 5095.8697722744555, Ion: None, sp_num: None
# Wavelength: 5096.9473050210045, Ion: None, sp_num: None
# Wavelength: 5098.024837767554, Ion: Th, sp_num: 2
# Wavelength: 5099.102370514103, Ion: None, sp_num: None
# Wavelength: 5100.179903260652, Ion: Fe, sp_num: 1
# Wavelength: 5101.257436007201, Ion: None, sp_num: None
# Wavelength: 5102.334968753751, Ion: Gd, sp_num: 2
# Wavelength: 5103.4125015003, Ion: None, sp_num: None
# Wavelength: 5104.49003424685, Ion: Sm, sp_num: 2
# Wavelength: 5105.567566993399, Ion: Fe, sp_num: 1
# Wavelength: 5106.645099739948, Ion: V, sp_num: 1
# Wavelength: 5107.722632486498, Ion: Th, sp_num: 2
# Wavelength: 5108.800165233047, Ion: Fe, sp_num: 1
# Wavelength: 5109.877697979597, Ion: Fe, sp_num: 1
# Wavelength: 5110.955230726146, Ion: Na, sp_num: 1
# Wavelength: 5112.032763472695, Ion: None, sp_num: None
# Wavelength: 5113.110296219244, Ion: None, sp_num: None
# Wavelength: 5114.187828965793, Ion: None, sp_num: None
# Wavelength: 5115.265361712343, Ion: Ti, sp_num: 1
# Wavelength: 5116.342894458892, Ion: Mo, sp_num: 1
# Wavelength: 5117.420427205441, Ion: None, sp_num: None
# Wavelength: 5118.49795995199, Ion: Pd, sp_num: 1
# Wavelength: 5119.57549269854, Ion: None, sp_num: None
# Wavelength: 5120.653025445089, Ion: None, sp_num: None
# Wavelength: 5121.730558191639, Ion: None, sp_num: None
# Wavelength: 5122.808090938188, Ion: None, sp_num: None
# Wavelength: 5123.885623684737, Ion: Th, sp_num: 2
# Wavelength: 5124.963156431287, Ion: Cr, sp_num: 1
# Wavelength: 5126.040689177836, Ion: Fe, sp_num: 1
# Wavelength: 5127.118221924386, Ion: None, sp_num: None
# Wavelength: 5128.195754670935, Ion: None, sp_num: None
# Wavelength: 5129.2732874174835, Ion: None, sp_num: None
# Wavelength: 5130.350820164033, Ion: None, sp_num: None
# Wavelength: 5131.428352910582, Ion: None, sp_num: None
# Wavelength: 5132.505885657132, Ion: Th, sp_num: 2
# Wavelength: 5133.583418403681, Ion: Th, sp_num: 2
# Wavelength: 5134.66095115023, Ion: None, sp_num: None
# Wavelength: 5135.738483896779, Ion: None, sp_num: None
# Wavelength: 5136.816016643329, Ion: None, sp_num: None
# Wavelength: 5137.893549389878, Ion: Ru, sp_num: 1
# Wavelength: 5138.971082136428, Ion: V, sp_num: 1
# Wavelength: 5140.048614882977, Ion: Cr, sp_num: 1
# Wavelength: 5141.126147629526, Ion: Dy, sp_num: 2
# Wavelength: 5142.203680376076, Ion: Th, sp_num: 2
# Wavelength: 5143.281213122625, Ion: None, sp_num: None
# Wavelength: 5144.3587458691745, Ion: Fe, sp_num: 1
# Wavelength: 5145.4362786157235, Ion: None, sp_num: None
# Wavelength: 5146.5138113622725, Ion: Th, sp_num: 2
# Wavelength: 5147.591344108822, Ion: None, sp_num: None
# Wavelength: 5148.668876855371, Ion: Ru, sp_num: 1
# Wavelength: 5149.746409601921, Ion: Fe, sp_num: 1
# Wavelength: 5150.82394234847, Ion: Tm, sp_num: 2
# Wavelength: 5151.901475095019, Ion: None, sp_num: None
# Wavelength: 5152.979007841568, Ion: None, sp_num: None
# Wavelength: 5154.056540588118, Ion: Cs, sp_num: 1
# Wavelength: 5155.134073334667, Ion: Th, sp_num: 2
# Wavelength: 5156.211606081217, Ion: None, sp_num: None
# Wavelength: 5157.289138827766, Ion: Ni, sp_num: 1
# Wavelength: 5158.366671574315, Ion: V, sp_num: 1
# Wavelength: 5159.444204320865, Ion: Zr, sp_num: 1
# Wavelength: 5160.521737067414, Ion: Fe, sp_num: 1
# Wavelength: 5161.5992698139635, Ion: Sn, sp_num: 1
# Wavelength: 5162.676802560512, Ion: Fe, sp_num: 1
# Wavelength: 5163.754335307061, Ion: Fe, sp_num: 1
# Wavelength: 5164.831868053611, Ion: None, sp_num: None
# Wavelength: 5165.90940080016, Ion: Gd, sp_num: 2
# Wavelength: 5166.98693354671, Ion: Sr, sp_num: 1
# Wavelength: 5168.064466293259, Ion: None, sp_num: None
# Wavelength: 5169.141999039808, Ion: Fe, sp_num: 1
# Wavelength: 5170.219531786357, Ion: None, sp_num: None
# Wavelength: 5171.297064532907, Ion: V, sp_num: 1
# Wavelength: 5172.374597279456, Ion: Ru, sp_num: 1
# Wavelength: 5173.452130026006, Ion: V, sp_num: 1
# Wavelength: 5174.529662772555, Ion: Fe, sp_num: 1
# Wavelength: 5175.607195519104, Ion: Mo, sp_num: 1
# Wavelength: 5176.684728265654, Ion: None, sp_num: None
# Wavelength: 5177.7622610122025, Ion: Gd, sp_num: 2
# Wavelength: 5178.839793758752, Ion: Cr, sp_num: 1
# Wavelength: 5179.917326505301, Ion: V, sp_num: 1
# Wavelength: 5180.99485925185, Ion: None, sp_num: None
# Wavelength: 5182.0723919984, Ion: V, sp_num: 1
# Wavelength: 5183.149924744949, Ion: None, sp_num: None
# Wavelength: 5184.227457491499, Ion: V, sp_num: 1
# Wavelength: 5185.304990238048, Ion: Ti, sp_num: 1
# Wavelength: 5186.382522984597, Ion: None, sp_num: None
# Wavelength: 5187.460055731146, Ion: Th, sp_num: 2
# Wavelength: 5188.537588477696, Ion: Zr, sp_num: 1
# Wavelength: 5189.615121224245, Ion: La, sp_num: 2
# Wavelength: 5190.692653970795, Ion: None, sp_num: None
# Wavelength: 5191.770186717344, Ion: None, sp_num: None
# Wavelength: 5192.847719463893, Ion: Pr, sp_num: 2
# Wavelength: 5193.9252522104425, Ion: None, sp_num: None
# Wavelength: 5195.0027849569915, Ion: Cr, sp_num: 1
# Wavelength: 5196.080317703541, Ion: Cr, sp_num: 1
# Wavelength: 5197.15785045009, Ion: None, sp_num: None
# Wavelength: 5198.235383196639, Ion: Cs, sp_num: 1
# Wavelength: 5199.312915943189, Ion: Fe, sp_num: 1
# Wavelength: 5200.390448689738, Ion: None, sp_num: None
# Wavelength: 5201.467981436288, Ion: None, sp_num: None
# Wavelength: 5202.545514182837, Ion: Ti, sp_num: 1
# Wavelength: 5203.623046929386, Ion: Ru, sp_num: 1
# Wavelength: 5204.700579675935, Ion: Na, sp_num: 2
# Wavelength: 5205.778112422485, Ion: U, sp_num: 2
# Wavelength: 5206.855645169034, Ion: None, sp_num: None
# Wavelength: 5207.933177915584, Ion: Th, sp_num: 2
# Wavelength: 5209.010710662133, Ion: None, sp_num: None
# Wavelength: 5210.088243408682, Ion: Na, sp_num: 2
# Wavelength: 5211.1657761552315, Ion: None, sp_num: None
# Wavelength: 5212.24330890178, Ion: None, sp_num: None
# Wavelength: 5213.32084164833, Ion: Mo, sp_num: 1
# Wavelength: 5214.398374394879, Ion: Er, sp_num: 2
# Wavelength: 5215.475907141428, Ion: None, sp_num: None
# Wavelength: 5216.553439887978, Ion: Er, sp_num: 2
# Wavelength: 5217.630972634527, Ion: Cr, sp_num: 1
# Wavelength: 5218.708505381077, Ion: None, sp_num: None
# Wavelength: 5219.786038127626, Ion: Er, sp_num: 2
# Wavelength: 5220.863570874175, Ion: Mo, sp_num: 1
# Wavelength: 5221.941103620725, Ion: None, sp_num: None
# Wavelength: 5223.018636367274, Ion: None, sp_num: None
# Wavelength: 5224.096169113824, Ion: Cr, sp_num: 1
# Wavelength: 5225.173701860373, Ion: Ti, sp_num: 1
# Wavelength: 5226.251234606922, Ion: None, sp_num: None
# Wavelength: 5227.3287673534705, Ion: Cr, sp_num: 1
# Wavelength: 5228.40630010002, Ion: Fe, sp_num: 1
# Wavelength: 5229.483832846569, Ion: Cr, sp_num: 1
# Wavelength: 5230.561365593119, Ion: None, sp_num: None
# Wavelength: 5231.638898339668, Ion: Cr, sp_num: 1
# Wavelength: 5232.716431086217, Ion: None, sp_num: None
# Wavelength: 5233.793963832767, Ion: Mo, sp_num: 1
# Wavelength: 5234.871496579316, Ion: None, sp_num: None
# Wavelength: 5235.949029325866, Ion: None, sp_num: None
# Wavelength: 5237.026562072415, Ion: None, sp_num: None
# Wavelength: 5238.104094818964, Ion: Cr, sp_num: 1
# Wavelength: 5239.181627565514, Ion: Th, sp_num: 2
# Wavelength: 5240.259160312063, Ion: None, sp_num: None
# Wavelength: 5241.336693058613, Ion: Nd, sp_num: 2
# Wavelength: 5242.414225805162, Ion: V, sp_num: 1
# Wavelength: 5243.4917585517105, Ion: Th, sp_num: 2
# Wavelength: 5244.5692912982595, Ion: None, sp_num: None
# Wavelength: 5245.646824044809, Ion: Th, sp_num: 2
# Wavelength: 5246.724356791358, Ion: None, sp_num: None
# Wavelength: 5247.801889537908, Ion: Ti, sp_num: 1
# Wavelength: 5248.879422284457, Ion: None, sp_num: None
# Wavelength: 5249.956955031006, Ion: V, sp_num: 1
# Wavelength: 5251.034487777556, Ion: Nd, sp_num: 2
# Wavelength: 5252.112020524105, Ion: Fe, sp_num: 1
# Wavelength: 5253.189553270655, Ion: Ru, sp_num: 1
# Wavelength: 5254.267086017204, Ion: Th, sp_num: 2
# Wavelength: 5255.344618763753, Ion: Ba, sp_num: 1
# Wavelength: 5256.422151510303, Ion: Cr, sp_num: 1
# Wavelength: 5257.499684256852, Ion: Th, sp_num: 2
# Wavelength: 5258.5772170034015, Ion: Er, sp_num: 2
# Wavelength: 5259.6547497499505, Ion: V, sp_num: 1
# Wavelength: 5260.7322824964995, Ion: None, sp_num: None
# Wavelength: 5261.809815243048, Ion: V, sp_num: 1
# Wavelength: 5262.887347989598, Ion: None, sp_num: None
# Wavelength: 5263.964880736147, Ion: None, sp_num: None
# ...
# Wavelength: 8754.093446809362, Ion: None, sp_num: None
# Wavelength: 8755.17097955591, Ion: None, sp_num: None
# Wavelength: 8756.248512302462, Ion: None, sp_num: None
# Wavelength: 8757.32604504901, Ion: None, sp_num: None
# Wavelength: 8758.403577795561, Ion: None, sp_num: None
# Wavelength: 8759.48111054211, Ion: None, sp_num: None
# Wavelength: 8760.55864328866, Ion: None, sp_num: None
# Wavelength: 8761.636176035208, Ion: None, sp_num: None
# Wavelength: 8762.713708781757, Ion: None, sp_num: None
# Wavelength: 8763.791241528306, Ion: Pd, sp_num: 1
# Wavelength: 8764.868774274855, Ion: None, sp_num: None
# Wavelength: 8765.946307021404, Ion: None, sp_num: None
# Wavelength: 8767.023839767955, Ion: None, sp_num: None
# Wavelength: 8768.101372514504, Ion: None, sp_num: None
# Wavelength: 8769.178905261053, Ion: Ti, sp_num: 1
# Wavelength: 8770.256438007604, Ion: None, sp_num: None
# Wavelength: 8771.333970754153, Ion: None, sp_num: None
# Wavelength: 8772.411503500702, Ion: None, sp_num: None
# Wavelength: 8773.48903624725, Ion: Ti, sp_num: 1
# Wavelength: 8774.5665689938, Ion: Ce, sp_num: 2
# Wavelength: 8775.644101740349, Ion: None, sp_num: None
# Wavelength: 8776.721634486898, Ion: None, sp_num: None
# Wavelength: 8777.799167233446, Ion: None, sp_num: None
# Wavelength: 8778.876699979997, Ion: None, sp_num: None
# Wavelength: 8779.954232726546, Ion: None, sp_num: None
# Wavelength: 8781.031765473095, Ion: Ti, sp_num: 1
# Wavelength: 8782.109298219646, Ion: None, sp_num: None
# Wavelength: 8783.186830966195, Ion: None, sp_num: None
# Wavelength: 8784.264363712744, Ion: None, sp_num: None
# Wavelength: 8785.341896459293, Ion: None, sp_num: None
# Wavelength: 8786.419429205842, Ion: None, sp_num: None
# Wavelength: 8787.49696195239, Ion: None, sp_num: None
# Wavelength: 8788.57449469894, Ion: Cr, sp_num: 1
# Wavelength: 8789.652027445489, Ion: None, sp_num: None
# Wavelength: 8790.72956019204, Ion: Cr, sp_num: 1
# Wavelength: 8791.807092938589, Ion: None, sp_num: None
# Wavelength: 8792.88462568514, Ion: Si, sp_num: 1
# Wavelength: 8793.962158431688, Ion: None, sp_num: None
# Wavelength: 8795.039691178237, Ion: None, sp_num: None
# Wavelength: 8796.117223924786, Ion: None, sp_num: None
# Wavelength: 8797.194756671335, Ion: None, sp_num: None
# Wavelength: 8798.272289417884, Ion: None, sp_num: None
# Wavelength: 8799.349822164433, Ion: None, sp_num: None
# Wavelength: 8800.427354910982, Ion: None, sp_num: None
# Wavelength: 8801.504887657533, Ion: None, sp_num: None
# Wavelength: 8802.582420404082, Ion: None, sp_num: None
# Wavelength: 8803.65995315063, Ion: None, sp_num: None
# Wavelength: 8804.737485897182, Ion: None, sp_num: None
# Wavelength: 8805.81501864373, Ion: None, sp_num: None
# Wavelength: 8806.89255139028, Ion: None, sp_num: None
# Wavelength: 8807.970084136829, Ion: Ho, sp_num: 2
# Wavelength: 8809.047616883377, Ion: None, sp_num: None
# Wavelength: 8810.125149629926, Ion: None, sp_num: None
# Wavelength: 8811.202682376475, Ion: Cr, sp_num: 1
# Wavelength: 8812.280215123024, Ion: None, sp_num: None
# Wavelength: 8813.357747869575, Ion: None, sp_num: None
# Wavelength: 8814.435280616124, Ion: None, sp_num: None
# Wavelength: 8815.512813362675, Ion: None, sp_num: None
# Wavelength: 8816.590346109224, Ion: None, sp_num: None
# Wavelength: 8817.667878855773, Ion: None, sp_num: None
# Wavelength: 8818.745411602322, Ion: None, sp_num: None
# Wavelength: 8819.82294434887, Ion: None, sp_num: None
# Wavelength: 8820.90047709542, Ion: None, sp_num: None
# Wavelength: 8821.978009841969, Ion: Fe, sp_num: 1
# Wavelength: 8823.055542588518, Ion: None, sp_num: None
# Wavelength: 8824.133075335068, Ion: None, sp_num: None
# Wavelength: 8825.210608081617, Ion: None, sp_num: None
# Wavelength: 8826.288140828166, Ion: None, sp_num: None
# Wavelength: 8827.365673574717, Ion: None, sp_num: None
# Wavelength: 8828.443206321266, Ion: None, sp_num: None
# Wavelength: 8829.520739067815, Ion: None, sp_num: None
# Wavelength: 8830.598271814364, Ion: Fe, sp_num: 1
# Wavelength: 8831.675804560913, Ion: None, sp_num: None
# Wavelength: 8832.753337307462, Ion: None, sp_num: None
# Wavelength: 8833.830870054011, Ion: None, sp_num: None
# Wavelength: 8834.90840280056, Ion: S, sp_num: 1
# Wavelength: 8835.98593554711, Ion: S, sp_num: 1
# Wavelength: 8837.06346829366, Ion: None, sp_num: None
# Wavelength: 8838.141001040209, Ion: Cr, sp_num: 1
# Wavelength: 8839.21853378676, Ion: None, sp_num: None
# Wavelength: 8840.296066533308, Ion: None, sp_num: None
# Wavelength: 8841.373599279857, Ion: None, sp_num: None
# Wavelength: 8842.451132026406, Ion: None, sp_num: None
# Wavelength: 8843.528664772955, Ion: None, sp_num: None
# Wavelength: 8844.606197519504, Ion: None, sp_num: None
# Wavelength: 8845.683730266053, Ion: None, sp_num: None
# Wavelength: 8846.761263012602, Ion: None, sp_num: None
# Wavelength: 8847.838795759153, Ion: None, sp_num: None
# Wavelength: 8848.916328505702, Ion: None, sp_num: None
# Wavelength: 8849.993861252253, Ion: None, sp_num: None
# Wavelength: 8851.071393998802, Ion: None, sp_num: None
# Wavelength: 8852.14892674535, Ion: Fe, sp_num: 1
# Wavelength: 8853.2264594919, Ion: None, sp_num: None
# Wavelength: 8854.303992238449, Ion: None, sp_num: None
# Wavelength: 8855.381524984998, Ion: None, sp_num: None
# Wavelength: 8856.459057731547, Ion: None, sp_num: None
# Wavelength: 8857.536590478096, Ion: None, sp_num: None
# Wavelength: 8858.614123224646, Ion: None, sp_num: None
# Wavelength: 8859.691655971195, Ion: None, sp_num: None
# Wavelength: 8860.769188717744, Ion: None, sp_num: None
# Wavelength: 8861.846721464295, Ion: Th, sp_num: 2
# Wavelength: 8862.924254210844, Ion: None, sp_num: None
# Wavelength: 8864.001786957393, Ion: None, sp_num: None
# Wavelength: 8865.079319703942, Ion: Ni, sp_num: 1
# Wavelength: 8866.156852450491, Ion: None, sp_num: None
# Wavelength: 8867.23438519704, Ion: None, sp_num: None
# Wavelength: 8868.311917943589, Ion: None, sp_num: None
# Wavelength: 8869.389450690138, Ion: Fe, sp_num: 1
# Wavelength: 8870.466983436689, Ion: None, sp_num: None
# Wavelength: 8871.544516183238, Ion: None, sp_num: None
# Wavelength: 8872.622048929787, Ion: None, sp_num: None
# Wavelength: 8873.699581676337, Ion: None, sp_num: None
# Wavelength: 8874.777114422886, Ion: None, sp_num: None
# Wavelength: 8875.854647169435, Ion: None, sp_num: None
# Wavelength: 8876.932179915984, Ion: S, sp_num: 1
# Wavelength: 8878.009712662533, Ion: None, sp_num: None
# Wavelength: 8879.087245409082, Ion: None, sp_num: None
# Wavelength: 8880.164778155631, Ion: None, sp_num: None
# Wavelength: 8881.24231090218, Ion: Fe, sp_num: 1
# Wavelength: 8882.319843648731, Ion: None, sp_num: None
# Wavelength: 8883.39737639528, Ion: Th, sp_num: 2
# Wavelength: 8884.47490914183, Ion: None, sp_num: None
# Wavelength: 8885.55244188838, Ion: None, sp_num: None
# Wavelength: 8886.629974634929, Ion: None, sp_num: None
# Wavelength: 8887.707507381478, Ion: None, sp_num: None
# Wavelength: 8888.785040128027, Ion: None, sp_num: None
# Wavelength: 8889.862572874576, Ion: None, sp_num: None
# Wavelength: 8890.940105621125, Ion: None, sp_num: None
# Wavelength: 8892.017638367673, Ion: None, sp_num: None
# Wavelength: 8893.095171114224, Ion: None, sp_num: None
# Wavelength: 8894.172703860773, Ion: None, sp_num: None
# Wavelength: 8895.250236607322, Ion: None, sp_num: None
# Wavelength: 8896.327769353873, Ion: V, sp_num: 1
# Wavelength: 8897.405302100422, Ion: None, sp_num: None
# Wavelength: 8898.482834846971, Ion: None, sp_num: None
# Wavelength: 8899.56036759352, Ion: None, sp_num: None
# Wavelength: 8900.637900340069, Ion: None, sp_num: None
# Wavelength: 8901.715433086618, Ion: None, sp_num: None
# Wavelength: 8902.792965833167, Ion: None, sp_num: None
# Wavelength: 8903.870498579716, Ion: None, sp_num: None
# Wavelength: 8904.948031326267, Ion: None, sp_num: None
# Wavelength: 8906.025564072816, Ion: None, sp_num: None
# Wavelength: 8907.103096819365, Ion: None, sp_num: None
# Wavelength: 8908.180629565915, Ion: None, sp_num: None
# Wavelength: 8909.258162312464, Ion: None, sp_num: None
# Wavelength: 8910.335695059013, Ion: None, sp_num: None
# Wavelength: 8911.413227805562, Ion: None, sp_num: None
# Wavelength: 8912.490760552111, Ion: None, sp_num: None
# Wavelength: 8913.56829329866, Ion: None, sp_num: None
# Wavelength: 8914.64582604521, Ion: None, sp_num: None
# Wavelength: 8915.723358791758, Ion: None, sp_num: None
# Wavelength: 8916.800891538309, Ion: None, sp_num: None
# Wavelength: 8917.878424284858, Ion: None, sp_num: None
# Wavelength: 8918.955957031409, Ion: None, sp_num: None
# Wavelength: 8920.033489777958, Ion: None, sp_num: None
# Wavelength: 8921.111022524507, Ion: None, sp_num: None
# Wavelength: 8922.188555271056, Ion: None, sp_num: None
# Wavelength: 8923.266088017604, Ion: None, sp_num: None
# Wavelength: 8924.343620764153, Ion: None, sp_num: None
# Wavelength: 8925.421153510702, Ion: None, sp_num: None
# Wavelength: 8926.498686257251, Ion: None, sp_num: None
# Wavelength: 8927.576219003802, Ion: None, sp_num: None
# Wavelength: 8928.653751750351, Ion: None, sp_num: None
# Wavelength: 8929.7312844969, Ion: None, sp_num: None
# Wavelength: 8930.80881724345, Ion: None, sp_num: None
# Wavelength: 8931.88634999, Ion: Cr, sp_num: 1
# Wavelength: 8932.963882736549, Ion: None, sp_num: None
# Wavelength: 8934.041415483098, Ion: V, sp_num: 1
# Wavelength: 8935.118948229647, Ion: None, sp_num: None
# Wavelength: 8936.196480976196, Ion: None, sp_num: None
# Wavelength: 8937.274013722745, Ion: None, sp_num: None
# Wavelength: 8938.351546469294, Ion: Th, sp_num: 2
# Wavelength: 8939.429079215844, Ion: None, sp_num: None
# Wavelength: 8940.506611962393, Ion: V, sp_num: 1
# Wavelength: 8941.584144708944, Ion: Cr, sp_num: 1
# Wavelength: 8942.661677455493, Ion: None, sp_num: None
# Wavelength: 8943.739210202042, Ion: None, sp_num: None
# Wavelength: 8944.816742948591, Ion: None, sp_num: None
# Wavelength: 8945.89427569514, Ion: Cs, sp_num: 1
# Wavelength: 8946.971808441689, Ion: None, sp_num: None
# Wavelength: 8948.049341188238, Ion: None, sp_num: None
# Wavelength: 8949.126873934787, Ion: None, sp_num: None
# Wavelength: 8950.204406681338, Ion: None, sp_num: None
# Wavelength: 8951.281939427887, Ion: None, sp_num: None
# Wavelength: 8952.359472174436, Ion: None, sp_num: None
# Wavelength: 8953.437004920987, Ion: None, sp_num: None
# Wavelength: 8954.514537667535, Ion: None, sp_num: None
# Wavelength: 8955.592070414084, Ion: None, sp_num: None
# Wavelength: 8956.669603160633, Ion: None, sp_num: None
# Wavelength: 8957.747135907182, Ion: None, sp_num: None
# Wavelength: 8958.824668653731, Ion: None, sp_num: None
# Wavelength: 8959.90220140028, Ion: None, sp_num: None
# Wavelength: 8960.97973414683, Ion: None, sp_num: None
# Wavelength: 8962.05726689338, Ion: None, sp_num: None
# Wavelength: 8963.134799639929, Ion: None, sp_num: None
# Wavelength: 8964.212332386478, Ion: None, sp_num: None
# Wavelength: 8965.289865133029, Ion: None, sp_num: None
# Wavelength: 8966.367397879578, Ion: None, sp_num: None
# Wavelength: 8967.444930626127, Ion: None, sp_num: None
# Wavelength: 8968.522463372676, Ion: None, sp_num: None
# Wavelength: 8969.599996119225, Ion: None, sp_num: None
# Wavelength: 8970.677528865774, Ion: None, sp_num: None
# Wavelength: 8971.755061612323, Ion: None, sp_num: None
# Wavelength: 8972.832594358872, Ion: None, sp_num: None
# Wavelength: 8973.910127105422, Ion: Fe, sp_num: 1
# Wavelength: 8974.987659851971, Ion: None, sp_num: None
# Wavelength: 8976.065192598522, Ion: None, sp_num: None
# Wavelength: 8977.142725345071, Ion: None, sp_num: None
# Wavelength: 8978.22025809162, Ion: None, sp_num: None
# Wavelength: 8979.297790838169, Ion: Cr, sp_num: 1
# Wavelength: 8980.375323584718, Ion: None, sp_num: None
# Wavelength: 8981.452856331267, Ion: None, sp_num: None
# Wavelength: 8982.530389077816, Ion: None, sp_num: None
# Wavelength: 8983.607921824365, Ion: None, sp_num: None
# Wavelength: 8984.685454570916, Ion: None, sp_num: None
# Wavelength: 8985.762987317465, Ion: None, sp_num: None
# Wavelength: 8986.840520064014, Ion: None, sp_num: None
# Wavelength: 8987.918052810564, Ion: None, sp_num: None
# Wavelength: 8988.995585557113, Ion: None, sp_num: None
# Wavelength: 8990.073118303662, Ion: None, sp_num: None
# Wavelength: 8991.150651050211, Ion: None, sp_num: None
# Wavelength: 8992.22818379676, Ion: None, sp_num: None
# Wavelength: 8993.30571654331, Ion: None, sp_num: None
# Wavelength: 8994.383249289858, Ion: None, sp_num: None
# Wavelength: 8995.460782036407, Ion: None, sp_num: None
# Wavelength: 8996.538314782958, Ion: None, sp_num: None
# Wavelength: 8997.615847529507, Ion: None, sp_num: None
# Wavelength: 8998.693380276056, Ion: Cu, sp_num: 1
# Wavelength: 8999.770913022607, Ion: None, sp_num: None
# Wavelength: 9000.848445769156, Ion: None, sp_num: None
# Wavelength: 9001.925978515705, Ion: None, sp_num: None
# Wavelength: 9003.003511262254, Ion: None, sp_num: None
# Wavelength: 9004.081044008803, Ion: None, sp_num: None
# Wavelength: 9005.158576755352, Ion: None, sp_num: None
# Wavelength: 9006.2361095019, Ion: None, sp_num: None
# Wavelength: 9007.31364224845, Ion: None, sp_num: None
# Wavelength: 9008.391174995, Ion: None, sp_num: None
# Wavelength: 9009.46870774155, Ion: None, sp_num: None
# Wavelength: 9010.5462404881, Ion: None, sp_num: None
# Wavelength: 9011.623773234649, Ion: None, sp_num: None
# Wavelength: 9012.701305981198, Ion: None, sp_num: None
# Wavelength: 9013.778838727747, Ion: None, sp_num: None
# Wavelength: 9014.856371474296, Ion: None, sp_num: None
# Wavelength: 9015.933904220845, Ion: None, sp_num: None
# Wavelength: 9017.011436967394, Ion: None, sp_num: None
# Wavelength: 9018.088969713943, Ion: None, sp_num: None
# Wavelength: 9019.166502460494, Ion: None, sp_num: None
# Wavelength: 9020.244035207043, Ion: None, sp_num: None
# Wavelength: 9021.321567953592, Ion: None, sp_num: None
# Wavelength: 9022.399100700142, Ion: None, sp_num: None
# Wavelength: 9023.476633446691, Ion: None, sp_num: None
# Wavelength: 9024.55416619324, Ion: None, sp_num: None
# Wavelength: 9025.63169893979, Ion: None, sp_num: None
# Wavelength: 9026.709231686338, Ion: None, sp_num: None
# Wavelength: 9027.786764432887, Ion: None, sp_num: None
# Wavelength: 9028.864297179436, Ion: Fe, sp_num: 1
# Wavelength: 9029.941829925985, Ion: None, sp_num: None
# Wavelength: 9031.019362672536, Ion: None, sp_num: None
# Wavelength: 9032.096895419085, Ion: None, sp_num: None
# Wavelength: 9033.174428165634, Ion: Fe, sp_num: 1
# Wavelength: 9034.251960912185, Ion: None, sp_num: None
# Wavelength: 9035.329493658734, Ion: None, sp_num: None
# Wavelength: 9036.407026405283, Ion: None, sp_num: None
# Wavelength: 9037.484559151831, Ion: None, sp_num: None
# Wavelength: 9038.56209189838, Ion: None, sp_num: None
# Wavelength: 9039.63962464493, Ion: None, sp_num: None
# Wavelength: 9040.717157391478, Ion: None, sp_num: None
# Wavelength: 9041.794690138027, Ion: S, sp_num: 1
# Wavelength: 9042.872222884578, Ion: None, sp_num: None
# Wavelength: 9043.949755631127, Ion: None, sp_num: None
# Wavelength: 9045.027288377678, Ion: None, sp_num: None
# Wavelength: 9046.104821124227, Ion: None, sp_num: None
# Wavelength: 9047.182353870776, Ion: V, sp_num: 1
# Wavelength: 9048.259886617325, Ion: None, sp_num: None
# Wavelength: 9049.337419363874, Ion: None, sp_num: None
# Wavelength: 9050.414952110423, Ion: None, sp_num: None
# Wavelength: 9051.492484856972, Ion: None, sp_num: None
# Wavelength: 9052.57001760352, Ion: None, sp_num: None
# Wavelength: 9053.647550350071, Ion: None, sp_num: None
# Wavelength: 9054.72508309662, Ion: None, sp_num: None
# Wavelength: 9055.80261584317, Ion: None, sp_num: None
# Wavelength: 9056.88014858972, Ion: None, sp_num: None
# Wavelength: 9057.95768133627, Ion: None, sp_num: None
# Wavelength: 9059.035214082818, Ion: None, sp_num: None
# Wavelength: 9060.112746829367, Ion: Fe, sp_num: 1
# Wavelength: 9061.190279575916, Ion: Fe, sp_num: 1
# Wavelength: 9062.267812322465, Ion: Cr, sp_num: 1
# Wavelength: 9063.345345069014, Ion: None, sp_num: None
# Wavelength: 9064.422877815563, Ion: None, sp_num: None
# Wavelength: 9065.500410562114, Ion: None, sp_num: None
# Wavelength: 9066.577943308663, Ion: None, sp_num: None
# Wavelength: 9067.655476055212, Ion: None, sp_num: None
# Wavelength: 9068.733008801762, Ion: None, sp_num: None
# Wavelength: 9069.810541548311, Ion: None, sp_num: None
# Cross-checked 0 Lines (Blue Emission Arm):
